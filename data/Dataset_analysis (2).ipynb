# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(15, 10))

# set height of bar
mBERT = [60.52, 59.56]
ParsBERT = [61.72, 59.5]
XLM_RoBERTa = [63.15, 61.48]
ALBERT_Persian = [55.74, 56.69]

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
# br1 = [0,1]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# Make the plot
plt.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
		edgecolor ='grey', label ='mBERT')
plt.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

# Adding Xticks
# plt.xlabel('model name', fontweight ='bold', fontsize = 15)
plt.ylabel('Exact Match', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(mBERT))],
		['Further-Pretrained with Quran Corpus', 'Not Further-Pretrained with Quran Corpus'], fontsize = 15)

# y = [60.52, 59.56, 60.52, 59.56, 60.52, 59.56, 60.52, 59.56]
# for index, value in enumerate(y):
#     plt.text(value, index,
#              str(value))

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(15, 10))

# set height of bar
mBERT = [69.93, 69.47]
ParsBERT = [71.29, 69.01]
XLM_RoBERTa = [71.33, 69.45]
ALBERT_Persian = [65.09, 65.74]

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
# br1 = [0,1]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# Make the plot
plt.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
		edgecolor ='grey', label ='mBERT')
plt.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

plt.ylabel('F1', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(mBERT))],
		['Further-Pretrained with Quran Corpus', 'Not Further-Pretrained with Quran Corpus'], fontsize = 15)

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(30, 10))

# set height of bar
# mBERT = [69.93, 69.47, 70.91]
# ParsBERT = [71.29, 69.01, 73]
# XLM_RoBERTa = [71.33, 69.45, 73.75]
# ALBERT_Persian = [65.09, 65.74, 69.92]

mBERT = [69.47, 69.93, 70.91]
ParsBERT = [69.01, 71.29, 73]
XLM_RoBERTa = [69.45, 71.33, 73.75]
ALBERT_Persian = [65.74, 66.65, 69.92]


# Set position of bar on X axis
br1 = np.arange(len(mBERT))
# br1 = [0,1]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# Make the plot
plt.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
		edgecolor ='grey', label ='mBERT')
plt.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

plt.ylabel('F1', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(mBERT))],
		['Not Further-Pretrained with Quran Corpus', 'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset'], fontsize = 15)

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(30, 10))

# set height of bar
mBERT = [59.56, 60.52, 62.2]
ParsBERT = [59.5, 61.72, 64.59]
XLM_RoBERTa = [61.48, 63.15, 66.02]
ALBERT_Persian = [56.69, 57.17, 60.76]

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
# br1 = [0,1]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# Make the plot
plt.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
		edgecolor ='grey', label ='mBERT')
plt.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

# Adding Xticks
# plt.xlabel('model name', fontweight ='bold', fontsize = 15)
plt.ylabel('Exact Match', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(mBERT))],
		['Not Further-Pretrained with Quran Corpus', 'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset'], fontsize = 15)

plt.set_ylabel('Count')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-84e12cd201a9> in <cell line: 37>()
#      35 		['Not Further-Pretrained with Quran Corpus', 'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset'], fontsize = 15)
#      36
# ---> 37 for container in plt.containers:
#      38     plt.bar_label(container, fmt='%.1f')
#      39
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'containers'

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
# ax.pie(data)


y = np.array([35.1, 1.2, 3.7, 5, 4.9, 34.5, 15.6])
mylabels = ["شخص", "مکان", "رویداد", "صفت", "عدد", "عبارت", "سایر"]

colors = ['#85C1E9', '#566573', '#DD7596', '#8EB897', '#EDDA74', '#EE9A4D', '#9E4638']

# plt.pie(y, labels = mylabels, colors = colors)
patches, texts = ax.pie(y, colors=colors, shadow=True, startangle=90)
ax.legend(patches, mylabels, loc='lower right')

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns

mBERT = [59.56, 60.52, 62.2]
ParsBERT = [59.5, 61.72, 64.59]
XLM_RoBERTa = [61.48, 63.15, 66.02]
ALBERT_Persian = [56.69, 57.17, 60.76]

df = pd.DataFrame(np.column_stack([mBERT, ParsBERT, XLM_RoBERTa, ALBERT_Persian]),
                               columns=['mBERT', 'ParsBERT', 'XLM_RoBERTa', 'ALBERT_Persian'])

ax = sns.barplot(data=df)
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f')

# %%
import numpy as np
import matplotlib.pyplot as plt

# import seaborn
# seaborn.set()

data = np.array([[59.56, 60.52, 62.2], [59.5, 61.72, 64.59], [61.48, 63.15, 66.02], [56.69, 57.17, 60.76]])

# set width of bar
barWidth = 0.14

# set height of bar
mBERT = [59.56, 60.52, 62.2]
ParsBERT = [59.5, 61.72, 64.59]
XLM_RoBERTa = [61.48, 63.15, 66.02]
ALBERT_Persian = [56.69, 57.17, 60.76]

labels = ['mBERT', 'ParsBERT', 'XLM_RoBERTa', 'ALBERT_Persian']
groups = ['Not Further-Pretrained with Quran Corpus',
          'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset']

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# fig, ax = plt.subplots(layout='constrained', figsize =(30, 5))
fig, ax = plt.subplots(figsize =(40, 15))
# Make the plot
# ax.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
# 		edgecolor ='grey', label ='mBERT')
# ax.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
# 		edgecolor ='grey', label ='ParsBERT')
# plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
# 		edgecolor ='grey', label ='XLM-RoBERTa')
# plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
# 		edgecolor ='grey', label ='ALBERT-Persian')

ax.bar(br1, mBERT, color ='#F7DC6F', width = barWidth,
		edgecolor ='grey', label ='mBERT')
ax.bar(br2, ParsBERT, color ='#728FCE', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF733B', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#498F4C', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')


for c in ax.containers:
    # annotate the container group
    ax.bar_label(c, label_type='edge', fontsize = 25)

plt.xticks([r + barWidth for r in range(len(mBERT))])
ax.set_xticklabels(groups, fontsize = 25, fontweight ='bold')


# ax.set_xticks([r + barWidth for r in range(len(mBERT))],
# 		['Further-Pretrained with Quran Corpus', 'Not Further-Pretrained with Quran Corpus'], fontsize = 15)
# ax.set_xlabel('Groups')
ax.set_ylabel('Exact Match', fontweight ='bold', fontsize = 30)
# ax.legend()
ax.legend(loc='lower right',fontsize="30")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.14

data = np.array([[69.47, 69.93, 70.91], [69.01, 71.29, 73], [69.45, 71.33, 73.75], [65.74, 66.65, 69.92]])

mBERT = [69.47, 69.93, 70.91]
ParsBERT = [69.01, 71.29, 73]
XLM_RoBERTa = [69.45, 71.33, 73.75]
ALBERT_Persian = [65.74, 66.65, 69.92]

labels = ['mBERT', 'ParsBERT', 'XLM_RoBERTa', 'ALBERT_Persian']
groups = ['Not Further-Pretrained with Quran Corpus',
          'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset']

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

fig, ax = plt.subplots(figsize =(40, 15))

# Make the plot
ax.bar(br1, mBERT, color ='#F7DC6F', width = barWidth,
		edgecolor ='grey', label ='mBERT')
ax.bar(br2, ParsBERT, color ='#728FCE', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF733B', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#498F4C', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

for c in ax.containers:
    # annotate the container group
    ax.bar_label(c, label_type='edge', fontsize = 25)

plt.xticks([r + barWidth for r in range(len(mBERT))])
ax.set_xticklabels(groups, fontsize = 25, fontweight ='bold')


# ax.set_xticks([r + barWidth for r in range(len(mBERT))],
# 		['Further-Pretrained with Quran Corpus', 'Not Further-Pretrained with Quran Corpus'], fontsize = 15)
# ax.set_xlabel('Groups')
ax.set_ylabel('F1', fontweight ='bold', fontsize = 30)
# ax.legend()
ax.legend(loc='lower right',fontsize="30")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# import seaborn
# seaborn.set()

data = np.array([[59.56, 60.52, 62.2], [59.5, 61.72, 64.59], [61.48, 63.15, 66.02], [56.69, 57.17, 60.76]])

# set width of bar
barWidth = 0.14

# set height of bar
mBERT = [59.56, 60.52, 62.2]
ParsBERT = [59.5, 61.72, 64.59]
XLM_RoBERTa = [61.48, 63.15, 66.02]
ALBERT_Persian = [56.69, 57.17, 60.76]

labels = ['mBERT', 'ParsBERT', 'XLM_RoBERTa', 'ALBERT_Persian']
groups = ['Not Further-Pretrained with Quran Corpus',
          'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset']

# Set position of bar on X axis
br1 = np.arange(len(mBERT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# fig, ax = plt.subplots(layout='constrained', figsize =(30, 5))
fig, ax = plt.subplots(figsize =(35.5, 12))
# Make the plot
ax.bar(br1, mBERT, color ='#E3CF57', width = barWidth,
		edgecolor ='grey', label ='mBERT')
ax.bar(br2, ParsBERT, color ='#6495ED', width = barWidth,
		edgecolor ='grey', label ='ParsBERT')
plt.bar(br3, XLM_RoBERTa, color ='#FF4500', width = barWidth,
		edgecolor ='grey', label ='XLM-RoBERTa')
plt.bar(br4, ALBERT_Persian, color ='#698B22', width = barWidth,
		edgecolor ='grey', label ='ALBERT-Persian')

# for i, j in enumerate(data):
#    for x_val, y_val in zip(x, j):
#       ax.annotate(str(y_val), xy=(x_val+i*width-width/2, y_val), ha='center', va='bottom')

for c in ax.containers:
    # annotate the container group
    ax.bar_label(c, label_type='edge', fontsize = 15)

# ax.set_ylabel('Exact Match', fontweight ='bold', fontsize = 15)
# ax.set_xlabel([r + barWidth for r in range(len(mBERT))],
		# ['Not Further-Pretrained with Quran Corpus', 'Further-Pretrained with Quran Corpus', 'Pipeline Fine-Tuend with PQuAD and Our Dataset'], fontsize = 15)

# x = np.arange(len(groups))

# ax.set_xticks(x)

plt.xticks([r + barWidth for r in range(len(mBERT))])
ax.set_xticklabels(groups, fontsize = 20)


# ax.set_xticks([r + barWidth for r in range(len(mBERT))],
# 		['Further-Pretrained with Quran Corpus', 'Not Further-Pretrained with Quran Corpus'], fontsize = 15)
# ax.set_xlabel('Groups')
ax.set_ylabel('Exact Match', fontweight ='bold', fontsize = 15)
ax.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

with open('/content/drive/MyDrive/temp_v3.jsonl', 'r') as f:
  dict_data_list = []
  for line in f:
   data = json.loads(line)
   dict_data_list.append(data)

# %%
from statistics import mean

questions_lengths = [len(q.split(' ')) for q in all_data['question'].tolist()]

min_q = min(questions_lengths)

mean_q = mean(questions_lengths)

mean_q
# Out:
# 9.372605363984674

# %%
from statistics import mean

questions_lengths = [len(q) for q in all_data['question'].tolist()]

min_q = min(questions_lengths)

mean_q = mean(questions_lengths)

mean_q
# Out:
# 45.85344827586207

# %%
a = 'kkkkkkkk'
len(a)
# Out:
# 8

# %%
import seaborn as sns
from random import shuffle
import pandas as pd

shuffle(dict_data_list)

all_data = pd.DataFrame(dict_data_list)


axs =sns.histplot([len(q.split(' ')) for q in all_data['question'].tolist()])
axs.set(title ='histogram of question length' ,xlabel = 'question length', ylabel='count')
axs.plot()
# Out:
# []

# %%
axs =sns.histplot([len(p.split(' ')) for p in all_data['context'].tolist()])
axs.set(title ='histogram of passage length' ,xlabel = 'passage length', ylabel='count')
axs.plot()
# Out:
# []

# %%
Counter(" ".join(all_data["context"]).split()).most_common(20)
# Out:
# [('و', 19863),
#  ('را', 9959),
#  ('که', 9810),
#  ('از', 8176),
#  ('به', 6987),
#  ('در', 5310),
#  ('آنها', 3728),
#  ('آن', 3414),
#  ('او', 3140),
#  ('شما', 2696),
#  ('بر', 2600),
#  ('برای', 2382),
#  ('خدا', 2320),
#  ('این', 2198),
#  ('ما', 2085),
#  ('خداوند', 1968),
#  ('است', 1813),
#  ('با', 1687),
#  ('تو', 1592),
#  ('آنان', 1557)]

# %%
from collections import Counter
import plotly.express as px

Counter(" ".join(all_data["context"]).split()).most_common(200)
labels, values = zip(*Counter(" ".join(all_data["context"]).split()).most_common(30))

fig = px.bar( x=labels, y=values)
fig.update_layout(
    title ='word frequency',
    xaxis_title='word',
    yaxis_title='count'
)
fig.show()

# %%
marks = ['مکان' ,'محل' ,'جایگاه' ,'چه جایی' ,'چه مکانی','کجا']

location_questions = []

for each in dict_data_list:
  constraint = any(ele in each['question'] for ele in marks)
  if constraint:
    location_questions.append(each)

# %%
len(location_questions)
# Out:
# 25

# %%
marks = ['نام فرزند' ,'نام پدر' ,'مادر' ,'چه گروهی' ,'کدام گروه' ,'کدام افراد' ,'چه افرادی' ,'چه کسانی' ,'چه کسی','کدام پیامبر']

people_questions = []

for each in dict_data_list:
  constraint = any(ele in each['question'] for ele in marks)
  if constraint:
    people_questions.append(each)

# %%
len(people_questions)
# Out:
# 733

# %%
marks = ['واقعه' ,'چه روز' ,'کدام روز' ,'چه زمانی' ,'وقت' ,'وقت' ,'موقع' ,'زمان' ,'چه هنگامی']

event_questions = []

for each in dict_data_list:
  constraint = any(ele in each['question'] for ele in marks)
  if constraint:
    event_questions.append(each)

# %%
len(event_questions)
# Out:
# 78

# %%
marks = ['مقدار' ,'تعداد' ,'چند' ,'چه مدت']

number_questions = []

for each in dict_data_list:
  constraint = any(ele in each['question'] for ele in marks)
  if constraint:
    number_questions.append(each)

# %%
len(number_questions)
# Out:
# 103

# %%
marks = ['صفت' ,'صفات']

adjective_questions = []

for each in dict_data_list:
  constraint = any(ele in each['question'] for ele in marks)
  if constraint:
    adjective_questions.append(each)

# %%
len(adjective_questions)
# Out:
# 104

# %%
phrase_questions = []

for each in dict_data_list:
  # print(each['answers'])
  # break
  if len(each['answers'][0]['text'])> 15:
    print(each['answers'][0]['text'])
    phrase_questions.append(each)
# Out:
# طوفان و ملخ و آفت گیاهی و قورباغه‌ها و خون
# هنگامی که در میان آنها، پیامبری از خودشان برانگیخت
# کسانی که روزه برای آنها طاقت‌فرساست
# کسی که خداوند رحمان به او اجازه داده، و به گفتار او راضی است
# آنها که تقوای الهی پیشه کردند
# جز برای اینکه عبادتم کنند
# انگور و سبزی بسیار، و زیتون و نخل فراوان، و باغهای پردرخت، و میوه و چراگاه
# آنچه در اختیارتان قرار داده
# کافران و منافقان
# مصایبی که به تو می‌رسد
# سرمایه وجود خویش و بستگانشان
# به آنها که در راه خدا کشته می‌شوند، مرده نگویید! بلکه آنان زنده‌اند
# گِل خشکیده‌ای که از گِل بد بوی گرفته شده بود
# آنها هستند که از او پیروی کردند
# پیشگامان پیشگامند
# هر کس را خدا گمراه نماید
# کسانی که آیین خود را پراکنده ساختند، و به دسته‌های گوناگون تقسیم شدند
# اگر آنها از آن خارج شوند
# هر کس به خدا ایمان آورد
# کسانی که در قیامت تردید می‌کنند
# ما انسان را از عصاره‌ای از گِل آفریدیم؛ سپس او را نطفه‌ای در قرارگاه مطمئن قرار دادیم؛ سپس نطفه را بصورت علقه، و علقه را بصورت مضغه، و مضغه را بصورت استخوانهایی درآوردیم؛ و بر استخوانها گوشت پوشاندیم؛ سپس آن را آفرینش تازه‌ای دادیم
# خداوند توانای حکیم
# در زمین فساد می‌کردند و اصلاح نمی‌کردند
# رشته شکاف هسته خرمایی
# زنان مشرک و بت‌پرست
# چیزی را شریک خدا قرار ندهند، دزدی و زنا نکنند، فرزندان خود را نکشند، تهمت و افترایی پیش دست و پای خود نیاورند و در هیچ کار شایسته‌ای مخالفت فرمان تو نکنند
# گناه و ستم بناحق
# آنها که از آتش دور شده، و به بهشت وارد شوند
# خدا، و روز رستاخیز، و فرشتگان، و کتاب، و پیامبران
# خدا را فراوان یاد کنید
# بر کسانی است که آن را تغییر می‌دهند
# پروردگارم مرا گرامی داشته است
# گوشت برادر مرده خود
# ترک جهاد با اموال و جانهایشان
# کسی که از مقام پروردگارش بترسد
# آنچه در آسمانها و آنچه در زمین است
# برای نیازمندانی باشد که در راه خدا، در تنگنا قرار گرفته‌اند
# گروه بسیاری از جن و انس
# آنان زنده‌اند، و نزد پروردگارشان روزی داده می‌شوند
# کسانی که به خدا و رسولانش ایمان آورده‌اند
# تا هنگام توانایی
# آنچه بعنوان ربا می‌پردازید تا در اموال مردم فزونی یابد
# هنگامی که با گروهی رو به رو می‌شوید
# به پشت سر خود بازگردید و کسب نور کنید
# ماجرای زنانی که دستهای خود را بریدند
# فرعون و هامان و قارون
# منافقان و کافران
# اموال و جانهایتان
# آمرزنده و بخشنده
# دشمن من و دشمن خودتان
# تمام آنچه روی زمین است و همانند آن
# کتابهای پیشینیان
# بعد از این سه وقت
# کسانی که کتاب به آنها داده‌ایم
# سوگند به ستارگانی که بازمی‌گردند، حرکت می‌کنند و از دیده‌ها پنهان می‌شوند، و قسم به شب، هنگامی که پشت کند و به آخر رسد، و به صبح، هنگامی که تنفّس کند
# آمرزنده و مهربان
# در راه خدا پیکار کن
# اعدام شوند؛ یا به دار آویخته گردند؛ یا دست و پای آنها، بعکس یکدیگر، بریده شود؛ و یا از سرزمین خود تبعید گردند
# هر کسی را که شکر کند
# آنچه را غیر از او می‌خوانند
# مانند درازگوشی هستند که کتابهایی حمل می‌کند
# بارانهای پربرکت آسمان
# کسانی که کافر شدند و در حال کفر از دنیا رفتند
# تو و هر کدام از آنان که از تو پیروی کند
# کسی را که متکبر و فخر فروش است
# مرکبی از الواح و میخهایی ساخته شده
# گناهی بر شما نیست که وارد خانه‌های غیر مسکونی بشوید که در آن متاعی متعلّق به شما وجود دارد
# متخلّفان از اعراب بادیه‌نشین
# بشارت دهنده و انذار کننده
# روزی که شرّ و عذابش گسترده است
# گروه بسیاری از جن و انس
# نعمت خدا و فضل او
# سلاحها و متاعهای خود
# اموال و جانهایشان
# هر کس، شیطان را به جای خدا ولّیِ خود برگزیند
# خداوند و فرشتگان و همه مردم
# و فرشتگانی که روح مؤمنان را با مدارا و نشاط جدا می‌سازند، و سوگند به فرشتگانی که با سرعت حرکت می‌کنند، و سپس بر یکدیگر سبقت می‌گیرند، و آنها که امور را تدبیر می‌کنند!
# امروز روز سخت و دردناکی است
# تا زمانی که مرگ ما فرا رسید
# آن کس را که دروغگو و کفران‌کننده است
# کسانی که ایمان می‌آورند
# ای قوم! به سرزمین مقدّسی که خداوند برای شما مقرّر داشته، وارد شوید! و به پشت سر خود بازنگردید که زیانکار خواهید بود
# آنها که گفتند: «خداوند همان مسیح بن مریم است»
# به خدا مطلبی نسبت دهید که نمی‌دانید
# آن که بار ستمی بر دوش دارد
# توبه‌پذیر و مهربان
# آمرزش و پاداشی پرارزش
# کسی که توبه کند و عمل صالح انجام دهد
# هر حیوان ناخن‌دار
# وقتی برای خود پیمانه می‌کنند
# خدا، و روز رستاخیز، و فرشتگان، و کتاب و پیامبران
# و خداوند شما را همچون گیاهی از زمین رویانید، سپس شما را به همان زمین بازمی‌گرداند، و بار دیگر شما را خارج می‌سازد
# همسرانی را که پروردگارتان برای شما آفریده است
# آنها عذاب عظیمی دارند
# زمین لرزه آنها را فرا گرفت
# آنچه به شما وعده داده می‌شود
# هیچ یک از کافران
# هنگامی که سفر می‌کنید
# كسي كه روح خود را تسليم خدا كند در حالي كه نيكوكار باشد
# کسی که شفاعت به کار نیکی کند
# کسی که در آستانه مرگ قرار گرفته
# کسانی که ایمان دارند
# آنها که توبه نکنند
# من و پدر و مادرم و همه مؤمنان
# و ما در هیچ شهر و آبادی پیامبری نفرستادیم مگر اینکه اهل آن را به ناراحتیها و خسارتها گرفتار ساختیم؛ شاید بازگردند و تضرع کنند
# هرگاه نام خدا برده شود
# اموال و جانهایتان
# هرگاه در چیزی نزاع داشتید
# از شرّ شیطان مطرود، به خدا پناه بر
# کسانی که ایمان دارند و بر پروردگارشان توکّل می‌کنند
# کسانی که سرمایه وجود خود را از دست داده‌اند
# ای قوم من! خدا را پرستش کنید، که جز او، معبود دیگری برای شما نیست! پیمانه و وزن را کم نکنید
# گاوی باشد زرد یکدست، که رنگ آن، بینندگان را شاد و مسرور سازد
# هنگامی که دعوت شدید
# تندباد وحشتناک و سردی
# آنها که نزد پروردگار تو هستند
# مجادله و القای شکّ
# مجاهدانی را که با مال و جان خود جهاد نمودند
# آنچه شما را جانشین و نماینده در آن قرار داده
# تندبادی بی‌باران
# سه مرتبه عادت ماهانه دیدن
# پیامبر و کسانی که با او ایمان آوردند
# بهشت و لباسهای حریر بهشتی
# آن کس که از خداوند رحمان در نهان بترسد و با قلبی پرانابه در محضر او حاضر شود
# آنچه به آنان روزی داده‌ایم
# آنها که کافر شدند
# عهد خود به هنگامی که عهد بستند
# از پروردگارتان بخواهید یک روز عذاب را از ما بردارد
# پدر و مادر و نزدیکان و یتیمان و بینوایان
# بارانی از سنگ متراکم بر روی هم، بر آنها نازل نمودیم
# در حالی که مردمش ستمگر بودند
# عدل و احسان و بخشش به نزدیکان
# فرعون و درباریان او
# چنانچه از مخالفت باز ایستند
# همگی بخاطر گناهانشان غرق شدند و در آتش دوزخ وارد گشتند
# منافقان و بیماردلان
# کلام پروردگار تو
# آن کس که بر خدا دروغ بسته، و یا آیات او را تکذیب کرده است
# اعمالی که انجام می‌دادند
# آنچه را پیش از آن آمده
# طوفان و ملخ و آفت گیاهی و قورباغه‌ها و خون
# شعله‌های مختلط و متحرّک آتش
# فرعون و اطرافیان او
# پیامبر و کسانی را که با او ایمان آوردند
# جانها و اموالشان
# دو نوجوان یتیم در آن شهر
# کسانی که در راه خدا هجرت کردند، سپس کشته شدند یا به مرگ طبیعی از دنیا رفتند
# از آنچه به آنها روزی داده‌ایم
# کسانی که ایمان آورده، و کارهای شایسته انجام داده‌اند
# مرد دزد و زن دزد
# هرگاه انفاق کنند
# کسانی را که ستم کرده بودند
# رأفت نسبت به آن دو
# همسرانی از جنس خودتان
# حزب و جمعیّت خدا
# کسانی که پیش از آن به آنها دانش داده شده
# افراد کر و لالی هستند که اندیشه نمی‌کنند
# زمین لرزه آنها را فرا گرفت
# هیچ کار شایسته‌ای
# هر کس از شما برای خدا و پیامبرش خضوع کند و عمل صالح انجام دهد
# آنها که خوشبخت و سعادتمند شدند
# محرومیتها و بیماریها و در میدان جنگ
# آنچه را از سوی پروردگارت بر تو نازل شده
# تندبادی که ریگها را به حرکت درمی‌آورد
# اهل کتاب و مؤمنان
# پسران شما را سر می‌بریدند؛ و زنان شما را زنده نگه می‌داشتند
# گناه و تعدّی و نافرمانی رسول
# اجبار آنها به هدایت
# نیکوکار و مهربان
# کسانی که ایمان آورده و کسانی که هجرت کرده و در راه خدا جهاد نموده‌اند
# چنگال عذاب الهی در زمین
# هنگامی که با کافران در میدان جنگ روبه‌رو شدید
# آن کس که نفس خویش را با معصیت و گناه آلوده ساخته
# بهترین دستورهائی که از سوی پروردگارتان بر شما نازل شده
# باید پیش از آمیزش جنسی با هم، برده‌ای را آزاد کنند؛ این دستوری است که به آن اندرز داده می‌شوید؛ و خداوند به آنچه انجام می‌دهید آگاه است! و کسی که توانایی نداشته باشد، دو ماه پیاپی قبل از آمیزش روزه بگیرد؛ و کسی که این را هم نتواند، شصت مسکین را اطعام کند
# مردان منافق و زنان منافق
# کور مادرزاد، و مبتلا به بیماری پیسی
# زنانی را که متعه می‌کنید
# گمراهی کسانی که گمراه شده‌اند
# نعمتهای فراوانی که خداوند از فضل خود به ایشان بخشیده است
# چیزی را که خداوند دلیلی برای آن نازل نکرده، شریک او قرار دهید
# آن کس که بر خدا دروغ ببندد
# پیشگامان نخستین از مهاجرین و انصار، و کسانی که به نیکی از آنها پیروی کردند
# کسانی که پس از آن کافر شوند
# این شما نبودید که آنها را کشتید؛ بلکه خداوند آنها را کشت
# این جمعیّت گنهکار
# آنان که بر صورتهایشان بسوی جهنم محشور می‌شوند
# توبه پذیر و مهربان
# سوگند به وجدان بیدار و ملامتگر
# انسانی را که خداوند محترم شمرده
# کسانی را که از آیات ما روی می‌گردانند
# هر کس خدا و رسولش را اطاعت نماید
# هر کس به دعوت کننده الهی پاسخ نگوید
# آنچه را از پیش فرستاده‌اند و تمام آثار آنها
# به لانه‌های خود بروید تا سلیمان و لشکرش شما را پایمال نکنند در حالی که نمی‌فهمند
# مجادله و القای شکّ
# کسی که پرهیزگار باشد
# نوح به پروردگارش عرض کرد: «پروردگارا! پسرم از خاندان من است
# مخالفت با رسول خدا
# کسانی که کافر شدند، و آیات ما را دروغ پنداشتند
# پدر و مادر و نزدیکان و یتیمان و مستمندان و درماندگان در راه
# محبّت امور مادی، از زنان و فرزندان و اموال هنگفت از طلا و نقره و اسبهای ممتاز و چهارپایان و زراعت
# حکیم و شایسته ستایش
# عذاب خوارکننده‌ای
# نابینا و لنگ و بیمار
# عدل و احسان و بخشش به نزدیکان
# سوگند به «بیت المعمور»، و سقف برافراشته، و دریای مملوّ و برافروخته
# ما آنها را پرستش نمی‌کردیم
# با رسالتهای خویش و با سخن‌گفتنم
# ظلم و دروغ بزرگی
# منزّه و بلندمقام
# چنین نیست! یقیناً پروردگارم با من است، بزودی مرا هدایت خواهد کرد
# پدران و فرزندان و برادران و فرزندان برادران و فرزندان خواهران خود و زنان مسلمان و بردگان خویش
# کسانی که در روز روبرو شدن دو جمعیت با یکدیگر، فرار کردند
# کسانی که ایمان آوردند
# پروردگار عالمیان
# نهی‌کنندگان از بدی
# کافران و منافقان
# کسی را که به سوی او بازگردد
# آنها که با خدا و پیامبرش به جنگ برمی‌خیزند، و اقدام به فساد در روی زمین می‌کنند
# کسانی را که غیر از او می‌خوانند
# هزار سال مگر پنجاه سال
# آنها که توانایی رفتن به سوی آن دارند
# گشایش‌دهنده و آگاه
# هر کس به دعوت کننده الهی پاسخ نگوید
# در غیاب پیامبر، سخنان نادرست نگفته‌اند
# کسانی که ایمان آورده و کارهای شایسته انجام دادند
# شما تنها از مردی مجنون پیروی می‌کنید
# این عصای من است؛ بر آن تکیه می‌کنم، برگ درختان را با آن برای گوسفندانم فرومی‌ریزم؛ و مرا با آن کارها و نیازهای دیگری است
# آنها که با خدا و پیامبرش به جنگ برمی‌خیزند، و اقدام به فساد در روی زمین می‌کنند
# آنها که گفتند: «خدا، همان مسیح بن مریم است»
# اگر پیمانهای خود را پس از عهد خویش بشکنند، و آیین شما را مورد طعن قرار دهند
# ابراهیم و اسماعیل
# جمعیّتی که می‌اندیشند
# آنها که رسول خدا را آزار می‌دهند
# کسی که انکار کند آنچه را باید به آن ایمان بیاورد
# انسانی را که خداوند خونش را حرام شمرده
# از راه کسانی پیروی کن که توبه‌کنان به سوی من آمده‌اند
# کسانی که می‌اندیشند
# بشارت‌دهنده و بیم‌دهنده
# بر سر راه مستقیم تو
# پروردگارا! اموالشان را نابود کن! و دلهایشان را سخت و سنگین ساز، به گونه‌ای که ایمان نیاورند تا عذاب دردناک را ببینند
# هفت شب و هشت روز
# آنها که نقشه‌های بد می‌کشند
# خویشاوندان و یتیمان و مسکینان و واماندگان در راه و سائلان و بردگان
# آنها که ایمان بیاورند و اصلاح کنند
# زبانها و دستها و پاهایشان
# کسانی که به ایشان علم داده شده
# تورات و انجیلی که نزدشان است
# هنگامی که بر زمین افتاد
# شاید متذکّر شود، یا بترسد
# عصاره‌ای از آب ناچیز و بی‌قدر
# آمرزنده و مهربان
# مردان منافق و زنان منافق
# خدا و پاداش و کیفر او
# ای مالک دوزخ! ای کاش پروردگارت ما را بمیراند
# کورِ مادرزاد و مبتلایان به برص
# آمرزنده و مهربان
# کسانی که گفتند: «پروردگار ما اللّه است»، سپس استقامت کردند
# نیکی‌ها و اعمال خیر
# آمرزنده و بردبار
# قسم به پدر و فرزندش
# زمانی را که چشمها از شدّت وحشت خیره شده و جانها به لب رسیده بود
# خورشید و ماه و ستارگان و کوه‌ها و درختان و جنبندگان، و بسیاری از مردم
# کسانی که کافر شدند و آیات ما را تکذیب کردند
# هر کس خدا و پیامبرش را اطاعت کند، و از خدا بترسد و از مخالفت فرمانش بپرهیزد
# هنگامی که آیات او بر آنها خوانده می‌شود،
# که هرگز استخوانهای او را جمع نخواهیم کرد
# ظرف آبخوری پادشاه
# نظری به ما بیفکنید تا از نور شما پرتوی برگیریم
# اموال و جانهایتان
# فرعون و اطرافیان اشرافی او
# آنها که دعوت پروردگارشان را اجابت کردند
# آمرزنده و سپاسگزار
# هر کس تقوای الهی پیشه کند
# بارانهای پی‌درپی
# باغهای سرسبز و نهرهای جاری
# بارانی از سنگ بر سر آنها باراندیم
# گِل خشکیده‌ای همچون سفال
# نماز و عبادت شبانه
# پایین‌ترین درکات
# تمام آنچه آنها جمع آوری میکنند
# آمرزنده و مهربان
# صیحه آسمانی آنها را بحق فرو گرفت
# آنها را بخاطر گناهانشان در هم کوبید و با خاک یکسان و صاف کرد
# آنها که ایمان آوردند
# با کسانی است که تقوا پیشه کرده‌اند، و کسانی که نیکوکارند
# بهشت که اوصاف آن را برای آنان بازگو کرده
# شادی و غفلت و فخرفروشی
# آنها که به احکامی که خدا نازل کرده حکم نمی‌کنند
# کسانی که از عبادت طاغوت پرهیز کردند و به سوی خداوند بازگشتند
# کسی که سخن راست بیاورد و کسی که آن را تصدیق کند
# شما گروه ناشناسی هستید
# ذکر خدا و آنچه از حقّ نازل کرده است
# با اهل کتاب جز به روشی که از همه نیکوتر است مجادله نکنید، مگر کسانی از آنان که ستم کردند
# فحشا و منکر و ستم
# گروهی که ایمان می‌آورند
# آن کس که پس از ستم کردن، توبه و جبران نماید
# پروردگارا! زندان نزد من محبوبتر است از آنچه اینها مرا بسوی آن می‌خوانند! و اگر مکر و نیرنگ آنها را از من باز نگردانی، بسوی آنان متمایل خواهم شد و از جاهلان خواهم بود
# افراد سفیه و نادان
# تمام وسایل دروغین آنها
# وسیله‌ای جهت جدا ساختن حق از باطل
# مردان و زنان باایمان
# بهترین و زیباترین پارچه‌های سبزرنگ
# آمرزنده و مهربان
# گاوی باشد که نه برای شخم زدن رام شده؛ و نه برای زراعت آبکشی کند؛ از هر عیبی برکنار باشد، و حتی هیچ‌گونه رنگ دیگری در آن نباشد
# کسانی که به آخرت ایمان ندارند
# آنچه در آن اختلاف داشتید
# هر کس گمراهی را برگزیند
# فضل الهی و رضای او
# هرگاه نیکی به تو رسد
# که گرگ او را بخورد
# فرستاده بزرگواری
# کافران بنی اسرائیل
# کسانی که کافر شدند، و آیات ما را دروغ پنداشتند
# برنمی‌خیزند مگر مانند کسی که بر اثر تماسّ شیطان، دیوانه شده
# مردار، خون، گوشت خوک و آنچه را نام غیرِ خدا به هنگام ذبح بر آن گفته شود
# کسانی هستند که به خدا و رسولش ایمان آورده‌اند و هنگامی که در کار مهمّی با او باشند، بی‌اجازه او جایی نمی‌روند
# آنان که کتاب آسمانی به ایشان داده‌ایم
# کسانی که به خدا و رسولان او ایمان آورده، و میان احدی از آنها فرق نمی‌گذارند
# هر کس، انسانی را از مرگ رهایی بخشد
# تنه‌های نخل ریشه‌کن شده
# قسم به روز هنگامی که تجلّی کند، و قسم به آن کس که جنس مذکّر و مؤنّث را آفرید
# بخشی از چیزهای پاکیزه را که بر آنها حلال بود
# منزّه است خدا! این بشر نیست؛ این یک فرشته بزرگوار است
# نعمتهای آشکار و پنهان خود
# نیکی، این نیست که رویِ خود را به سوی مشرق و مغرب کنید
# اژدهایی شد که به هر سو می‌شتافت
# کسانی را که ایمان آورده و کارهای شایسته انجام داده‌اند
# هنگامی که بلا بر آنها مسلط می‌شد
# پدر و مادر و نزدیکان
# آنها که آیات ما را تکذیب کردند
# آنچه در آسمانها و آنچه در زمین است
# هیچ گونه علم و یقین
# کسانی که آیات ما را تکذیب کردند
# آمرزنده و مهربان
# آنچه در آسمانها و آنچه در زمین است
# چگونه جسد برادر خود را دفن کند
# پروردگار جهانیان
# هر کس، شیطان را به جای خدا ولّیِ خود برگزیند
# کتاب آشکار کننده‌ای
# بارهای سنگین، و زنجیرهایی را که بر آنها بود
# مشکلات از من برطرف شد، و دیگر باز نخواهد گشت
# صیحه آسمانی فروگرفت
# آنچه را نمی‌دانستید
# راه خداوند عزیز و حمید
# کسانی که توبه کنند و ایمان آورند و عمل صالح انجام دهند
# آمرزش و رحمت خدا
# آسمانها و زمین و آنچه را در میان این دو است
# شب قدر بهتر از هزار ماه است! فرشتگان و «روح» در آن شب به اذن پروردگارشان برای هر کاری نازل می‌شوند. شبی است سرشار از سلامت تا طلوع سپیده!
# برای این است که درهای خیرات را با شتاب به روی آنها بگشاییم
# باغهایی از بهشت که نهرها زیر آن جاری است
# طرف راست کوه طور
# بارانی از سنگ بر آنها فرستادیم
# کسی را که به سوی او بازگردد
# آنها که به خدا دروغ می‌بندند
# آن برادری را که از پدر دارید
# آنان که قلبهایی سخت در برابر ذکر خدا دارند
# آمرزنده و مهربان
# ابراهیم و اسماعیل و اسحاق و یعقوب و اسباط
# سعادتمندان و خجستگان
# کسانی را که تقوا پیشه کردند
# کوه‌ها و پرندگان
# به کسانی که ایمان آورده، و کارهای شایسته انجام داده‌اند
# اموال و جانهایشان
# کسی که ایمان آورد و عمل صالح انجام دهد
# اموال و خانواده‌های ما
# آنان هرگز مالک شفاعت نیستند؛ مگر کسی که نزد خداوند رحمان، عهد و پیمانی دارد
# کسانی که قلبشان را از یاد خود غافل ساختیم
# تا از آیین آنان، پیروی کنی
# اسبان چابک تندرو
# برخی از ساعات شب و اطراف روز
# کسی که خدا و پیامبر را اطاعت کند
# بدبخت‌ترین افراد
# آمرزشی است از سوی پروردگارشان
# یک روز شوم مستمر
# کشتی را سوراخ کرد
# آن کس که نافرمانی خدا و پیامبرش را کند و از مرزهای او تجاوز نماید
# کسانی را که ایمان آوردند و پرهیزگار بودند
# آنها را از رحمت خویش دور ساختیم؛ و دلهای آنان را سخت و سنگین نمودیم
# کسانی که بعد از آنها وارثان کتاب شدند
# با کافران و منافقان جهاد کن، و بر آنها سخت بگیر
# آسمانها و زمین و آنچه را میان این دو است
# فتنه و فساد عظیمی
# کسانی از آنها، که نیکی کردند و تقوا پیش گرفتند
# کوه‌ها و درختان و داربستهایی که مردم می‌سازند
# غم و اندوه‌های دوزخ
# پروردگارم مرا خوار کرده است
# هیچ انسانِ ناسپاسِ گنهکاری
# آنها که بعد از این به خدا دروغ می‌بندند
# آنچه را بر تو وحی شده
# همانند عمل کسی قرار دادید که به خدا و روز قیامت ایمان آورده، و در راه او جهاد کرده است
# پذیرش توبه از سوی خدا، تنها برای کسانی است که کار بدی را از روی جهالت انجام می‌دهند، سپس زود توبه می‌کنند
# سرزمین مقدّسی که خداوند برای شما مقرّر داشته
# کسانی که ادّعای نصرانیّت داشتند
# کسانی که روزه برای آنها طاقت‌فرساست
# عدل و احسان و بخشش به نزدیکان
# باغهایی از بهشت، که نهرها از زیر درختانش جاری است
# دانشی که نزد من است
# عربهای بادیه‌نشین
# در برابر آنچه می‌گویند
# آنها که ایمان آوردند، و ایمان خود را با شرک و ستم نیالودند
# نور و کتاب آشکاری
# اموال و جانهای خود
# افرادی که قبلاً ایمان نیاورده‌اند، یا در ایمانشان عمل نیکی انجام نداده‌اند
# اگر آیین خدا را یاری کنید
# آنچه را موجب خشنودی اوست
# هر کس را خدا هدایت کند
# زنان از کارافتاده‌ای که امید به ازدواج ندارند
# چهار ماه و ده روز
# فرعون و اطرافیانش
# این تمتع و بهره‌گیری از دنیا
# این است که بار خود را بر زمین بگذارند
# بسیاری از گمانها
# تندبادی طغیانگر و سرد و پرصدا
# آنچه را از کتاب پروردگارت به تو وحی شده
# آمرزنده و مهربان
# سرمایه زندگی پست
# نشانه تو آن است که سه روز، جز به اشاره و رمز، با مردم سخن نخواهی گفت
# آمرزنده و مهربان
# کسانی را که ایمان آورده بودند
# افرادی که قبلاً ایمان نیاورده‌اند، یا در ایمانشان عمل نیکی انجام نداده‌اند
# بشارت‌دهنده و بیم‌دهنده
# آمرزنده و مهربان
# آنچه دلهای شما کسب کرده
# کسی او را گرامی نخواهد داشت
# آسمانهای هفتگانه و زمین و کسانی که در آنها هستند
# جمعی از کافران آنها
# بوزینه‌هایی طردشده
# آنها که بدبخت شدند
# مجازاتِ او دوزخ است
# آنچه در آسمانها و زمین است
# خدا و رسول و خویشاوندان او، و یتیمان و مستمندان و در راه ماندگان
# نزدیکان و مستمندان و مهاجران در راه خدا
# اسرار آسمانها و زمین
# نسبتهای ناروای شما
# آنها که در راه ما جهاد کنند
# پیش از نماز صبح، و نیمروز هنگامی که لباسهای معمولی خود را بیرون می‌آورید، و بعد از نماز عشا
# کسانی را که ایمان آورده و کارهای شایسته انجام داده‌اند
# کسانی که زندگی دنیا را به آخرت فروخته‌اند
# هر دروغگوی گنهکار
# چهار ماه و ده روز
# تندبادی که ریگها را به حرکت درمی‌آورد
# تقوا و پرهیزگاری شما
# مردان و زنان باایمان
# پیش از روز قیامت
# کسانی که به آخرت ایمان ندارند
# همه چیز جز ذات او
# مردان و زنان منافق
# نماز و عبادت شبانه
# توانگری و تنگدستی
# ترس، گرسنگی، و کاهش در مالها و جانها و میوه‌ها
# تسبیح و حمد پروردگارشان
# در حالی که شما مردگان بودید
# پدر و مادر و نزدیکان
# کسانی که آیات ما را تکذیب کردند، و در برابر آن تکبّر ورزیدند
# کسانی را که با موسی ایمان آورده‌اند
# مردان و زنان باایمان
# کسانی که ایمان آوردند
# آدم و نوح و آل ابراهیم و آل عمران
# مردان و زنان باایمان
# چیزی از ترس، گرسنگی، و کاهش در مالها و جانها و میوه‌ها
# کسانی که کتاب آسمانی به آنان داده‌ایم
# آنها که در راه خدا کشته می‌شوند
# هر کس، فرد باایمانی را از روی عمد به قتل برساند
# همانجا که مأمور هستید
# هزار سال مگر پنجاه سال
# از روی شهوت به سراغ مردان می‌روید، نه زنان
# کسانی که در راه خدا کشته شدند
# کسانی که ولایت خدا و پیامبر او و افراد باایمان را بپذیرند
# کسانی که ایمان آورده‌اند و عمل صالح انجام می‌دهند
# کسی که توانایی آزاد کردن برده‌ای نداشته باشد
# آنچه در آسمانها و زمین است
# تمام نعمتها و مواهبی که به آنان روزی داده‌ایم
# اخبار دروغ و شایعات بی‌اساس
# آنچه بر تو نازل شده، و آنچه پیش از تو نازل گردیده
# سوگندهایی که بدون توجه یاد می‌کنید
# بهتان و گناه آشکاری
# آمرزنده و بردبار
# هر کس را خداوند گمراه سازد
# سوگند به آن روز موعود، و سوگند به «شاهد» و «مشهود»
# هنگامی که می‌خواهید با رسول خدا نجوا کنید
# آن کس که بر خدا دروغ بسته در حالی که دعوت به اسلام می‌شود
# بلندمرتبه و بزرگ
# آن کس که انفاق کند و پرهیزگاری پیش گیرد، و جزای نیک را تصدیق کند
# مردان و زنان باایمان
# شکر نعمتهایی را که بر من و پدر و مادرم ارزانی داشته‌ای
# کسانی که کافر شدند و از راه خدا بازداشتند
# مزد آب دادن به گوسفندان
# کسانی که کافر شدند
# کسانی که اموال یتیمان را به ظلم و ستم می‌خورند
# کسانی را که غیر از او می‌خوانند
# کافران و منافقان
# آنان که وقتی برای خود پیمانه می‌کنند، حق خود را بطور کامل می‌گیرند؛ امّا هنگامی که می‌خواهند برای دیگران پیمانه یا وزن کنند، کم می‌گذارند
# فرعون و اطرافیان او
# ما یاوران خداییم؛ به خدا ایمان آوردیم؛ و تو نیز گواه باش که ما اسلام آورده‌ایم
# تنور جوشیدن گرفت
# آرزوهای دور و دراز
# هر کس نفس خود را پاک و تزکیه کرده
# گنجی متعلق به آن دو
# کیست که در نزد او، جز به فرمان او شفاعت کند
# آنچه خداوند نازل کرده
# ابراهیم و اسماعیل
# چه چیز شما را به دوزخ وارد ساخت
# اجبار آنها به هدایت
# ای کاش بار دیگر  بازمی‌گشتم و از نیکوکاران بودم
# آن کسی که بر خدا دروغ ببندد و سخن راست را هنگامی که به سراغ او آمده تکذیب کند
# کسانی که به آنها کتاب آسمانی داده‌ایم
# فرزندان من! خداوند این آیین پاک را برای شما برگزیده است؛ و شما، جز به آیین اسلام از دنیا نروید
# نصف مجازات زنان آزاد
# مشرق و مغرب، از آن خداست؛ خدا هر کس را بخواهد، به راه راست هدایت می‌کند
# آنچه عمل می‌کردند
# هر کس از بندگان خویش را بخواهیم
# آمرزش و اجر بزرگی
# هنگام طلوع آفتاب
# کسانی از شما که ایمان آورده و کارهای شایسته انجام داده‌اند
# توبه‌پذیر و مهربان
# کسانی از شما، که در روز شنبه نافرمانی و گناه کردند
# کسانی که درباره خدا بعد از پذیرفتن او
# هر کس از هدایت من پیروی کند
# قوی و شکست ناپذیر
# به شما اندرز می‌دهد
# هر کس را خداوند گمراه کند
# همگی به سجده افتادند
# هنگامی که اطفال شما به سنّ بلوغ رسند
# جمعی از پیشینیان شما
# نزدیک این درخت نشوید
# آنچه در آسمانها و آنچه در زمین است
# تسبیح و حمد پروردگارت
# از آنچه به آن آگاهی نداری
# ابراهیم و اسماعیل
# هیچ نعمتی را که به گروهی داده
# بخشی از آنچه را به آنها گوشزد شده بود
# آنچه را بدروغ همتای خدا می‌پنداشتند
# کسانی که به آیات خداوند کافر شدند
# آنها که صبر و استقامت ورزیدند و کارهای شایسته انجام دادند
# قسمت مهمّی را از آنچه به آنان تذکّر داده شده بود
# کتابهای آسمانی دیگر
# هنگامی که می‌خواهند برای دیگران پیمانه یا وزن کنند
# پیش از طلوع آفتاب، و قبل از غروب آن
# پیامبران و صدّیقان و شهدا و صالحان
# مردان و زنان باایمان
# آنها که بر خدا دروغ می‌بندند، یا آیات او را تکذیب می کنند
# آنچه را از کتاب به تو وحی شده
# روزی که انسانها برانگیخته می‌شوند
# رحمت خدا و روز رستاخیز
# قوم نوح و عاد و ثمود و قوم ابراهیم و اصحاب مدین
# کسی که بعد از آن، تجاوز کند
# هر کس با خدا و رسولش دشمنی کند
# کسانی که کافر شدند
# گناهان بزرگ و اعمال زشت
# سرای صلح و سلامت
# گروهی که اهل تفکّرند
# کسی که از پیامبر اطاعت کند
# آنها که ایمان آوردند، و هجرت کردند، و با اموال و جانهایشان در راه خدا جهاد نمودند
# سوگندهایی که محکم کرده‌اید
# عهد خود به هنگامی که عهد بستند
# سوگند به فرشتگانی که کارها را تقسیم می‌کنند
# از آنچه از سوی پروردگارت به تو وحی می‌شود
# کسی که به سراغ تو می‌آید و کوشش می‌کند، و از خدا ترسان است
# عذابی را که به ما وعده می‌دهی
# کسانی که ایمان آورده‌اند
# سخن لغو و بیهوده
# آنان که کتاب آسمانی به ایشان داده‌ایم
# آمرزنده و مهربان
# آن نوجوان را کشت
# پیامبر و کسانی که با او ایمان آوردند
# کسانی که ایمان می‌آورند
# آمرزنده و شکرگزار
# تجارتی بی‌زیان و خالی از کساد
# بی‌نیاز و بردبار
# جنبنده زمین که عصای او را می‌خورد
# هر کس کار شایسته‌ای انجام دهد -خواه مرد یا زن- در حالی که مؤمن باشد
# آنچه را در آسمانها و زمین است
# آمرزنده و مهربان
# هرگاه آن دو، تلاش کنند که تو چیزی را همتای من قرار دهی، که از آن آگاهی نداری
# آنان که توبه کنند، و ایمان بیاورند، و کار شایسته انجام دهند
# در این سرای اقامت
# «وَد»، «سواع»، «یغوث»، «یعوق» و «نسر»
# تندبادی است که عذاب دردناکی در آن است
# شراب طهوری آمیخته با زنجبیل
# القاب زشت و ناپسند
# شدّت و رنجی که به او رسیده
# کسانی که به خدا دروغ می‌بندند
# آنچه انجام می‌دادند
# نیکی، این نیست که رویِ خود را به سوی مشرق و مغرب کنید
# هر کس همتایی برای خدا قرار دهد
# کسی که آیات خدا را تکذیب کرده، و از آن روی گردانده است
# حقّی که از سوی پروردگارشان بود
# کسی که شفاعت به کار بدی کند
# آیا تو به مردم گفتی که من و مادرم را بعنوان دو معبود غیر از خدا انتخاب کنید
# کسانی که در زمین هستند
# پاک و منزّه است کسی که این را مسخّر ما ساخت، وگرنه ما توانایی تسخیر آن را نداشتیم؛ و ما به سوی پروردگارمان بازمی‌گردیم
# صید دریا و طعام آن
# فرمان پروردگارتان
# با کسانی که با شما می‌جنگند
# هر کس به احکامی که خدا نازل کرده حکم نکند
# کسانی که کافر شدند
# خداوند آن را برای او چندین برابر کند
# هر کس از شما بعد از این کافر شود
# مهّم نیست! ما بسوی پروردگارمان بازمی‌گردیم! ما امیدواریم که پروردگارمان خطاهای ما را ببخشد، چرا که ما نخستین ایمان‌آورندگان بودیم
# تا روزی که مردم برانگیخته می‌شوند
# آنچه عمل می‌کردید
# کسی که سخن راست بیاورد و کسی که آن را تصدیق کند
# سوگند به آنها که آیات بیدارگر را القا می‌نمایند
# قوّی و شکست‌ناپذیر
# کتاب و دانش و تورات و انجیل
# کسانی که کافر شدند
# چه چیز آنها را، از قبله‌ای که بر آن بودند، بازگردانید
# آنها که در راه خدا کشته می‌شوند
# مگر آن کس که مورد ستم واقع شده باشد
# رونشان با آن آب می‌شود، و هم پوستهایشان
# آدم و نوح و آل ابراهیم و آل عمران
# کسانی که با خدا و رسولش دشمنی می‌کنند
# اموال و فرزندان فراوان
# خدا و رسول او و مؤمنان
# نوری که با او نازل شده
# ماده‌گاوی است که نه پیر و از کار افتاده باشد، و نه بکر و جوان؛ بلکه میان این دو باشد
# هر کس تقوای الهی پیشه کند
# آن کس که بر خدا دروغ می‌بندد، تا مردم را از روی جهل گمراه سازد
# کسانی که می‌ترسند
# هنگامی که به مخالفت برخاستند و استحقاق مجازات یافتند
# کسانی که در راه خدا کشته شدند
# پذیرش توبه از سوی خدا، تنها برای کسانی است که کار بدی را از روی جهالت انجام می‌دهند، سپس زود توبه می‌کنند
# مگر پس از آنکه خدا برای هر کس بخواهد و راضی باشد اجازه شفاعت دهد
# هنگامی که خدا و پیامبرش امری را لازم بدانند
# اموال و جانهای خود
# اموال و جانهای خود
# کفر و فسق و گناه
# آنها را آشتی دهید
# بخاطر آن است که قلب تو را بوسیله آن محکم داریم
# نشانه‌های کتابهای پیش از آن
# شکست‌ناپذیر و مهربان
# کسانی که بر طبق آنچه خدا نازل کرده حکم نمی‌کنند
# بدین گونه خداوند هر کاری را بخواهد انجام می‌دهد
# مردار، خون، گوشت خوک و آنچه را نام غیرِ خدا به هنگام ذبح بر آن گفته شود
# بندگان خاص خداوند رحمان
# انسانی بی‌عیب و نقص
# کسانی که کافر شدند و از راه خدا بازداشتند سپس در حال کفر از دنیا رفتند
# بلاهای کوبنده‌ای
# شادی‌کنندگان مغرور
# ابراهیم نه یهودی بود و نه نصرانی؛ بلکه موحّدی خالص و مسلمان بود
# دو نفر از کسانی که نسبت به میت، اولی هستند
# نهرهایی از شراب طهور
# عذرآورندگان از اعراب
# کسانی که نزد پروردگار تو هستند
# کسانی که در صدد ابطال سخنان تو هستند
# کسی که خدا راضی است
# کسانی که به آخرت ایمان نمی‌آورند
# کسانی که کتاب آسمانی به آنان داده‌ایم
# ما را در حالی که به پهلو خوابیده، یا نشسته، یا ایستاده است، می‌خواند
# هر کس را خدا خوار کند
# اموال و جانهای خود
# ای موسی! تا آنها در آنجا هستند، ما هرگز وارد نخواهیم شد! تو و پروردگارت بروید و  بجنگید، ما همینجا نشسته‌ایم
# مخالفت فرمان خدا
# سیصد سال درنگ کردند، و نه سال نیز بر آن افزودند
# آنها را به آن بازمی‌گردانند
# هنگامی که عذاب را می‌بیند
# آمرزنده و مهربان
# هنگامی که قرآن می‌خوانی
# کافرانی که به شما نزدیکترند
# کسانی را که در گمراهی آشکاری هستند
# آنها که صبر و استقامت ورزیدند و کارهای شایسته انجام دادند
# آنها را هشتاد تازیانه بزنید
# کسانی که از پروردگارشان می‌ترسند
# اعمالی که انجام دادند
# پدر و مادر و نزدیکان
# تمام کسانی که در آسمانها و کسانی که در زمینند
# غرق شادی و سرورند
# طوفان و ملخ و آفت گیاهی و قورباغه‌ها و خون
# حمد، مخصوص پروردگار عالمیان است
# حسابرس و نگهدار هر چیز
# هر کس اطاعت خدا و رسولش کند
# سرزمین خشک خالی از گیاه
# کسی که از پیش با خدا و پیامبرش مبارزه کرده بود
# هر کس از شما بیمار یا مسافر باشد
# پیامبر و پیشوایان
# آب صاف و خالص که بدبو نشده
# این است که پرهیزگار باشید
# ابراهیم و اسحاق و یعقوب
# معبدها، تمثالها، ظروف بزرگ غذا همانند حوضها، و دیگهای ثابت
# کسانی که به باطل ایمان آوردند و به خدا کافر شدند
# کسی که بخل ورزد و بی‌نیازی طلبد، و پاداش نیک را انکار کند
# مردار باشد، یا خونی که بیرون ریخته، یا گوشت خوک -که اینها همه پلیدند- یا حیوانی که به گناه، هنگام سر بریدن، نام غیر خدا بر آن برده شده است
# آمرزنده و مهربان
# پیامبران و صدّیقان و شهدا و صالحان
# مخصوص خداوندی است که پروردگار جهانیان است
# خدا کارهای شما را اصلاح کند و گناهانتان را بیامرزد
# مؤمنانی را که کارهای شایسته انجام می‌دهند
# باتقواترین شماست
# اموال و جانهای خود
# آنها را که ستم کردند، صیحه آسمانی فرو گرفت
# او را تکذیب و ناقه را پی کردند
# از زوال خورشید تا نهایت تاریکی شب
# هنگامی که بر سوار بر کشتی شوند
# کسانی که زنان پاکدامن و بی‌خبر و مؤمن را متهم می‌سازند
# گروهی از بندگان برگزیده خود
# فحشا و منکر و ستم
# مرا، و پدر و مادرم و تمام کسانی را که با ایمان وارد خانه من شدند، و جمیع مردان و زنان باایمان
# کسی که توبه کند، و ایمان آورد و عمل صالحی انجام دهد
# کسانی که به خویشتن ستم کردند
# وسایل دفاعی و سلاحهایشان
# شعیب و کسانی را که با او ایمان آورده بودند
# دستبندهایی از طلا و مروارید
# زنانی که پدران شما با آنها ازدواج کرده‌اند
# ابراهیم و موسی و عیسی
# کسانی که ایمان نمی‌آورند
# «قوم نوح» و «عاد» و «ثمود» و «قوم ابراهیم» و «اصحاب مدین» و «شهرهای زیر و رو شده»
# کتاب و حکمت و تورات و انجیل
# نشانه تو این است که سه شبانه روز قدرت تکلّم نخواهی داشت؛ در حالی که زبانت سالم است
# هر کس از شما بیمار یا مسافر باشد
# علمای بنی اسرائیل
# مجازات عظیمی دارند
# تنها اعمال زشت را، چه آشکار باشد چه پنهان
# نزدیکان و مسکینان و در راه‌ماندگان
# ای هارون! چرا هنگامی که دیدی آنها گمراه شدند، از من پیروی نکردی
# هر بنده توبه‌کار
# ناقه خدا را با آبشخورش واگذارید
# آنچه در آسمانها و زمین است

# %%
len(phrase_questions)
# Out:
# 719

# %%
import plotly.express as px
df = px.data.gapminder().query("continent == 'Oceania'")
fig = px.line(df, x='year', y='lifeExp', color='country', symbol="country")
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x_axis = ['mBERT', 'ParsBERT', 'XLM-RoBERTa', 'ALBERT-Persian']

# ansarian = np.array(['67.68', '68.90', '68.9', '67.07'])
# makarem = np.array(['71.42', '74.74', '74.74', '72.44'])
# fooladvand = np.array(['75.67', '74.32', '78.37', '72.97'])
# ghomshei = np.array(['57.14', '54.28', '60.00', '56.42'])
# moezzi = np.array(['65.00', '62.5', '71.66', '60.83'])
# sadeqi = np.array(['60.71', '66.42', '67.85', '65.0'])
# mojtabavi = np.array(['58.57', '62.85', '61.42', '62.85'])
# bahrampour = np.array(['72.15', '74.68', '81.01', '74.68'])
# ayati = np.array(['67.08', '60.75', '64.55', '72.15'])
# khorramshahi = np.array(['68.24', '72.29', '70.94', '69.59'])
# khorramdel = np.array(['61.7', '66.66', '65.24', '63.12'])

ansarian = [67.68, 68.90, 68.9, 67.07]
makarem = [71.42, 74.74, 74.74, 72.44]
fooladvand = [75.67, 74.32, 78.37, 72.97]
ghomshei = [57.14, 54.28, 60.00, 56.42]
moezzi = [65.00, 62.5, 71.66, 60.83]
sadeqi = [60.71, 66.42, 67.85, 65.0]
mojtabavi = [58.57, 62.85, 61.42, 62.85]
bahrampour = [72.15, 74.68, 81.01, 74.68]
ayati = [67.08, 60.75, 64.55, 72.15]
khorramshahi = [68.24, 72.29, 70.94, 69.59]
khorramdel = [61.7, 66.66, 65.24, 63.12]

plt.figure(figsize=(10, 6))

plt.plot(x_axis, ansarian, marker='o', label = 'ansarian')
plt.plot(x_axis, makarem, marker='o', label = 'makarem')
plt.plot(x_axis, fooladvand, marker='o', label = 'fooladvand')
plt.plot(x_axis, ghomshei, marker='o', label = 'ghomshei')
plt.plot(x_axis, moezzi, marker='o', label = 'moezzi')
plt.plot(x_axis, sadeqi, marker='o', label = 'sadeqi')
plt.plot(x_axis, mojtabavi, marker='o', label = 'mojtabavi')
plt.plot(x_axis, bahrampour, marker='o', label = 'bahrampour')
plt.plot(x_axis, ayati, marker='o', label = 'ayati')
plt.plot(x_axis, khorramshahi, marker='o', label = 'khorramshahi')
plt.plot(x_axis, khorramdel, marker='o', label = 'khorramdel', color = 'springgreen')


plt.title('title name')
plt.xlabel('Model Name')
plt.ylabel('Exact Match')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x_axis = ['mBERT', 'ParsBERT', 'XLM-RoBERTa', 'ALBERT-Persian']

ansarian = [74.41, 76.24, 76.35, 73.23]
makarem = [80.42, 82.28, 82.34, 81.34]
fooladvand = [81.4, 80.27, 81.75, 77.25]
ghomshei = [65.35, 66.09, 71.64, 66.37]
moezzi = [68.94, 68.67, 75.58, 68.74]
sadeqi = [66.73, 71.24, 72.33, 68.21]
mojtabavi = [71.22, 76.66, 76.42, 75.55]
bahrampour = [79.7, 80.31, 86.07, 81.43]
ayati = [78.35, 76.86, 77.51, 80.53]
khorramshahi = [73.1, 78.39, 76.1, 74.66]
khorramdel = [71.31, 74.88, 74.98, 70.53]

plt.figure(figsize=(10, 6))

plt.plot(x_axis, ansarian, marker='o', label = 'ansarian')
plt.plot(x_axis, makarem, marker='o', label = 'makarem')
plt.plot(x_axis, fooladvand, marker='o', label = 'fooladvand')
plt.plot(x_axis, ghomshei, marker='o', label = 'ghomshei')
plt.plot(x_axis, moezzi, marker='o', label = 'moezzi')
plt.plot(x_axis, sadeqi, marker='o', label = 'sadeqi')
plt.plot(x_axis, mojtabavi, marker='o', label = 'mojtabavi')
plt.plot(x_axis, bahrampour, marker='o', label = 'bahrampour')
plt.plot(x_axis, ayati, marker='o', label = 'ayati')
plt.plot(x_axis, khorramshahi, marker='o', label = 'khorramshahi')
plt.plot(x_axis, khorramdel, marker='o', label = 'khorramdel', color = 'springgreen')


plt.title('title name')
plt.xlabel('Model Name')
plt.ylabel('F1')
# plt.legend()
plt.show()

# %%
from statistics import mean
import numpy as np
import matplotlib.pyplot as plt

f1_original = [80.42, 82.28, 82.34, 81.34]
f1_backtranslation = [86.75, 87.07, 86.87, 87.77]
f1_extra= [82.64, 83.84, 84.46, 84.31]
f1_QG = [81.79, 83.24, 83.41, 82.92]

em_original = [71.42, 74.74, 74.74, 72.44]
em_backtranslation = [83.16, 83.67, 83.67, 83.92]
em_extra = [75.51, 77.57, 77.82, 78.06]
em_QG = [73.21, 76.02, 75.51, 74.74]



X = ['original data','back translation','external quran translations','Automatic QG']
F1 = [mean(f1_original)/100, mean(f1_backtranslation)/100, mean(f1_extra)/100, mean(f1_QG)/100]
exact_match = [mean(em_original)/100, mean(em_backtranslation)/100, mean(em_extra)/100, mean(em_QG)/100]

X_axis = np.arange(len(X))

plt.figure(figsize=(8.4, 6.99))
plt.bar(X_axis - 0.2, F1, 0.4, label = 'F1', color = '#85C1E9')
plt.bar(X_axis + 0.2, exact_match, 0.4, label = 'Exact Match', color = '#EE9A4D')

plt.xticks(X_axis, X)
plt.xlabel("Groups")
# plt.ylabel("Number of Students")
# plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %% [markdown]
# ## back-translation

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

f1_after = [86.75, 87.07, 86.87, 87.77]
f1_before = [80.42, 82.28, 82.34, 81.34]

em_after = [83.16, 83.67, 83.67, 83.92]
em_before = [71.42, 74.74, 74.74, 72.44]

f1_after_avg = mean(f1_after)
f1_before_avg = mean(f1_before)

em_after_avg = mean(em_after)
em_before_avg = mean(em_before)

print(f1_after_avg - f1_before_avg)
print(em_after_avg - em_before_avg)
# Out:
# 5.519999999999996
# 10.27000000000001

# %% [markdown]
# ### extra context

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

f1_after = [82.64, 83.84, 84.46, 84.31]
f1_before = [80.42, 82.28, 82.34, 81.34]

em_after = [75.51, 77.57, 77.82, 78.06]
em_before = [71.42, 74.74, 74.74, 72.44]

f1_after_avg = mean(f1_after)
f1_before_avg = mean(f1_before)

em_after_avg = mean(em_after)
em_before_avg = mean(em_before)

print(f1_after_avg - f1_before_avg)
print(em_after_avg - em_before_avg)
# Out:
# 2.217500000000001
# 3.905000000000001

# %% [markdown]
# ### automatic questions

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

f1_after = [81.79, 83.24, 83.41, 82.92]
f1_before = [80.42, 82.28, 82.34, 81.34]

em_after = [73.21, 76.02, 75.51, 74.74]
em_before = [71.42, 74.74, 74.74, 72.44]

f1_after_avg = mean(f1_after)
f1_before_avg = mean(f1_before)

em_after_avg = mean(em_after)
em_before_avg = mean(em_before)

print(f1_after_avg - f1_before_avg)
print(em_after_avg - em_before_avg)
# Out:
# 1.2450000000000045
# 1.5350000000000108

# %% [markdown]
# # all

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

f1_after = [86.36, 87.59, 86.85, 87.35]
f1_before = [80.42, 82.28, 82.34, 81.34]

em_after = [82.91, 84.44, 83.93, 83.42]
em_before = [71.42, 74.74, 74.74, 72.44]

f1_after_avg = mean(f1_after)
f1_before_avg = mean(f1_before)

em_after_avg = mean(em_after)
em_before_avg = mean(em_before)

print(f1_after_avg - f1_before_avg)
print(em_after_avg - em_before_avg)
# Out:
# 5.4424999999999955
# 10.340000000000003

# %%
import matplotlib.pyplot as plt
import numpy as np


x_axis = ['mBERT', 'ParsBERT', 'XLM-RoBERTa', 'ALBERT-Persian']

ansarian = [74.41, 76.24, 76.35, 73.23]
makarem = [80.42, 82.28, 82.34, 81.34]
fooladvand = [81.4, 80.27, 81.75, 77.25]
ghomshei = [65.35, 66.09, 71.64, 66.37]
moezzi = [68.94, 68.67, 75.58, 68.74]
sadeqi = [66.73, 71.24, 72.33, 68.21]
mojtabavi = [71.22, 76.66, 76.42, 75.55]
bahrampour = [79.7, 80.31, 86.07, 81.43]
ayati = [78.35, 76.86, 77.51, 80.53]
khorramshahi = [73.1, 78.39, 76.1, 74.66]
khorramdel = [71.31, 74.88, 74.98, 70.53]

plt.figure(figsize=(10, 6))

plt.plot(x_axis, ansarian, marker='o', label = 'ansarian')
plt.plot(x_axis, makarem, marker='o', label = 'makarem')
plt.plot(x_axis, fooladvand, marker='o', label = 'fooladvand')
plt.plot(x_axis, ghomshei, marker='o', label = 'ghomshei')
plt.plot(x_axis, moezzi, marker='o', label = 'moezzi')
plt.plot(x_axis, sadeqi, marker='o', label = 'sadeqi')
plt.plot(x_axis, mojtabavi, marker='o', label = 'mojtabavi')
plt.plot(x_axis, bahrampour, marker='o', label = 'bahrampour')
plt.plot(x_axis, ayati, marker='o', label = 'ayati')
plt.plot(x_axis, khorramshahi, marker='o', label = 'khorramshahi')
plt.plot(x_axis, khorramdel, marker='o', label = 'khorramdel', color = 'springgreen')


plt.title('title name')
plt.xlabel('Model Name')
plt.ylabel('F1')
# plt.legend()
plt.show()

# %%
f1_original = [80.42, 82.28, 82.34, 81.34]
f1_backtranslation = [86.75, 87.07, 86.87, 87.77]
f1_extra= [82.64, 83.84, 84.46, 84.31]
f1_QG = [81.79, 83.24, 83.41, 82.92]

em_original = [71.42, 74.74, 74.74, 72.44]
em_backtranslation = [83.16, 83.67, 83.67, 83.92]
em_extra = [75.51, 77.57, 77.82, 78.06]
em_QG = [73.21, 76.02, 75.51, 74.74]


# back translation

f1_back = [mean(f1_original)/100, mean(f1_backtranslation)/100]
em_back = [mean(em_original)/100, mean(em_backtranslation)/100]

# extra context

f1_extra = [mean(f1_original)/100, mean(f1_extra)/100]
em_extra = [mean(em_original)/100, mean(em_extra)/100]

# QG
f1_QG = [mean(f1_original)/100, mean(f1_QG)/100]
em_QG = [mean(em_original)/100, mean(em_QG)/100]

X = ['original','NEW']

# X = ['original data','back translation','external quran translations','Automatic QG']
# F1 = [mean(f1_original)/100, mean(f1_backtranslation)/100, mean(f1_extra)/100, mean(f1_QG)/100]
# exact_match = [mean(em_original)/100, mean(em_backtranslation)/100, mean(em_extra)/100, mean(em_QG)/100]

# plt.figure(figsize=(15, 6))
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Horizontally stacked subplots')

ax1.plot(f1_back, marker='o', label = 'Average F1')
ax1.plot(em_back, marker='o', label = 'Average Exact match')
plt.legend()

ax2.plot(f1_extra, marker='o', label = 'F1')
ax2.plot(em_extra, marker='o', label = 'Exact match')

ax3.plot(f1_QG, marker='o', label = 'F1')
ax3.plot(em_QG, marker='o', label = 'Exact match')

plt.legend()

# ax2.plot(x, -y)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # translations overlap

# %%
import json
import os
import re
from bs4 import BeautifulSoup
import string

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
punctuations = '''`=«»،÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
english_punctuations = string.punctuation
punctuations_list = punctuations + english_punctuations

arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             ّ    | # shadda
                             ٰ    | #qasr
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ۛ    |##
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)

def remove_digits(text):
    text = re.sub(r"[1234567890١٢٣٤٥٦٧٨٩٠]+", "", text)
    return text

def remove_english_characters(text):
    text = re.sub(r'[a-zA-Z]+','',text)
    return text


def remove_diacritics(text):
    text = re.sub(arabic_diacritics, '', text)
    return text


def remove_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)

def normalization(sentence):
    text = remove_english_characters(sentence)
    text = remove_digits(text)
    text = remove_diacritics(text)
    text = remove_punctuations(text)
    return text

# %%
corpus_path = '/content/drive/MyDrive/fa'

translation_dict = {}

for each in os.listdir(corpus_path):
  file_path = corpus_path + '/' + each
  with open(file_path, 'r', encoding="utf8") as f:
    content = f.read()
  soup= BeautifulSoup(content, 'xml')
  verses = soup.find_all('s')
  token_list = []
  for verse in verses:
    normal_verse = normalization(verse.contents[0])
    normal_verse = re.sub("[\(\[].*?[\)\]]", "", normal_verse)
    token_list += set(normal_verse.split())

  translation_dict[each.removesuffix('.xml')] = set(token_list)

# %%
translation_dict
# Out:
# {'ansarian.xml': {'نوشانند',
#   'اسیری',
#   'صورتگر',
#   'عداوت',
#   'شریعت',
#   'مهاجران',
#   'دروغشان',
#   'بفرستید',
#   'نیکویی',
#   'گرداندیم',
#   'مصاحبت',
#   'وثوابش',
#   'پاکیزه',
#   'فرما',
#   'شفیعی',
#   'نزاده',
#   'نامید',
#   'اولادی',
#   'شایستگانند',
#   'دستخوش',
#   'سیراب',
#   'آشنا',
#   'عصای',
#   'ساختی',
#   'انکار',
#   'انگشتانش',
#   'نرفتن',
#   'زندگان',
#   'نپروراندیم',
#   'یاغی',
#   'زبونشان',
#   'نفس',
#   'پردازد',
#   'شنیده',
#   'اقوامی',
#   'پروا',
#   'کردیم',
#   'نوادگانی',
#   'جنبندگانی',
#   'بیمها',
#   'سلسبیل',
#   'رزقشان',
#   'آرند',
#   'ندارم',
#   'مهلتم',
#   'برنده',
#   'گرداندنشان',
#   'تراشید',
#   'پیرزنم',
#   'زنجیره',
#   'پرهیز',
#   'آتشگیره',
#   'جاودانان',
#   'پیامبری',
#   'نجس',
#   'متنفر',
#   'بزرگان',
#   'تدبیرکنندگان',
#   'آر',
#   'پسران',
#   'سخنانشان',
#   'سفره',
#   'بازگرفتنش',
#   'نیکوکار',
#   'وچنان',
#   'سرگذشت',
#   'تسبیح',
#   'شفاعتش',
#   'ناپسندشان',
#   'ترسیدم',
#   'ریایی',
#   'شکافتیم',
#   'زمین',
#   'ناب',
#   'نظیر',
#   'گفتارها',
#   'خشنودیم',
#   'معمول',
#   'آرایش',
#   'آنجا',
#   'مهربانم',
#   'مأموریت',
#   'شنویم',
#   'خودتان',
#   'کفی',
#   'اعمالتان',
#   'کناره',
#   'مسالمت',
#   'آمدید',
#   'مبتلای',
#   'ختم',
#   'یهودی',
#   'رهاندنش',
#   'آویز',
#   'پیروزند',
#   'برایتان',
#   'نتوانید',
#   'متعلق',
#   'ن',
#   'ومتفاوتی',
#   'سلاحتان',
#   'همان',
#   'گذارید',
#   'خرافاتشان',
#   'وفای',
#   'ابن',
#   'مرفهین',
#   'هریک',
#   'المنتهی',
#   'تشخیص',
#   'معاندان',
#   'تفاوتی',
#   'گریخته',
#   'محور',
#   'مسلح',
#   'اعصاب',
#   'مواسات',
#   'ببار',
#   'ستمکارانم',
#   'واهی',
#   'بیالود',
#   'ناآگاهی',
#   'برگردید',
#   'تقصیری',
#   'وکردارش',
#   'مساجد',
#   'رویاندیم',
#   'جاودانگی',
#   'ارجمندت',
#   'اولیا',
#   'روده',
#   'برفرازشان',
#   'فاجر',
#   'آنگونه',
#   'علتْ',
#   'نمرده',
#   'ماییم',
#   'لعنتی',
#   'شنیدن',
#   'کنارشان',
#   'نافرمان',
#   'شکستیم',
#   'وشکست',
#   'قرارگاهی',
#   'ومیانشان',
#   'گواهان',
#   'حیاتی',
#   'نتوانی',
#   'پیچیدن',
#   'همراهی',
#   'جدی',
#   'گردانیم',
#   'ابلیس',
#   'شعیب',
#   'باگذشت',
#   'امانتش',
#   'سراهای',
#   'تقرب',
#   'ندادند',
#   'زحمت',
#   'تعبیر',
#   'شاه',
#   'شوره',
#   'خورشی',
#   'پسندند',
#   'دیارتان',
#   'وقوف',
#   'سراغ',
#   'انگورها',
#   'وصیله',
#   'فقیران',
#   'شایسته',
#   'فرستاده',
#   'رویانید',
#   'آوازدادند',
#   'همنشینانی',
#   'پشتیبانی',
#   'محصولات',
#   'مشت',
#   'هشتاد',
#   'قرائت',
#   'درخشنده',
#   'دشوار',
#   'بیخ',
#   'فرزندانش',
#   'صالحشان',
#   'درگذرد',
#   'رنگی',
#   'برم',
#   'پلیدند',
#   'برسند',
#   'بشنوانی',
#   'وثیقه',
#   'پهن',
#   'خران',
#   'بیازماییم',
#   'کردارم',
#   'خویشان',
#   'بودی',
#   'بسا',
#   'شنوید',
#   'آشفته',
#   'بیاشام',
#   'عبادات',
#   'مظلوم',
#   'تداعی',
#   'شن',
#   'سرافکنده',
#   'استخوانم',
#   'هراسش',
#   'قدح',
#   'لجن',
#   'صفی',
#   'گوارایتان',
#   'زدن',
#   'ناگواری',
#   'زینتی',
#   'ستد',
#   'آزاریم',
#   'گلی',
#   'ستمکارتر',
#   'ملازمش',
#   'کوچکتان',
#   'اعضای',
#   'کوچه',
#   'کنندگانیم',
#   'اوگفته',
#   'پیامبرانْ',
#   'مپندار',
#   'شدنش',
#   'مردانی',
#   'سوت',
#   'پاداشش',
#   'دشواری',
#   'جریانات',
#   'باربر',
#   'لشکریانی',
#   'ویهودیان',
#   'نقبی',
#   'سردرگم',
#   'بازماندگان',
#   'ستمکارانند',
#   'رسا',
#   'زنی',
#   'شکلی',
#   'احدی',
#   'خودستایی',
#   'شرع',
#   'کسی',
#   'انتشارش',
#   'تقوایی',
#   'وجستجویتان',
#   'نهانش',
#   'افکندید',
#   'وآهسته',
#   'هشتمین',
#   'عجیبی',
#   'گام',
#   'امکان',
#   'بکاهید',
#   'قوم',
#   'سنگسارت',
#   'درماندگان',
#   'استهزا',
#   'یعوق',
#   'بحیره',
#   'لغت',
#   'سوره',
#   'مفسد',
#   'دوشیزه',
#   'پوشانند',
#   'آلوده',
#   'سایه',
#   'خضوع',
#   'اعجاز',
#   'رهایی',
#   'بگردید',
#   'عمرشان',
#   'شیرین',
#   'وصف',
#   'ملأ',
#   'ننهادیم',
#   'نایل',
#   'عنایت',
#   'رویش',
#   'هنوز',
#   'اقتدار',
#   'کری',
#   'سبکی',
#   'وسیع',
#   'مشاهده',
#   'رویاند',
#   'خشنودند',
#   'کردنتان',
#   'سیزدهم',
#   'توصیف',
#   'نماییم',
#   'وفرشتگان',
#   'نظرشان',
#   'خصومت',
#   'قسم',
#   'دقیق',
#   'احوالات',
#   'رهاییم',
#   'چهل',
#   'سرگرم',
#   'بسوزانیم',
#   'برما',
#   'سرسبزی',
#   'رساننده',
#   'مبتلا',
#   'پرهیزکارانند',
#   'کی',
#   'قیمت',
#   'سومین',
#   'تغییرات',
#   'دزد',
#   'سدها',
#   'بنی',
#   'حوریانی',
#   'فخرفروشیتان',
#   'ص',
#   'بترسی',
#   'پرتاب',
#   'حدقه',
#   'مرتد',
#   'بازگشتند',
#   'اکتفای',
#   'شکست',
#   'کشاورزان',
#   'پیشگاهت',
#   'بودنش',
#   'سوگندت',
#   'بردارد',
#   'راندیم',
#   'پیچد',
#   'جبین',
#   'تجارتی',
#   'نورشان',
#   'ولی',
#   'اصحاب',
#   'مغالطه',
#   'سر',
#   'ورزیدی',
#   'کشتن',
#   'انداختند',
#   'ندادم',
#   'گلوگیر',
#   'آگاهی',
#   'نعمتش',
#   'دسترسی',
#   'سنگری',
#   'واهمه',
#   'خواهانیم',
#   'چشمش',
#   'زندگی',
#   'بخشیدن',
#   'برانی',
#   'مشابهش',
#   'عیسی',
#   'برآنان',
#   'مکررت',
#   'بردگان',
#   'وعاجز',
#   'کشم',
#   'بهشتیم',
#   'انگور',
#   'شیردهنده',
#   'رهروان',
#   'نجاتشان',
#   'وقت',
#   'پیراهن',
#   'علاقه',
#   'شصت',
#   'وبنی',
#   'کافور',
#   'بخشش',
#   'شوند',
#   'آذوقه',
#   'موعدی',
#   'وفاداران',
#   'عشقشان',
#   'نیز',
#   'ایام',
#   'دلتنگی',
#   'ابد',
#   'رنگارنگ',
#   'بهشتی',
#   'نیستید',
#   'ضروری',
#   'ساز',
#   'پربرکتی',
#   'آوردنش',
#   'پدرت',
#   'آبرومندی',
#   'کیفری',
#   'قرب',
#   'روشی',
#   'معشوقه',
#   'پروردگارت',
#   'سعادت',
#   'پروردگارا',
#   'محتویات',
#   'زندانیان',
#   'نشستن',
#   'گرداندند',
#   'فرا',
#   'چالاک',
#   'همه',
#   'کرانش',
#   'گرنه',
#   'بهایی',
#   'صفایی',
#   'الله',
#   'ونیرو',
#   'یائسگی',
#   'دارندگان',
#   'تبهکارش',
#   'بیمارم',
#   'خوارکننده',
#   'یافتگانی',
#   'تقدیر',
#   'بنمای',
#   'بترسد',
#   'مخالفان',
#   'برگردانی',
#   'منات',
#   'معنوی',
#   'وجود',
#   'بزم',
#   'آورد',
#   'اسیر',
#   'بخواهی',
#   'شرمی',
#   'بگذار',
#   'درگذرید',
#   'نرسید',
#   'بچشاند',
#   'افروزید',
#   'ارسال',
#   'بز',
#   'رحیم',
#   'بدبخت',
#   'نحوست',
#   'حجاز',
#   'دفاعی',
#   'احسانی',
#   'تجارتشان',
#   'سنگر',
#   'مضمون',
#   'موجی',
#   'بازداشتند',
#   'کودکانی',
#   'بجویید',
#   'بپیماید',
#   'تعالیم',
#   'بکشید',
#   'دعاست',
#   'یأجوج',
#   'گندیده',
#   'نواحی',
#   'آخرت',
#   'تحقیر',
#   'شعری',
#   'رهبانیتی',
#   'تار',
#   'نظری',
#   'پلیدی',
#   'وپنداشتند',
#   'سالم',
#   'مدد',
#   'شنواند',
#   'وام',
#   'دنباله',
#   'امیال',
#   'ایستی',
#   'گرفتارند',
#   'اداره',
#   'سپارید',
#   'زنجیرهایی',
#   'گذارم',
#   'میری',
#   'اوایل',
#   'بفرست',
#   'معبودانشان',
#   'بازگو',
#   'استوارتان',
#   'مهمانداری',
#   'جلی',
#   'امتناع',
#   'سببش',
#   'کمرشکن',
#   'پیشامد',
#   'بستر',
#   'نیرنگی',
#   'گرانی',
#   'سرخ',
#   'اویند',
#   'وامان',
#   'باشم',
#   'هوش',
#   'کاری',
#   'عفیفه',
#   'خوابند',
#   'جوشان',
#   'محبوبیتی',
#   'شمردیم',
#   'شنیدند',
#   'نیت',
#   'شدهاست',
#   'اش',
#   'یا',
#   'بزنید',
#   'کلیدهای',
#   'سیاه',
#   'تقوایان',
#   'یتیم',
#   'انگیزه',
#   'گورش',
#   'خواهرت',
#   'بلاست',
#   'گردد',
#   'یازدهم',
#   'دروغگو',
#   'فایده',
#   'جن',
#   'نتوانست',
#   'بازنایستند',
#   'وکاملان',
#   'کاهیم',
#   'خروج',
#   'گفتید',
#   'سازند',
#   'خانوادگی',
#   'ملحق',
#   'اخراج',
#   'جبهه',
#   'قبل',
#   'بلاغت',
#   'زیانکارترند',
#   'خواهند',
#   'طلا',
#   'عبدالله',
#   'شوال',
#   'ضعیفان',
#   'تباهکارانه',
#   'غیبت',
#   'ناچیزی',
#   'نتازاندید',
#   'برگرداند',
#   'گریختی',
#   'گسترانیده',
#   'نیفتاد',
#   'سختی',
#   'بیماری',
#   'درودی',
#   'پر',
#   'وثروت',
#   'عمومی',
#   'بردیم',
#   'نمازی',
#   'مشروعی',
#   'بیشترشان',
#   'ولادت',
#   'دستم',
#   'دلسوز',
#   'زنده',
#   'تبلیغی',
#   'رویند',
#   'زشتی',
#   'مادر',
#   'افزوده',
#   'سنجش',
#   'نسلش',
#   'بندگیش',
#   'باکی',
#   'لغوتان',
#   'شکسته',
#   'طریق',
#   'بپرهیز',
#   'گذاران',
#   'صدقاتْ',
#   'نشنیده',
#   'بازدارد',
#   'مغرورشدگان',
#   'شیون',
#   'آمدنش',
#   'القری',
#   'ساکن',
#   'واگذاری',
#   'استفاده',
#   'لجوجان',
#   'ساعاتی',
#   'حدود',
#   'بزرگوارانی',
#   'شنوند',
#   'طس',
#   'امکانات',
#   'بیفزای',
#   'دامنشان',
#   'یابیم',
#   'تکبرش',
#   'دیدار',
#   'فریادی',
#   'عنادشان',
#   'وپروردگار',
#   'هویت',
#   'باعظمت',
#   'تازم',
#   'تبهکاران',
#   'محسوس',
#   'غارتگران',
#   'نیرومندشان',
#   'محاسبات',
#   'موجود',
#   'فرمان',
#   'ازلابلای',
#   'بلندقامت',
#   'دریایی',
#   'نورس',
#   'مصلحانی',
#   'صلحی',
#   'فرهنگی',
#   'حاصلشتان',
#   'کوچکم',
#   'درک',
#   'نرساند',
#   'گری',
#   'وآنان',
#   'واین',
#   'متعادل',
#   'هزینه',
#   'برادری',
#   'پابرجا',
#   'بداریم',
#   'شیره',
#   'کبودچشم',
#   'شتابند',
#   'مسری',
#   'شهرمان',
#   'نسزد',
#   'ادای',
#   'ملایم',
#   'رستگارند',
#   'ناتوانی',
#   'محرومیت',
#   'امورش',
#   'بارگاه',
#   'نشنود',
#   'شمایید',
#   'فرستادید',
#   'نهفته',
#   'برانداز',
#   'روزهای',
#   'گذار',
#   'سی',
#   'وجودم',
#   'نحر',
#   'تعقیب',
#   'دانشمندانش',
#   'معجزه',
#   'مادیو',
#   'شام',
#   'کاشانه',
#   'معاد',
#   'مردمْ',
#   'شفاعتی',
#   'خرند',
#   'نیاورید',
#   'هشیاری',
#   'وموسی',
#   'خریدن',
#   'اندوهگین',
#   'حقیقت',
#   'آشامید',
#   'گفتارهای',
#   'بعل',
#   'اجساد',
#   'بنگرد',
#   'ریزان',
#   'وضو',
#   'تزویرشان',
#   'خاکسار',
#   'نمایان',
#   'مسلطیم',
#   'متوفی',
#   'درگاه',
#   'یکسان',
#   'آغاز',
#   'میانه',
#   'گرایید',
#   'وسیرت',
#   'ورزیدند',
#   'یونس',
#   'دهان',
#   'سپردند',
#   'گفته',
#   'تحیت',
#   'مدفون',
#   'کنم',
#   'خواندید',
#   'تفرقه',
#   'گردنش',
#   'خواهانند',
#   'مودت',
#   'نگفتم',
#   'دادخواهی',
#   'اهلی',
#   'رهانیم',
#   'طی',
#   'زیادتر',
#   'تلاوتش',
#   'توکل',
#   'مجنون',
#   'حوادث',
#   'تمسک',
#   'رنگش',
#   'تندی',
#   'فرستیم',
#   'ظلم',
#   'ناسپاس',
#   'گذاشتی',
#   'روبه',
#   'طاغوت',
#   'فصحا',
#   'بسترهایی',
#   'بپرستیم',
#   'طوی',
#   'افتد',
#   'پوستشان',
#   'حاجات',
#   'نکردی',
#   'صاحبانشان',
#   'نوزاد',
#   'خطرات',
#   'بازدارید',
#   'ایمن',
#   'سرتان',
#   'حقیقی',
#   'تیره',
#   'زاری',
#   'برگردانیم',
#   'پیرامونش',
#   'کشیده',
#   'ودام',
#   'درباره',
#   'نعمتی',
#   'دهندگانم',
#   'صولت',
#   'وبرخی',
#   'مادرتان',
#   'وعنادشان',
#   'نفرت',
#   'ویقین',
#   'شهامت',
#   'اتصال',
#   'ودر',
#   'احوال',
#   'هموارش',
#   'تدریجی',
#   'پیشگانْ',
#   'وانتساب',
#   'اولوالعزم',
#   'گیری',
#   'نوش',
#   'برادرم',
#   'آنانی',
#   'یاریش',
#   'بازگشتید',
#   'نخل',
#   'کذب',
#   'یاآنان',
#   'آتشی',
#   'سوخت',
#   'پوشانده',
#   'هوا',
#   'مخالفین',
#   'مسکونی',
#   'تکلیف',
#   'نیرومندترم',
#   'یابد',
#   'غافل',
#   'مأمورم',
#   'سربلندی',
#   'فرمانبرداران',
#   'توحید',
#   'اشتیاق',
#   'رؤیا',
#   'بگوییم',
#   'درآور',
#   'دامنتان',
#   'جبری',
#   'واقعیاتی',
#   'یاران',
#   'معرفی',
#   'موقوف',
#   'جمال',
#   'کیان',
#   'انجامش',
#   'پادارنده',
#   'کشانید',
#   'منفعت',
#   'همنشینان',
#   'تأمین',
#   'حضرت',
#   'قصرها',
#   'نگاه',
#   'پنجم',
#   'راستت',
#   'فرشتگانش',
#   'ماندید',
#   'مشکلات',
#   'آزادشان',
#   'زودتر',
#   'ترسانند',
#   'برنداشتند',
#   'شنوی',
#   'تذکری',
#   'گرفتن',
#   'شدنی',
#   'انسان',
#   'نصاری',
#   'سایبانی',
#   'هلاکتشان',
#   'کنجکاو',
#   'گیریم',
#   'ارث',
#   'پهنای',
#   'ویرانگرم',
#   'تحققش',
#   'درجات',
#   'شوید',
#   'سفیرانی',
#   'مسلکانشان',
#   'مغرورانه',
#   'برگردانند',
#   'رضایت',
#   'فهمند',
#   'هدایت',
#   'بپرستد',
#   'مطیعان',
#   'مزدی',
#   'نپیوسته',
#   'خوارترینان',
#   'هشدار',
#   'درس',
#   'پرهیزد',
#   'کافی',
#   'مان',
#   'محاکمه',
#   'نپرستیم',
#   'علت',
#   'ایکه',
#   'بیمشان',
#   'خوشبوست',
#   'وحق',
#   'نجاتی',
#   'دیوارش',
#   'پیامبر',
#   'ممنوعیت',
#   'پلیدیشان',
#   'ایم',
#   'دریاست',
#   'آزردن',
#   'ملازمت',
#   'نقش',
#   'دیرینت',
#   'سودی',
#   'جنگید',
#   'گرگ',
#   'امیدواران',
#   'قاطع',
#   'گریان',
#   'مالشان',
#   'همسرانْ',
#   'رئیس',
#   'دادخواه',
#   'پرستیدنش',
#   'سمحه',
#   'حقوق',
#   'دیگر',
#   'درخواست',
#   'گماشتگانش',
#   'بسیاری',
#   'برانگیزید',
#   'شاهدانی',
#   'صحفه',
#   'صومعه',
#   'رستاخیز',
#   'زورگو',
#   'جست',
#   'انحراف',
#   'گرویده',
#   'نیات',
#   'عده',
#   'ترساند',
#   'پدرانمان',
#   'تسلط',
#   'نموده',
#   'تخت',
#   'داشتم',
#   'فرزند',
#   'بیاموزی',
#   'مشغول',
#   'طاغیان',
#   'غلیظ',
#   'زیانکارند',
#   'عقل',
#   'جهت',
#   'ستاره',
#   'کامل',
#   'آموزید',
#   'نارسیده',
#   'ناخن',
#   'تنظیم',
#   'خوشدلی',
#   'گردهمایی',
#   'برند',
#   'نوشندگان',
#   'کشتزار',
#   'وتنها',
#   'مصرف',
#   'بکشم',
#   'دهید',
#   'اطلاع',
#   'ناشی',
#   'نمازْ',
#   'خوشگذران',
#   'برعهده',
#   'ست',
#   'طالوت',
#   'نبودیم',
#   'وکوته',
#   'معبودانی',
#   'دیوارها',
#   'درهایی',
#   'مؤمنانند',
#   'جودی',
#   'گناهشان',
#   'خواهران',
#   'بدانید',
#   'چهره',
#   'بندگانیم',
#   'اخبار',
#   'ناملایم',
#   'زنند',
#   'جادویشان',
#   'آموخت',
#   'مبارک',
#   'سارانی',
#   'داشتید',
#   'پسرش',
#   'خداشناسی',
#   'ضبط',
#   'عرفات',
#   'بازگردد',
#   'ورثه',
#   'رسولی',
#   'اوهام',
#   'ناآگاهان',
#   'جستجوگر',
#   'ندانند',
#   'نیندیشیده',
#   'هیچ',
#   'خونخواهش',
#   'گسلند',
#   'بندگانند',
#   'خوانیم',
#   'بمیرید',
#   'معاشر',
#   'نایست',
#   'وگفت',
#   'بلورینی',
#   'جویانه',
#   'سوار',
#   'پرسش',
#   'مگس',
#   'برگیرد',
#   'بیانش',
#   'گفتن',
#   'عاصی',
#   'شباهت',
#   'اسرافشان',
#   'محکومیت',
#   'مانیم',
#   'داناست',
#   'دگرگون',
#   'ناحق',
#   'علاقمند',
#   'متجاوزان',
#   'دانستند',
#   'خاطر',
#   'تهدیدی',
#   'تنگی',
#   'گشتن',
#   'لجام',
#   'کیششان',
#   'سحرهایند',
#   'کاهلی',
#   'پوک',
#   ...},
#  'ayati.xml': {'هزيمت',
#   'شيرين',
#   'ببين',
#   'عداوت',
#   'مهاجران',
#   'آماس',
#   'نمى\u200cتوانست',
#   'محنتى',
#   'ساكنانش',
#   'پسركم',
#   'اكنون',
#   'چراغى',
#   'مى\u200cايستادند',
#   'حاجاتى',
#   'بنمايم',
#   'نهرهايى',
#   'دستخوش',
#   'آبادانش',
#   'پيامبران',
#   'آشنا',
#   'نمازگزارانى\u200c',
#   'جزئى',
#   'زندگان',
#   'مى\u200cافتادند',
#   'مارى',
#   'نشنيده\u200cاند',
#   'زبون\u200cشدگان',
#   'مى\u200cبرم',
#   'بوزينگانى',
#   'نفس',
#   'پردازد',
#   'گلوگير',
#   'برديم',
#   'درآمديد',
#   'پروا',
#   'نشين',
#   'موالى',
#   'آرند',
#   'گورند',
#   'ندارم',
#   'گرداندنشان',
#   'نيكبختان',
#   'دستهاى',
#   'يادشان',
#   'حامى',
#   'قافله',
#   'گوى',
#   'سندس',
#   'خاطرش',
#   'بيفكنديم',
#   'كج',
#   'بزرگان',
#   'زمينند',
#   'قوى',
#   'آر',
#   'پسران',
#   'بازگرفتنش',
#   'جاهلند',
#   'سرگذشت',
#   'ناپسندشان',
#   'داشتيد',
#   'آنجا',
#   'مهربانم',
#   'قسمتى',
#   'حسابگران',
#   'اينك',
#   'بركنده',
#   'مولايى',
#   'پرداختيد',
#   'توكل',
#   'خودتان',
#   'بهشتى',
#   'اعمالتان',
#   'پندهاست',
#   'دليلهايى',
#   'تنديسها',
#   'متعلق',
#   'بزرگ\u200cتر',
#   'مهلتى',
#   'همان',
#   'بگويى',
#   'صورت\u200cبخش',
#   'وقتى',
#   'دشنامش',
#   'گردانيدن',
#   'بيايى',
#   'مى\u200cخواندش',
#   'پليدى\u200cاش',
#   'ببار',
#   'اشترانى',
#   'چشيدند',
#   'آورده\u200cايم',
#   'برنيايند',
#   'ناپاكان',
#   'لغوى',
#   'درنگش',
#   'مشغولشان',
#   'همسريشان',
#   'انعام',
#   'فاجر',
#   'ببينيم',
#   'دروغى',
#   'كشتزار',
#   'طعمهاى',
#   'نافرمان',
#   'نگهبانش',
#   'توصيه',
#   'برجى',
#   'كاهد',
#   'گواهان',
#   'برترى\u200cجوى',
#   'بستيم',
#   'كشتند',
#   'كينه\u200cتوزترين',
#   'بيفتيد',
#   'گفتى',
#   'ببيند',
#   'موعد',
#   'فراخوانند',
#   'عذابند',
#   'نيكوكاران',
#   'آفرينش',
#   'نمى\u200cنمود',
#   'ستمكاريشان',
#   'باران\u200cزاست',
#   'نوشندگانش',
#   'تقرب',
#   'ندادند',
#   'نمازگزاريد',
#   'فرياد',
#   'ندانسته\u200cاى',
#   'لخته\u200cخونى',
#   'مشغولند',
#   'عاقبتى',
#   'نرسيده\u200cاند',
#   'منه',
#   'نمى\u200cگردند',
#   'قدرش',
#   'نكشتند',
#   'افكندم',
#   'درراه',
#   'فرستاده',
#   'مشغولش',
#   'لبه',
#   'صواب\u200cتر',
#   'هدايت',
#   'مشت',
#   'هشتاد',
#   'درست\u200cقول',
#   'تاريك',
#   'تبديلى',
#   'آمده\u200cام',
#   'نپذيريد',
#   'درخشنده',
#   'دشوار',
#   'فرزندانش',
#   'درگذرد',
#   'نمى\u200cآوردند',
#   'برم',
#   'برسند',
#   'نمى\u200cشنويد',
#   'خران',
#   'كارى',
#   'بسا',
#   'آشفته',
#   'مى\u200cجستند',
#   'گروبندى',
#   'مى\u200cگرفت',
#   'نپرستيم',
#   'نشانديم',
#   'نگاهش',
#   'لجن',
#   'بخشيديم',
#   'نمى\u200cيابم',
#   'ميرانيدى',
#   'فريب',
#   'زدن',
#   'خويشاوندمان',
#   'مى\u200cپيمايند',
#   'ستد',
#   'پوسيده',
#   'همسايه',
#   'مى\u200cطلبد',
#   'كوشش',
#   'پارساى',
#   'صبحدم',
#   'آفريده\u200cام',
#   'مى\u200cپندارند',
#   'سرافكنده',
#   'تابوتى',
#   'مپندار',
#   'روشى',
#   'نيستيم',
#   'پاداشش',
#   'زودى',
#   'مى\u200cپذيرند',
#   'كفرآميز',
#   'سواى',
#   'خيرخواه',
#   'آفاق',
#   'بازماندگان',
#   'پراكنده\u200cشان',
#   'برسيد',
#   'رسا',
#   'مى\u200cشناسيم',
#   'مى\u200cشوم',
#   'فرزندانى',
#   'برهانى',
#   'رحمها',
#   'خاك\u200cنشين',
#   'مى\u200cگرديم',
#   'معينى',
#   'بارخدايا',
#   'مى\u200cآورده\u200cايد',
#   'درنياييم',
#   'درجاتى',
#   'گام',
#   'قوم',
#   'گزارندگان',
#   'سنگسارت',
#   'درماندگان',
#   'استهزا',
#   'لغت',
#   'ثلث',
#   'مى\u200cرود',
#   'سوره',
#   'تختى',
#   'پاره\u200cپاره',
#   'نمى\u200cپردازيد',
#   'رسانده\u200cاند',
#   'گردانيدم',
#   'هركس',
#   'چيز',
#   'پيروزيتان',
#   'دنيايى',
#   'خضوع',
#   'عمرشان',
#   'شدنى',
#   'نطلبيده\u200cاند',
#   'وصف',
#   'ميزبانم',
#   'كفران',
#   'قتال',
#   'نكرد',
#   'پيشه',
#   'مى\u200cگويد',
#   'هنوز',
#   'عشيره\u200cاش',
#   'آينده',
#   'مى\u200cزوريم',
#   'مشاهده',
#   'مى\u200cپرستيده\u200cايد',
#   'درآميخت',
#   'وجهى',
#   'خشنودند',
#   'مى\u200cفروختيد',
#   'برمى\u200cخيزيم',
#   'نظرشان',
#   'مى\u200cپرستيم',
#   'خصومت',
#   'قسم',
#   'وحوش',
#   'گزافكار',
#   'سختش',
#   'هلاكتان',
#   'چهل',
#   'برخيزانند',
#   'مرواريد',
#   'منادى',
#   'مى\u200cخوردند',
#   'نيكوكارن',
#   'سرگرم',
#   'مراد',
#   'مبتلا',
#   'مى\u200cنوشد',
#   'رهايش',
#   'سالها',
#   'درمى',
#   'عرف',
#   'دزد',
#   'ايمان\u200cآورنده',
#   'كاميابيى',
#   'انگاشت',
#   'خوان',
#   'منهيد',
#   'مى\u200cنمود',
#   'مستى',
#   'شكرپذيرنده',
#   'هميشه',
#   'مرتد',
#   'حدقه',
#   'بازگشتند',
#   'بلاخيزتر',
#   'خاله\u200cتان',
#   'مى\u200cفريبند',
#   'بازگشته\u200cايم',
#   'نماياند',
#   'برخوردارند',
#   'پنداشته\u200cايد',
#   'كوچكتر',
#   'بردارد',
#   'بياراييد',
#   'نقدى',
#   'مى\u200cبخشيد',
#   'نورشان',
#   'اينجهانى',
#   'اصحاب',
#   'جايشان',
#   'سر',
#   'باريد',
#   'بازمى\u200cگرديم',
#   'سرمايه\u200cشان',
#   'خنك',
#   'نعمتش',
#   'تازيانه',
#   'پيرامونش',
#   'نادانى',
#   'استخوانها',
#   'مى\u200cتوانند',
#   'مكرها',
#   'نهانش\u200cكند',
#   'ميش',
#   'نشناختندش',
#   'هدايت\u200cيافتگان',
#   'رستگارى',
#   'نيازمنديد',
#   'آيتى',
#   'جولانشان',
#   'فاسقى',
#   'انگور',
#   'رسولى',
#   'وقت',
#   'نجاتشان',
#   'بكشى',
#   'ترينشان',
#   'نمازگاه',
#   'مى\u200cميرد',
#   'شصت',
#   'بخشش',
#   'شوند',
#   'پيامبرانش',
#   'نشمرد',
#   'عيبى',
#   'مى\u200cرسند',
#   'آيد',
#   'بازپس\u200cمگرديد',
#   'نداى',
#   'بيهوده\u200cاند',
#   'پايه',
#   'خويش',
#   'دگرگونش',
#   'ابد',
#   'رنگارنگ',
#   'دلها',
#   'صيحه',
#   'مى\u200cكرد',
#   'سرزمينى',
#   'توراتى',
#   'مواظبت',
#   'گوشهايشان',
#   'ناآسان',
#   'گردشان',
#   'ساز',
#   'پدرت',
#   'وظيفه',
#   'مى\u200cدارم',
#   'نصيبى',
#   'مگوييد',
#   'خريد',
#   'معذبشان',
#   'تيمم',
#   'رويانيد',
#   'پيشى',
#   'پروردگارت',
#   'كنندگان',
#   'سعادت',
#   'مقدارى',
#   'صابرانتان',
#   'پروردگارا',
#   'چونان',
#   'نشستن',
#   'گذرگاه',
#   'اين',
#   'كشتى\u200cشكن',
#   'خراجى',
#   'بهره\u200cاى',
#   'مى\u200cخوانندشان',
#   'مرديم',
#   'فرا',
#   'همه',
#   'كتابتان',
#   'خانواده\u200cاش',
#   'گرنه',
#   'موكل',
#   'مكنيد',
#   'بفرستيد',
#   'پاداشى',
#   'الله',
#   'بلنديها',
#   'مجرمانيد',
#   'مبرايش',
#   'نيستم',
#   'بندگى',
#   'شكنجه\u200cهاى',
#   'فسادكنندگان',
#   'علمش',
#   'بشارتتان',
#   'چشمه\u200cسارانند',
#   'بترسد',
#   'كاش',
#   'راه\u200cمانده',
#   'برمى\u200cگردانند',
#   'فتنه\u200cجويى',
#   'حسرتى',
#   'حوران',
#   'مخالفان',
#   'رويشان',
#   'منات',
#   'پشيمان',
#   'وجود',
#   'آبستن\u200cكننده',
#   'آويخت',
#   'آورد',
#   'مساكنشان',
#   'گنهكارى',
#   'بسزا',
#   'بگذار',
#   'بچشاند',
#   'ترسيدم',
#   'بز',
#   'بيشترتان',
#   'نياورم',
#   'بدبخت',
#   'گامى',
#   'تجارتشان',
#   'گرفته\u200cاى',
#   'كمينگاه',
#   'كفار',
#   'بازداشتند',
#   'ياد',
#   'مشاركتى',
#   'نصرانى',
#   'جانهايى',
#   'تقدير',
#   'آخرت',
#   'بينند',
#   'يافته\u200cاند',
#   'خدايانتان',
#   'بدانيد',
#   'گرانشان',
#   'پرردگارش',
#   'جبرئيل',
#   'حقى',
#   'چيزهايى',
#   'گمراه\u200cكنندگان',
#   'طلبيدند',
#   'يافتم',
#   'پوشيدن',
#   'عفوكننده',
#   'نمى\u200cطلبم',
#   'سنگهايى',
#   'مدد',
#   'شناخته\u200cايد',
#   'وام',
#   'گرفتارند',
#   'ديگرش',
#   'بخوريد',
#   'مددش',
#   'رهبرى',
#   'گردانيديم',
#   'بگرويد',
#   'جماع',
#   'مى\u200cشنوى',
#   'پناهگاهى',
#   'بفرست',
#   'رويانيده\u200cايم',
#   'زيورهاى',
#   'مناسكتان',
#   'دريابد',
#   'بستر',
#   'دربندماندگان',
#   'فروبر',
#   'ذرات',
#   'بازگشتى',
#   'عذرها',
#   'مكانش',
#   'دويدند',
#   'بيان',
#   'كوتاه',
#   'سرخ',
#   'گريبان',
#   'تمام\u200cكردن',
#   'باشم',
#   'هوش',
#   'مى\u200cشنوند',
#   'گذرگاهى',
#   'جويبارانند',
#   'دراندازد',
#   'بيزارند',
#   'پديدار',
#   'نكشد',
#   'وعده\u200cهايى',
#   'جوشان',
#   'گمگشته',
#   'اخروى',
#   'حيرانشان',
#   'قلاده',
#   'سپاسگزاران',
#   'نكنيم',
#   'لكن',
#   'مى\u200cورزد',
#   'ترسناك',
#   'خواهرت',
#   'مى\u200cخنديد',
#   'گردد',
#   'كنندگانند',
#   'مى\u200cخواهد',
#   'آب\u200cآورشان',
#   'دروغگو',
#   'نيروى',
#   'ميرانم',
#   'كوچكى',
#   'جن',
#   'جهودان',
#   'آموخته\u200cاند',
#   'ورزيده\u200cايد',
#   'تسليمشان',
#   'سازند',
#   'كام',
#   'مى\u200cنمايند',
#   'وعده\u200cشان',
#   'ملحق',
#   'اخراج',
#   'حجتشان',
#   'تجاوزكنندگان',
#   'قبل',
#   'غواصى',
#   'خواهند',
#   'بناهايش',
#   'طلا',
#   'درستش',
#   'بسنده\u200cاى',
#   'شيوه',
#   'نمى\u200cدانستيد',
#   'فرستاده\u200cاى',
#   'نيافته\u200cاند',
#   'خداوند',
#   'خاكسترى',
#   'آسمانهاى',
#   'فربهى',
#   'ساختيد',
#   'پر',
#   'كسانم',
#   'عذابهاى',
#   'نزديك\u200cتر',
#   'زنده',
#   'وعده\u200cها',
#   'داشتنى\u200cتر',
#   'بلعيد',
#   'پايدارى',
#   'بنى',
#   'زنده\u200cاى',
#   'بازگرديم',
#   'زكات',
#   'مادر',
#   'افزوده',
#   'پيروزمندتر',
#   'نمى\u200cيابند',
#   'لغوتان',
#   'چسبيده',
#   'بازدارد',
#   'بپراكند',
#   'افشردنيها',
#   'مهتران',
#   'مشماريد',
#   'مستوجب',
#   'حدود',
#   'خوف',
#   'شنوند',
#   'بى\u200cگناه',
#   'سومين',
#   'شايان',
#   'بريم',
#   'بعدا',
#   'اينچنين',
#   'سجده\u200cاى',
#   'الحساب',
#   'بى\u200cكتاب',
#   'درازا',
#   'حاضرانتان',
#   'موجود',
#   'خردند',
#   'فرمان',
#   'تعدى\u200cاش',
#   'عيب',
#   'فراوان\u200cتر',
#   'ملائكه',
#   'مقرب\u200cترين',
#   'بدگويى',
#   'باريك',
#   'مأخوذند',
#   'نمى\u200cگيرم',
#   'عظيم\u200cتر',
#   'نوشنده',
#   'بعيد',
#   'اسرائيلش',
#   'سخن\u200cچينى',
#   'يارى',
#   'اداى',
#   'مرواريدهايى',
#   'بايستند',
#   'بساخت',
#   'نرهاند',
#   'آتششان',
#   'بدانيم',
#   'ناگوارتر',
#   'بى\u200cمهر',
#   'گنهكار',
#   'سپاسى',
#   'نسزد',
#   'بعض',
#   'نمى\u200cآفريند',
#   'بى\u200cدرنگ',
#   'رستگارند',
#   'نشنود',
#   'بچرخد',
#   'نهفته',
#   'نكشيد',
#   'دانايم',
#   'قوتشان',
#   'گذار',
#   'ذره\u200cاى',
#   'آمده\u200cاى',
#   'خواسته\u200cاند',
#   'وارثانى',
#   'شكنى',
#   'حكم',
#   'معجزه',
#   'زيان\u200cديدگان',
#   'مكانتى',
#   'يابد',
#   'شام',
#   'شنيدند',
#   'برسانى',
#   'بركنيم',
#   'حكيم',
#   'خرند',
#   'شرابى',
#   'مى\u200cشمريم',
#   'فرشهايى',
#   'نازك',
#   'خلقى',
#   'سخت\u200cدل',
#   'غرفه\u200cهايى',
#   'بعل',
#   'تابستانى',
#   'بنگرد',
#   'نخواسته\u200cام',
#   'پروردگانشان',
#   'فرشى',
#   'لبريز',
#   'مى\u200cزند',
#   'درگاه',
#   'بينى',
#   'بركنده\u200cايم',
#   'برمى\u200cگزيد',
#   'آغاز',
#   'تأخيرافكندن',
#   'يتيم',
#   'دهان',
#   'نمى\u200cكرده',
#   'گفته',
#   'موافقت',
#   'بشنويد',
#   'بجنگيد',
#   'اندرون',
#   'كافران',
#   'شكافى',
#   'تفرقه',
#   'كاتبانى',
#   'گردنش',
#   'نياموخته\u200cايم',
#   'رويان',
#   'بسترى',
#   'نگفتم',
#   'مى\u200cافكنيد',
#   'پوشدش',
#   'شهادتشان',
#   'آوردگان',
#   'يار',
#   'مى\u200cنوشيد',
#   'تقاضا',
#   'نمى\u200cترسم',
#   'مجنون',
#   'گمراهى',
#   'حوادث',
#   'حاضرش',
#   'اندرزهايى',
#   'نگهبانى',
#   'زنى',
#   'رنگش',
#   'ناسپاس',
#   'كشاند',
#   'طاغوت',
#   'ائتلافشان',
#   'كافور',
#   'مى\u200cپسندد',
#   'مى\u200cترسانيم',
#   'لرزانند',
#   'افتد',
#   'نباتى',
#   'مصفى',
#   'استخوانهاى',
#   'صاحبانشان',
#   'دفن',
#   'منزلهايى',
#   'منزلگاهشان',
#   'سرتان',
#   'حالتى',
#   'نگذرد',
#   'كارسازى',
#   'آى',
#   'درباره',
#   'بكوشيد',
#   'ناكرده',
#   'مادرتان',
#   'نفرت',
#   'ديدارشان',
#   'مخوانيد',
#   'بنويسيد',
#   'همتايان',
#   'غايب',
#   'احوال',
#   'دفاعى',
#   'آمده\u200cايم',
#   'بيفتاد',
#   'اولوالعزم',
#   'انديشه\u200cاى',
#   'برادرم',
#   'نخل',
#   'فضيلتى',
#   'شكر',
#   'نخستينش',
#   'عمه\u200cهايتان',
#   'مشعرالحرام',
#   'درمى\u200cيافتند',
#   'مداومت',
#   'هوا',
#   'اينجاست',
#   'داستانهايشان',
#   'يازند',
#   'غافل',
#   'مسكين',
#   'گرديدى',
#   'مأمورم',
#   'عقوبات',
#   'مى\u200cخوانديم',
#   'موجش',
#   'كليدهايش',
#   'فرمانبرداران',
#   'شمرى',
#   'صدقه\u200cاى',
#   'سرانجامى',
#   'درآور',
#   'نمى\u200cفرستم',
#   'نجواكردن',
#   'متمايل',
#   'غنيمت',
#   'آفريدگارتان',
#   'پرستيده\u200cاند',
#   'دانايان',
#   'بروى',
#   'گير',
#   'طوفانشان',
#   'بياموزد',
#   'بازمى\u200cداريد',
#   'كليساها',
#   'آوازى',
#   'آنهايى',
#   'شفيعانتان',
#   'قصرها',
#   'نگاه',
#   'پنجم',
#   'راستت',
#   'فرشتگانش',
#   'خواهشهايشان',
#   'بسيارشان',
#   'زودتر',
#   'ميانه\u200cرو',
#   'ترسانند',
#   'تنگنايى',
#   'پرده\u200cاى',
#   'كارگزاريشان',
#   'چراغها',
#   'گرفتن',
#   'انسان',
#   'گريخت',
#   'بيفزاى',
#   'مى\u200cتوانستند',
#   'كلوخ',
#   'آفريدگان',
#   'گزيد',
#   'خوراك',
#   'نافرمانيشان',
#   'ارث',
#   'كامل',
#   'درجات',
#   'فروگرفتشان',
#   'كنيزان',
#   'آنجايها',
#   'رودخانه',
#   'برگردانند',
#   'هلاك',
#   'فهمند',
#   'بخواهى',
#   'نكشته',
#   'خائنانه\u200cشان',
#   'صخره',
#   'غيبتش',
#   'هشدار',
#   'اندوهگينتان',
#   'درس',
#   'مى\u200cآفرينم',
#   'بسيارى',
#   'حكايت',
#   'ماندنى\u200cتر',
#   'خواركننده\u200cتر',
#   'كاخى',
#   'بهروزى',
#   'نستانند',
#   'عذابمان',
#   'تاريكيهاى',
#   'مى\u200cتوانيد',
#   'بالاى',
#   'غواص',
#   'بى\u200cخردانند',
#   'نقش',
#   'نتيجه',
#   'ابا',
#   'صدقه\u200cدهندگان',
#   'ايستاده',
#   'گرگ',
#   'مغفرت',
#   'تعرض',
#   'مولايش',
#   'خواركننده',
#   'اسرافكاران',
#   'فراراهش',
#   'برمى\u200cآورد',
#   'ريگ',
#   'كتابهاى',
#   'بيشترين',
#   'آسانى',
#   'سقفهايشان',
#   'تهمتى',
#   'منع\u200cكردن',
#   'مى\u200cنهاديم',
#   'آهنين',
#   'ستيزه',
#   'برنخاسته\u200cاند',
#   'فروگرفتن',
#   'جست',
#   'داده\u200cايم',
#   'مى\u200cايستادى',
#   'انحراف',
#   'آفرينم',
#   'تشنه\u200cكام',
#   'عده',
#   'جاويدانى',
#   'پايبند',
#   'پدرانمان',
#   'تسلط',
#   'نتوانم',
#   'نموده',
#   'تخت',
#   'مسيحيان',
#   'فرودين',
#   'مهمانسرايشان',
#   'نكشند',
#   'توبه\u200cاى',
#   'مدانيد',
#   'داشتم',
#   'فرزند',
#   'پيرايه',
#   'نردبانى',
#   'متلاشى',
#   'ديندارى',
#   'مشغول',
#   'ناشده',
#   'نفقه\u200cشان',
#   'مستى\u200cآور',
#   'ياوران',
#   'برمى\u200cكشيم',
#   'عقل',
#   'مدتش',
#   'جهت',
#   'درهاى',
#   'ستاره',
#   'نمى\u200cافكند',
#   'كشيده',
#   'مى\u200cريزم',
#   'خاصه',
#   'برده\u200cايم',
#   'مى\u200cدهيم',
#   'برند',
#   'مكتوب',
#   'بستاى',
#   'مالى',
#   'فشرده\u200cاند',
#   'درنمى\u200cيافتيد',
#   'بيعت',
#   'چرم',
#   'تكذيب\u200cكنندگان',
#   'بفريفته',
#   'سرزمينشان',
#   'نكاهد',
#   'بگيرند',
#   'طالوت',
#   'آغشته',
#   'كافر',
#   'زار',
#   'مى\u200cشود',
#   'رسواييشان',
#   'نكنيد',
#   'نامه\u200cاش',
#   'راهبرانى',
#   'نمى\u200cشمارى',
#   'مى\u200cنامند',
#   'نبوده\u200cاى',
#   'مؤمنانند',
#   'گناهشان',
#   'خواهران',
#   'چهره',
#   'اخبار',
#   'نتوانى',
#   'آبشان',
#   'زنند',
#   'حقانيت',
#   'زكريا',
#   'آموخت',
#   'داريم',
#   'پسرش',
#   'عرفات',
#   'اعضايت',
#   'حجتها',
#   'مى\u200cدهيد',
#   'بازگردد',
#   'گريان',
#   'مى\u200cگرديدم',
#   'ندانند',
#   'گونه\u200cهاى',
#   'داناييم',
#   'نيافت',
#   'جامدند',
#   'نكنند',
#   'زردگونند',
#   'واگذاريم',
#   'نيستند',
#   'عبرتى',
#   'سوار',
#   'مى\u200cانداختى',
#   'هراسى',
#   'شكستنشان',
#   'گفتن',
#   'پوستهايشان',
#   'خريداران',
#   'نمى\u200cستانيد',
#   'نكرديم',
#   'غرقه\u200cاند',
#   'سيرند',
#   'بقاست',
#   'داناست',
#   'دگرگون',
#   'ناحق',
#   'متجاوزان',
#   'دانستند',
#   'خاطر',
#   'سجده\u200cكنان',
#   'نمى\u200cپذيرند',
#   'حكمت',
#   'ندهى',
#   'پندارهاى',
#   'گشتن',
#   'زبان\u200cبازى',
#   'مى\u200cكنيم',
#   'مولايت',
#   'آزموده\u200cايم',
#   'خوش\u200cطعم',
#   'درياى',
#   'نيافته\u200cاى',
#   'زيان\u200cديده',
#   'قرارى',
#   'گوساله\u200cاى',
#   'كناره',
#   'باغى',
#   'تصرف',
#   'ميانين',
#   'پس\u200cمانده',
#   'نيرنگ',
#   'مؤمنانى',
#   ...},
#  'bahrampour.xml': {'شيرين',
#   'صورتگر',
#   'ببين',
#   'عداوت',
#   'مهاجران',
#   'تكه',
#   'تقدم',
#   'سيطره',
#   'ساكنانش',
#   'محنتى',
#   'نمى\u200cتوانست',
#   'فرما',
#   'مشوش',
#   'اكنون',
#   'چراغى',
#   'نزاده',
#   'بيجا',
#   'بنمايم',
#   'نهرهايى',
#   'قربانگاهى',
#   'ك',
#   'دستخوش',
#   'آتشبانان',
#   'پيامبران',
#   'معبودى',
#   'جزئى',
#   'زندگان',
#   'مى\u200cافتادند',
#   'مارى',
#   'نوشته\u200cاى',
#   'وامانده\u200cاند',
#   'العزم',
#   'مى\u200cبرم',
#   'بوزينگانى',
#   'نفس',
#   'بورزند',
#   'گلوگير',
#   'برگماشت',
#   'اسب\u200cهاى',
#   'برديم',
#   'برادرى',
#   'وانگهى',
#   'گنگانند',
#   'پروا',
#   'نشين',
#   'زايل',
#   'رفيقشان',
#   'آرند',
#   'باغستان',
#   'ندارم',
#   'مهلتم',
#   'برنده',
#   'گوى',
#   'شبهات\u200c',
#   'حامى',
#   'نخل\u200cهاى',
#   'يادشان',
#   'بيفكنديم',
#   'جاودانان',
#   'كج',
#   'بزرگان',
#   'مرتبه\u200c',
#   'قوى',
#   'پسران',
#   'آر',
#   'زمينند',
#   'جاهلند',
#   'زمينى\u200c',
#   'سرگذشت',
#   'چگونه\u200c',
#   'واگذاشته\u200c',
#   'ناب',
#   'داشتيد',
#   'العالمين',
#   'مى\u200cرسيدم',
#   'آنجا',
#   'مهربانم',
#   'قسمتى',
#   'حسابگران',
#   'درجه\u200cها',
#   'اينك',
#   'بركنده',
#   'پليدكارى',
#   'مولايى',
#   'توكل',
#   'خودتان',
#   'بهشتى',
#   'اعمالتان',
#   'كوچ',
#   'آراستيم',
#   'جاسوسانى',
#   'نتيجه\u200cى\u200c',
#   'ضررى',
#   'آن\u200cها',
#   'هدايتگر',
#   'متعلق',
#   'جويبارها',
#   'رويت',
#   'ن',
#   'بزرگ\u200cتر',
#   'مهلتى',
#   'همان',
#   'بگويى',
#   'وقتى',
#   'هنگام\u200c',
#   'ساجد',
#   'ابن',
#   'متكبرانه',
#   'بى\u200cرغبت',
#   'بزرگى\u200c',
#   'مسلح',
#   'بيايى',
#   'بيابان\u200cها',
#   'دادگرى',
#   'خاص\u200c',
#   'پست\u200cترين\u200cها',
#   'ببار',
#   'مسئوليت\u200c',
#   'اشترانى',
#   'كهن',
#   'چشيدند',
#   'آورده\u200cايم',
#   'رويانديم',
#   'نوشته\u200cهاى\u200c',
#   'قريب',
#   'مساجد',
#   'تذكرى',
#   'لابه\u200cلاى\u200c',
#   'سهمى',
#   'نباشى\u200c',
#   'زخم\u200cهاى',
#   'حكم\u200c',
#   'پيرزنم',
#   'مطيعان',
#   'ببينيم',
#   'صدايى',
#   'نمرده',
#   'داورى\u200c',
#   'دروغى',
#   'كشتزار',
#   'نافرمان',
#   'توصيه',
#   'برجى',
#   'گواهان',
#   'نخوان',
#   'كشتند',
#   'بستيم',
#   'رجا',
#   'بسوزانيد',
#   'گفتى',
#   'ببيند',
#   'موعد',
#   'نرسيده\u200cاست',
#   'عذابند',
#   'بازخريد',
#   'نيكوكاران',
#   'الفاسقون',
#   'آفرينش',
#   'كوبنده',
#   'باگذشت',
#   'تقرب',
#   'ندادند',
#   'آزمايشند',
#   'زحمت',
#   'شاه',
#   'وظيفه\u200c',
#   'فرياد',
#   'ندانسته\u200cاى',
#   'نرسيده\u200cاند',
#   'نمى\u200cگردند',
#   'اسب\u200cها',
#   'سراغ',
#   'موعدشان',
#   'بجز',
#   'نماينده\u200cى',
#   'انگورها',
#   'سنگريزه\u200cها',
#   'افكندم',
#   'مردنى',
#   'سازگارى',
#   'فرستاده',
#   'آدم\u200c',
#   'طرح\u200cريزى',
#   'مشغولش',
#   'لبه',
#   'هدايت',
#   'محصولات',
#   'مى\u200cگذاريم\u200c',
#   'مشت',
#   'آنان\u200c',
#   'هشتاد',
#   'بى\u200cشكست',
#   'نمازهايشان',
#   'تاريك',
#   'گريه',
#   'تبديلى',
#   'دعاهايى',
#   'شركاى',
#   'آمده\u200cام',
#   'تلخ\u200c',
#   'قرائت',
#   'نپذيريد',
#   'حكمت\u200c',
#   'كبرياست',
#   'دشوار',
#   'انس\u200c',
#   'فرزندانش',
#   'نمى\u200cآوردند',
#   'سوره\u200cى',
#   'برسند',
#   'نيارند',
#   'نمى\u200cشنويد',
#   'خران',
#   'كارى',
#   'امامشان',
#   'بسا',
#   'وعدگاه',
#   'كاغذى',
#   'آشفته',
#   'مى\u200cجستند',
#   'زنده\u200cى',
#   'عبادات',
#   'مظلوم',
#   'مى\u200cخفتند',
#   'مى\u200cگرفت',
#   'مبنى',
#   'نپرستيم',
#   'فرستاده\u200cى',
#   'استخوانم',
#   'لجن',
#   'افول',
#   'لازم\u200c',
#   'الكفل',
#   'بخشيديم',
#   'نمى\u200cيابم',
#   'فريب',
#   'زدن',
#   'بهشتيان\u200c',
#   'ستد',
#   'پوسيده',
#   'سرعت\u200c',
#   'همسايه',
#   'مى\u200cطلبد',
#   'كوشش',
#   'صبحدم',
#   'مى\u200cپندارند',
#   'مپندار',
#   'نيستيم',
#   'شدنش',
#   'سوت',
#   'باربر',
#   'زودى',
#   'نز',
#   'كفرآميز',
#   'سواى',
#   'مردمى\u200c',
#   'خيرخواه',
#   'مبغوض',
#   'آفاق',
#   'بازماندگان',
#   'برسيد',
#   'رسا',
#   'مى\u200cپيچد',
#   'آمده\u200cام\u200c',
#   'مى\u200cشناسيم',
#   'دروغبافى',
#   'مى\u200cشوم',
#   'برج\u200cها',
#   'فرزندانى',
#   'ميانسالى',
#   'برهانى',
#   'خاك\u200cنشين',
#   'بيماردلان',
#   'اصلاحگرانيم',
#   'مى\u200cگرديم',
#   'معينى',
#   'مهربان\u200cتر',
#   'طعنه\u200c',
#   'خوشى\u200cهاى\u200c',
#   'درجاتى',
#   'گام',
#   'بشماريد',
#   'يدعون',
#   'قوم',
#   'سنگسارت',
#   'درماندگان',
#   'استهزا',
#   'خلاف\u200cهايى',
#   'خصم\u200cاند',
#   'چهره\u200cهاى',
#   'سوره',
#   'مى\u200cرود',
#   'تختى',
#   'ثلث',
#   'نمى\u200cپردازيد',
#   'نمى\u200cك',
#   'اندازه\u200cگيرى\u200c',
#   'مى\u200cخواهيم\u200c',
#   'مى\u200cداري',
#   'رسانده\u200cاند',
#   'آلوده',
#   'چيز',
#   'گن',
#   'نمى\u200cتوانستيد',
#   'دنيايى',
#   'بندگان\u200c',
#   'افشاگر',
#   'اعجاز',
#   'عمرشان',
#   'شدنى',
#   'راستى\u200cشان',
#   'وصف',
#   'درمانده\u200cى',
#   'خالقى\u200c',
#   'كفران',
#   'حمايتگرى',
#   'وسايل',
#   'نكرد',
#   'پيشه',
#   'مى\u200cگويد',
#   'هنوز',
#   'ه',
#   'اقتدار',
#   'پيدايش',
#   'آينده',
#   'طاغى\u200cتر',
#   'مشاهده',
#   'كلانى',
#   'چاه\u200cهاى',
#   'مى\u200cپرستيده\u200cايد',
#   'خشنودند',
#   'ايراد',
#   'نظرشان',
#   'مى\u200cپرستيم',
#   'نكشيدند',
#   'خصومت',
#   'قسم',
#   'چهره\u200cاش',
#   'عايد',
#   'درك',
#   'غذاهاى',
#   'چهل',
#   'جمعيتشان',
#   'مرواريد',
#   'مى\u200cگفت\u200c',
#   'منادى',
#   'مى\u200cخوردند',
#   'موجب\u200c',
#   'سرگرم',
#   'نگذارند',
#   'بى\u200cكم',
#   'مبتلا',
#   'تاكنون\u200c',
#   'مى\u200cنوشد',
#   'رهايش',
#   'ذبح\u200c',
#   'سالها',
#   'خضر',
#   'گريزشان',
#   'عرف',
#   'دزد',
#   'مى\u200cرانى',
#   'شكوهمند',
#   'وحشت\u200c',
#   'ص',
#   'منهيد',
#   'مى\u200cنمود',
#   'مستى',
#   'پرتاب',
#   'هميشه',
#   'بازگشتند',
#   'باك\u200c',
#   'بازگشته\u200cايم',
#   'پنداشته\u200cايد',
#   'پليديشان',
#   'مسيحى',
#   'تشعشعى',
#   'بردارد',
#   'مى\u200cبخشيد',
#   'گذشت\u200c',
#   'نورشان',
#   'اصحاب',
#   'نخوت\u200c',
#   'جايشان',
#   'نمى\u200cبرد',
#   'سر',
#   'انداختند',
#   'باريد',
#   'سرمايه\u200cشان',
#   'خنك',
#   'نعمتش',
#   'تازيانه',
#   'كارنامه\u200cاى',
#   'مى\u200cزنم',
#   'متأخرند',
#   'نادانى',
#   'مى\u200cتوانند',
#   'چشمش',
#   'رسولانم',
#   'سويت',
#   'بياسايند',
#   'ميش',
#   'سرپرستانشان',
#   'مشابهش',
#   'نمى\u200cخورد',
#   'نيازمنديد',
#   'بردگان',
#   'آيتى',
#   'فاسقى',
#   'قسم\u200cهاى',
#   'انگور',
#   'رسولى',
#   'رهروان',
#   'نوشانديم',
#   'وقت',
#   'نجاتشان',
#   'نجوايتان',
#   'بكشى',
#   'علاقه',
#   'مى\u200cميرد',
#   'شصت',
#   'بخشش',
#   'شوند',
#   'آذوقه',
#   'پيامبرانش',
#   'عيبى',
#   'آسانى\u200c',
#   'مى\u200cرسند',
#   'وعده\u200cگاه\u200c',
#   'آيد',
#   'مى\u200cنازيديد',
#   'نداى',
#   'پايه',
#   'خويش',
#   'دگرگونش',
#   'ابد',
#   'رنگارنگ',
#   'خورده\u200cى',
#   'صيحه',
#   'مى\u200cكرد',
#   'سرزمينى',
#   'مواظبت',
#   'شبانه\u200cروز',
#   'گردشان',
#   'ساز',
#   'نسوزد',
#   'پدرت',
#   'برخى\u200cتان\u200c',
#   'قرب',
#   'برده\u200cايد',
#   'وظيفه',
#   'مى\u200cدارم',
#   'نصيبى',
#   'خريد',
#   'مگوييد',
#   'نامه\u200cام',
#   'رويانيد',
#   'پيشى',
#   'عبرت\u200cآموز',
#   'پروردگارت',
#   'كنندگان',
#   'سعادت',
#   'مقدارى',
#   'پروردگارا',
#   'چونان',
#   'اين',
#   'بهره\u200cاى',
#   'گرداندند',
#   'مرديم',
#   'مقاماتى',
#   'فرا',
#   'نزديكتان',
#   'همه',
#   'زشتكارى\u200cها',
#   'كتابتان',
#   'خانواده\u200cاش',
#   'زده\u200cايم',
#   'راستين\u200c',
#   'مكنيد',
#   'بفرستيد',
#   'صدوركم',
#   'مخلصان',
#   'بخورم',
#   'الله',
#   'پاداشى',
#   'دل\u200cهاى',
#   'عجب',
#   'دارندگان',
#   'همزيستى',
#   'نيستم',
#   'بندگى',
#   'برمى\u200cداشتيم',
#   'پيروزتان',
#   'چشمه\u200cسارانند',
#   'تربيت',
#   'مكه\u200c',
#   'بترسد',
#   'كاش',
#   'برمى\u200cگردانند',
#   'فتنه\u200cجويى',
#   'حسرتى',
#   'پروردگ',
#   'مخالفان',
#   'رويشان',
#   'برمى\u200cگرداند',
#   'پشيمان',
#   'حوران',
#   'منات',
#   'وجود',
#   'مى\u200cتوانم\u200c',
#   'اطاعت\u200c',
#   'آويخت',
#   'بت\u200cهاى\u200c',
#   'آورد',
#   'معبودهايتان',
#   'بگذار',
#   'دردناك\u200c',
#   'بچشاند',
#   'ترسيدم',
#   'بز',
#   'اين\u200cها',
#   'اله',
#   'گامى',
#   'بى\u200cنيازى',
#   'بسته\u200cايم',
#   'تجارتشان',
#   'گرفته\u200cاى',
#   'سنگر',
#   'موسم',
#   'كفار',
#   'آزادى',
#   'الامر',
#   'بازداشتند',
#   'نبرده\u200cايد',
#   'كارشان\u200c',
#   'ياد',
#   'روشنگرانه',
#   'مشاركتى',
#   'دعاست',
#   'نصرانى',
#   'تقدير',
#   'مى\u200cچشانديم',
#   'مباركى',
#   'آخرت',
#   'بينند',
#   'يافته\u200cاند',
#   'خدايانتان',
#   'بدانيد',
#   'هشدارتان',
#   'جبرئيل',
#   'يك\u200c',
#   'على',
#   'حقى',
#   'تار',
#   'آبم',
#   'چيزهايى',
#   'يافتم',
#   'دفاع\u200c',
#   'سالم',
#   'دوزند',
#   'رحم\u200cهاست',
#   'مدد',
#   'وام',
#   'نمانده',
#   'النون',
#   'گرفتارند',
#   'بخوريد',
#   'رهبرى',
#   'گردانيديم',
#   'بگرويد',
#   'مى\u200cشنوى',
#   'پناهگاهى',
#   'بفرست',
#   'معبودانشان',
#   'زيورهاى',
#   'مجسمه\u200cها',
#   'امتناع',
#   'ستمكارند',
#   'دريابد',
#   'اجابتتان',
#   'بستر',
#   'بازگشتى',
#   'غذايمان',
#   'بيان',
#   'كوتاه',
#   'شگفت\u200cآور',
#   'سرخ',
#   'گريبان',
#   'هوش',
#   'باشم',
#   'مى\u200cشنوند',
#   'بيزارند',
#   'پديدار',
#   'خوابند',
#   'مقتول\u200c',
#   'مى\u200cشكنيد',
#   'خوا',
#   'جوشان',
#   'تگرگى',
#   'نمايانگر',
#   'مركز',
#   'راههاى',
#   'برپائيش',
#   'دانسته\u200cايد',
#   'رطب',
#   'سپاسگزاران',
#   'نكنيم',
#   'لكن',
#   'نيمه\u200c',
#   'صورتتان',
#   'مى\u200cورزد',
#   'گورش',
#   'افكار',
#   'خواهرت',
#   'مى\u200cخنديد',
#   'گردد',
#   'مى\u200cخواهد',
#   'دروغگو',
#   'نيروى',
#   'ملتزم',
#   'جن',
#   'عامى',
#   'نادان\u200cها',
#   'خروج',
#   'هيبت\u200c',
#   'سازند',
#   'كام',
#   'مى\u200cنمايند',
#   'وعده\u200cشان',
#   'كوفت',
#   'كسانى\u200cاند',
#   'ملحق',
#   'اخراج',
#   'قبل',
#   'غواصى',
#   'مى\u200cچشند',
#   'خواهند',
#   'طلا',
#   'شيوه',
#   'نمى\u200cدانستيد',
#   'مسير',
#   'فرستاده\u200cاى',
#   'روزه\u200cگير',
#   'آرمان',
#   'برگرداند',
#   'نيافته\u200cاند',
#   'خداوند',
#   'خاكسترى',
#   'كامل\u200cكننده\u200cى',
#   'مردها',
#   'پر',
#   'كسانم',
#   'داورانى',
#   'دلسوز',
#   'نزديك\u200cتر',
#   'زنده',
#   'باغ\u200cهاى',
#   'دستم',
#   'بلعيد',
#   'پايدارى',
#   'قدرت\u200c',
#   'بنى',
#   'زنده\u200cاى',
#   'نام\u200c',
#   'بازگرديم',
#   'زكات',
#   'تغذيه',
#   'معادى',
#   'مادر',
#   'بى\u200cخردانه',
#   'سنجش',
#   'نمى\u200cيابند',
#   'امرش\u200c',
#   'لگدمال',
#   'جمعيت',
#   'چسبيده',
#   'دنيايند',
#   'بازدارد',
#   'پشيما',
#   'سركردگان',
#   'مهتران',
#   'استفاده',
#   'بناى',
#   'حدود',
#   'خوف',
#   'پذيرايى',
#   'شنوند',
#   'سومين',
#   'رويارويشان',
#   'سختدلان',
#   'بعدا',
#   'بى\u200cآلايش',
#   'سجده\u200cاى',
#   'الحساب',
#   'موجود',
#   'فرمان',
#   'موقعيتى\u200c',
#   'عيب',
#   'بتابد',
#   'ملائكه',
#   'استراحتگاهشان',
#   'گيرندگان',
#   'عملكرد',
#   'باريك',
#   'فروتنان',
#   'همان\u200cگونه',
#   'بدى\u200c',
#   'عذاب\u200c',
#   'تقرب\u200c',
#   'عظيم\u200cتر',
#   'پشم\u200c',
#   'پندگيرى',
#   'زشتى\u200cهاشان',
#   'مى\u200cانگارم',
#   'نمى\u200cتوانيم',
#   'بعيد',
#   'شكستشان',
#   'يارى',
#   'اداى',
#   'بامدادى',
#   'مرواريدهايى',
#   'بايستند',
#   'مى\u200cگرفتم',
#   'انكارشان\u200c',
#   'بساط',
#   'بدانيم',
#   'مى\u200cتراشيدند',
#   'سعادتى',
#   'گنهكار',
#   'فراموششان',
#   'سپاسى',
#   'نسزد',
#   'پرستى',
#   'حسابشان\u200c',
#   'تشريع',
#   'بى\u200cدرنگ',
#   'نمى\u200cآفريند',
#   'رستگارند',
#   'نشنود',
#   'بى\u200cاجازه\u200cى',
#   'خيلى',
#   'مى\u200cشوى\u200c',
#   'نهفته',
#   'نكشيد',
#   'گذار',
#   'ذره\u200cاى',
#   'آمده\u200cاى',
#   'وارثانى',
#   'فرستاده\u200cاش',
#   'حكم',
#   'بندگى\u200c',
#   'عوض\u200c',
#   'معجزه',
#   'دوشيزه',
#   'يابد',
#   'لباسيد',
#   'خواهانيم',
#   'مارشان',
#   'شام',
#   'نداشتيد',
#   'شنيدند',
#   'معاد',
#   'پى\u200cجويانه',
#   'برسانى',
#   'سلطه\u200cاى',
#   'حكيم',
#   'شرابى',
#   'نازك',
#   'برندارى',
#   'موجهى',
#   'عيبجوست',
#   'غرفه\u200cهايى',
#   'بعل',
#   'سرنوشتى',
#   'تابستانى',
#   'بنگرد',
#   'فرشى',
#   'نگهبان\u200c',
#   'زبان\u200c',
#   'مى\u200cزند',
#   'درگاه',
#   'بينى',
#   'برمى\u200cگزيد',
#   'صورتگرى',
#   'آغاز',
#   'يتيم',
#   'دهان',
#   'سپردند',
#   'حوزه',
#   'گفته',
#   'بشنويد',
#   'بجنگيد',
#   'نمى\u200cنهد',
#   'اندرون',
#   'كافران',
#   'شكافى',
#   'تفرقه',
#   'گردنش',
#   'خوردن\u200c',
#   'مقررى',
#   'بسترى',
#   'خاشاكى',
#   'زيادتر',
#   'نگفتم',
#   'مى\u200cكن',
#   'مى\u200cنوشيد',
#   'يار',
#   'تقاضا',
#   'سازشى',
#   'مجنون',
#   'گمراهى',
#   'حوادث',
#   'نگهبانى',
#   'زنى',
#   'ظلم',
#   'پديده\u200cى',
#   'ناسپاس',
#   'روبه',
#   'شوي',
#   'كشاند',
#   'طاغوت',
#   'مى\u200cپسندد',
#   'مى\u200cترسانيم',
#   'پيمانم',
#   'افتد',
#   'پوستشان',
#   'مژده\u200cرسانان',
#   'نمى\u200cگذارد',
#   'تماشاگران',
#   'نوزاد',
#   'خطرات',
#   'ايمانتان\u200c',
#   'مايه\u200cى',
#   'سرتان',
#   'كمى',
#   'مباح',
#   'ساكنيد',
#   'كارسازى',
#   'آى',
#   'سليمان\u200c',
#   'پرده\u200cى',
#   'عليه',
#   'پيامبرم',
#   'تمديد',
#   'دهندگانم',
#   'گنه\u200cپيشگان',
#   'وار',
#   'بكوشيد',
#   'نزاع\u200c',
#   'ندانستى',
#   'نفرت',
#   'وعده\u200cى\u200c',
#   'ضربتى',
#   'بنويسيد',
#   'مخوانيد',
#   'همتايان',
#   'بازگردانديم',
#   'احوال',
#   'ذبحش\u200c',
#   'ى',
#   'غايب',
#   'دفاعى',
#   'روحيه',
#   'برادرم',
#   'عبادتى',
#   'نخل',
#   'فضيلتى',
#   'شكر',
#   'عمه\u200cهايتان',
#   'اموال\u200c',
#   'پوشانده',
#   'هوا',
#   'اينجاست',
#   'پايه\u200c',
#   'ماندگار',
#   'هراسيدند',
#   'بازگردانى',
#   'مسكين',
#   'غافل',
#   'يازند',
#   'مأمورم',
#   'نافرمان\u200cاند',
#   'عقوبات',
#   'نيكى\u200cرسان',
#   'مى\u200cخوانديم',
#   'مختص',
#   'ايشا',
#   'فرمانبرداران',
#   'ضعيفان',
#   'صدقه\u200cاى',
#   'زيتونى',
#   'درآور',
#   'انگيزه\u200cى',
#   'مرزهاى',
#   'بپيچند',
#   'متمايل',
#   'استراحتگاهى',
#   'غنيمت',
#   'آفريدگارتان',
#   'دانايان',
#   'نوادگانش',
#   'گير',
#   'انجامش',
#   'صورت\u200cهاى',
#   'جمال',
#   'بياموزد',
#   'كامل\u200c',
#   'كليساها',
#   'ساقه\u200cاى\u200c',
#   'آنهايى',
#   'چشمه\u200cسارانى',
#   'هيبت',
#   'قصرها',
#   'نگاه',
#   'پنجم',
#   'دل\u200c',
#   'آزادشان',
#   'زودتر',
#   'ترسانند',
#   'برنداشتند',
#   'اقامتگاه\u200cهاى',
#   'ميانه\u200cرو',
#   'سزايش',
#   'پرده\u200cاى',
#   'قدردان',
#   'بازسازيم',
#   'گرفتن',
#   'انسان',
#   'بيفزاى',
#   'گريخت',
#   'اعزام',
#   'ملامتم',
#   'آفريدگان',
#   'گزيد',
#   'روزافزون',
#   'خوراك',
#   'ارث',
#   'كامل',
#   'درجات',
#   'ناخوشايند',
#   'كنيزان',
#   'بنياد',
#   'مغرورانه',
#   'برگردانند',
#   'هلاك',
#   'دلداده\u200cى',
#   'مى\u200cميريد',
#   'مى\u200cگشتيد',
#   'بخواهى',
#   'ناسازگارى',
#   'نگرديدند',
#   'صخره',
#   'ميل\u200c',
#   'استخوان\u200cهايش',
#   'هشدار',
#   'درس',
#   'بسيارى',
#   'مى\u200cشكند',
#   'حكايت',
#   'علت',
#   'ماندنى\u200cتر',
#   'كاخى',
#   'بى\u200cراهه',
#   'مى\u200cتوانيد',
#   'مى\u200cكوبيم',
#   'بالاى',
#   'خانه\u200c',
#   'غواص',
#   'قريش\u200c',
#   'نتيجه',
#   'ابا',
#   'سقف\u200cهايش',
#   'بيم\u200cرسانى',
#   'ايستاده',
#   'ماهرى',
#   'همه\u200cتان',
#   'گرگ',
#   'ايشان\u200cاند',
#   'انابه',
#   'انگيز',
#   'مغفرت',
#   'قاطع',
#   'مالشان',
#   'پاره\u200cهاى',
#   'تعرض',
#   'اسرافكاران',
#   'حقوق',
#   'سخنان\u200c',
#   'درخواست',
#   'ريگ',
#   'كتابهاى',
#   'نمى\u200cگذاشت',
#   'آسانى',
#   'تهمتى',
#   'آفريده\u200cهاى',
#   'مى\u200cنهاديم',
#   'مى\u200cاندازد',
#   'ستيزه',
#   'آهنين',
#   'پيشه\u200cى',
#   ...},
#  'fooladvand.xml': {'شيرين',
#   'صورتگر',
#   'مغاك\u200c',
#   'ببين',
#   'عداوت',
#   'مهاجران',
#   'توانايى\u200cاش',
#   'محنتى',
#   'نمى\u200cتوانست',
#   'فرما',
#   'اكنون',
#   'چراغى',
#   'نزاده',
#   'يادكن\u200c',
#   'بيجا',
#   'نهرهايى',
#   'دستخوش',
#   'آتشبانان',
#   'پيامبران',
#   'معبودى',
#   'جزئى',
#   'زندگان',
#   'مى\u200cافتادند',
#   'مارى',
#   'يادنامه\u200cشان',
#   'نوشته\u200cاى',
#   'پذيريد',
#   'گردانيديم\u200c',
#   'مى\u200cبرم',
#   'بوزينگانى',
#   'نفس',
#   'پردازد',
#   'گلوگير',
#   'اسب\u200cهاى',
#   'برديم',
#   'درآمديد',
#   'ترنجبين',
#   'پروا',
#   'سجودكنندگان',
#   'گشاينده\u200cاى',
#   'موالى',
#   'زايل',
#   'رفيقشان',
#   'آرند',
#   'باغستان',
#   'ندارم',
#   'مهلتم',
#   'اخگر',
#   'گوى',
#   'دستهاى',
#   'يادشان',
#   'شهدى',
#   'بيفكنديم',
#   'جاودانان',
#   'استوارترى',
#   'كج',
#   'سايبانهايى',
#   'مراعات\u200c',
#   'بزرگان',
#   'زمينند',
#   'قوى',
#   'پسران',
#   'آر',
#   'ربوده\u200cاند',
#   'برمگير',
#   'زمينى\u200c',
#   'سرگذشت',
#   'چگونه\u200c',
#   'ناب',
#   'داشتيد',
#   'العالمين',
#   'عاجزند',
#   'مى\u200cرسيدم',
#   'آنجا',
#   'مهربانم',
#   'قسمتى',
#   'اينك',
#   'بركنده',
#   'پليدكارى',
#   'مولايى',
#   'پرداختيد',
#   'توكل',
#   'درگذريم',
#   'دخالت',
#   'خودتان',
#   'بهشتى',
#   'كوچ',
#   'پادشاهانى',
#   'آراستيم',
#   'جاسوسانى',
#   'نجوايى',
#   'فهميدنش',
#   'آن\u200cها',
#   'سرانگشتانشان',
#   'متعلق',
#   'جويبارها',
#   'رويت',
#   'رودهايى',
#   'مهلتى',
#   'همان',
#   'بگويى',
#   'وقتى',
#   'هنگام\u200c',
#   'متكبرانه',
#   'ميانجيگرى',
#   'گردانيدن',
#   'بى\u200cرغبت',
#   'تيره\u200cبختند',
#   'بيايى',
#   'دادگرى',
#   'بدنها',
#   'خاص\u200c',
#   'رداى',
#   'شكارگر',
#   'كهن',
#   'چشيدند',
#   'بدفرجام',
#   'درمى\u200cآورديم',
#   'شبهه\u200cاند',
#   'آورده\u200cايم',
#   'نوشته\u200cهاى\u200c',
#   'گماشتند',
#   'مساجد',
#   'تذكرى',
#   'سهمى',
#   'اجزاء',
#   'لغوى',
#   'افراشتيم',
#   'حكم\u200c',
#   'پيرزنم',
#   'ببينيم',
#   'صدايى',
#   'هدايت\u200cكردن',
#   'نمرده',
#   'حالم',
#   'داورى\u200c',
#   'دروغى',
#   'كشتزار',
#   'نافرمان',
#   'توصيه',
#   'برجى',
#   'خوشه\u200cهاى\u200c',
#   'گواهان',
#   'برترى\u200cجوى',
#   'بستيم',
#   'بيفتيد',
#   'بازگرداننده\u200c',
#   'بسوزانيد',
#   'ببيند',
#   'گفتى',
#   'موعد',
#   'بازخريد',
#   'نيكوكاران',
#   'دانسته\u200cاى',
#   'آفرينش',
#   'امانتى',
#   'كوبنده',
#   'باختر',
#   'نپرورديم',
#   'دركوشند',
#   'دچاراند',
#   'تقرب',
#   'ندادند',
#   'زحمت',
#   'كسانت',
#   'شاه',
#   'فرياد',
#   'ندانسته\u200cاى',
#   'بازنگردانيد',
#   'نرسيده\u200cاند',
#   'وقوف',
#   'نمى\u200cگردند',
#   'سراغ',
#   'انبوه\u200c',
#   'موعدشان',
#   'شكوفه\u200cهايشان',
#   'بجز',
#   'نكشتند',
#   'سنگريزه\u200cها',
#   'افكندم',
#   'سازگارى',
#   'فرستاده',
#   'آدم\u200c',
#   'پست\u200cكننده',
#   'هدايت',
#   'صاحب\u200cتفضل',
#   'محصولات',
#   'كدام\u200c',
#   'آنان\u200c',
#   'هشتاد',
#   'نمازهايشان',
#   'تاريك',
#   'تبديلى',
#   'آمده\u200cام',
#   'نپذيريد',
#   'حكمت\u200c',
#   'دشوار',
#   'انس\u200c',
#   'فرزندانش',
#   'درگذرد',
#   'نمى\u200cآوردند',
#   'برسند',
#   'نمى\u200cشنويد',
#   'پهن',
#   'خران',
#   'كارى',
#   'بسا',
#   'بازگشت\u200cكننده',
#   'وعدگاه',
#   'آشفته',
#   'مى\u200cجستند',
#   'پيوندها',
#   'عبادات',
#   'مظلوم',
#   'مى\u200cگرفت',
#   'شن',
#   'نپرستيم',
#   'استخوانم',
#   'افشانگر',
#   'افول',
#   'لازم\u200c',
#   'بخشيديم',
#   'صمد',
#   'نمى\u200cيابم',
#   'وقتى\u200c',
#   'فريب',
#   'زدن',
#   'رفتنى',
#   'بهشتيان\u200c',
#   'ستد',
#   'پوسيده',
#   'ستيزه\u200cاند',
#   'كوشش',
#   'همسايه',
#   'مى\u200cطلبد',
#   'پاك\u200cشدگان',
#   'موى\u200c',
#   'صبحدم',
#   'آفريده\u200cام',
#   'مى\u200cپندارند',
#   'ملازمش',
#   'سرافكنده',
#   'قفلهايى',
#   'عقيده',
#   'ولادت\u200c',
#   'مپندار',
#   'نيستيم',
#   'متقاعدكننده\u200c',
#   'سوت',
#   'پاداشش',
#   'زودى',
#   'كيفيت\u200c',
#   'سواى',
#   'خيرخواه',
#   'مردمى\u200c',
#   'سردرگم',
#   'بازماندگان',
#   'برسيد',
#   'رسا',
#   'خواستاريد',
#   'كشمكش',
#   'مى\u200cشناسيم',
#   'مى\u200cشوم',
#   'انتشارش',
#   'فرزندانى',
#   'ميانسالى',
#   'فرمانفرمايى',
#   'برهانى',
#   'رحمها',
#   'خاك\u200cنشين',
#   'مى\u200cگرديم',
#   'نامبرده\u200c',
#   'معينى',
#   'طعنه\u200c',
#   'گام',
#   'درجاتى',
#   'بشماريد',
#   'قوم',
#   'سنگسارت',
#   'استهزا',
#   'چهره\u200cهاى',
#   'سوره',
#   'مى\u200cرود',
#   'تختى',
#   'نمى\u200cپردازيد',
#   'اندازه\u200cگيرى\u200c',
#   'رسانده\u200cاند',
#   'گردانيدم',
#   'هركس',
#   'چيز',
#   'نمى\u200cتوانستيد',
#   'دنيايى',
#   'بندگان\u200c',
#   'خضوع',
#   'اعجاز',
#   'عمرشان',
#   'ناخن\u200c',
#   'راستى\u200cشان',
#   'درداده',
#   'وصف',
#   'سريعترين',
#   'كفران',
#   'حمايتگرى',
#   'وسايل',
#   'نكرد',
#   'پيشه',
#   'مى\u200cگويد',
#   'هنوز',
#   'آينده',
#   'هشداردهندگانى',
#   'مشاهده',
#   'مى\u200cپرستيده\u200cايد',
#   'درآميخت',
#   'خشنودند',
#   'ايراد',
#   'سربلندى',
#   'انبوهى\u200c',
#   'نظرشان',
#   'مى\u200cپرستيم',
#   'چهره\u200cاش',
#   'قسم',
#   'وحوش',
#   'عذاب\u200cشدگان',
#   'عايد',
#   'درك',
#   'موجب\u200c',
#   'چهل',
#   'غذاهاى',
#   'راستى\u200c',
#   'مرواريد',
#   'مى\u200cخوردند',
#   'منادى',
#   'قواى',
#   'سرگرم',
#   'روزان',
#   'نگذارند',
#   'مبتلا',
#   'تاكنون\u200c',
#   'مى\u200cنوشد',
#   'معذرتى',
#   'ذبح\u200c',
#   'سالها',
#   'گريزشان',
#   'عرف',
#   'افزونتر',
#   'دزد',
#   'بگذر',
#   'ايمان\u200cآورنده',
#   'مى\u200cرانى',
#   'شكوهمند',
#   'وحشت\u200c',
#   'خوان',
#   'منهيد',
#   'مى\u200cنمود',
#   'مستى',
#   'پرتاب',
#   'هميشه',
#   'حدقه',
#   'مرتد',
#   'بازگشتند',
#   'سم\u200cهاى\u200c',
#   'استاگر',
#   'بازگشته\u200cايم',
#   'پنداشته\u200cايد',
#   'پليديشان',
#   'برخوردارند',
#   'برمى\u200cگرديم',
#   'كوچكتر',
#   'مسيحى',
#   'تشعشعى',
#   'بردارد',
#   'آسمان\u200cگستريم',
#   'نقدى',
#   'نورشان',
#   'اصحاب',
#   'نخوت\u200c',
#   'جايشان',
#   'شرع\u200c',
#   'سر',
#   'چندى\u200c',
#   'انداختند',
#   'بازمى\u200cگرديم',
#   'سرمايه\u200cشان',
#   'ندادم',
#   'خنك',
#   'نعمتش',
#   'تازيانه',
#   'كارنامه\u200cاى',
#   'پيرامونش',
#   'شادى\u200cكنندگان',
#   'مى\u200cزنم',
#   'شايستگانند',
#   'نادانى',
#   'استخوانها',
#   'مى\u200cتوانند',
#   'چشمش',
#   'سويت',
#   'بياسايند',
#   'ميش',
#   'عوايد',
#   'رستگارى',
#   'نيازمنديد',
#   'بردگان',
#   'آيتى',
#   'زيركى',
#   'فاسقى',
#   'انگور',
#   'وقت',
#   'نجاتشان',
#   'بكشى',
#   'نمى\u200cداديد',
#   'مى\u200cميرد',
#   'شصت',
#   'بخشش',
#   'شوند',
#   'پيامبرانش',
#   'آسانى\u200c',
#   'عيبى',
#   'آميغى',
#   'مى\u200cرسند',
#   'آيد',
#   'مى\u200cنازيديد',
#   'يونس\u200c',
#   'پايه',
#   'خويش',
#   'دلها',
#   'مى\u200cكرد',
#   'مواظبت',
#   'سرزمينى',
#   'گوشهايشان',
#   'شبانه\u200cروز',
#   'باخود',
#   'ساز',
#   'شفاعتگران',
#   'گردشان',
#   'آوردنش',
#   'پدرت',
#   'برده\u200cايد',
#   'وظيفه',
#   'مى\u200cدارم',
#   'نصيبى',
#   'مگوييد',
#   'مادرهايتان',
#   'تيمم',
#   'رويانيد',
#   'پيشى',
#   'پروردگارت',
#   'پروردگارا',
#   'وهمين',
#   'نشستن',
#   'اين',
#   'نپرداخته\u200cاند',
#   'بهره\u200cاى',
#   'مرديم',
#   'بيماريد',
#   'فرا',
#   'همه',
#   'صددند',
#   'كتابتان',
#   'خانواده\u200cاش',
#   'گرنه',
#   'نداده\u200cام',
#   'زده\u200cايم',
#   'راستين\u200c',
#   'مكنيد',
#   'بفرستيد',
#   'گزيديد',
#   'هردوشان',
#   'بخورم',
#   'الله',
#   'پاداشى',
#   'عجب',
#   'دارندگان',
#   'بپردازم',
#   'همزيستى',
#   'نيستم',
#   'چشمه\u200cسارانند',
#   'مكه\u200c',
#   'بترسد',
#   'سبحانك',
#   'مطلق\u200c',
#   'كاش',
#   'راه\u200cمانده',
#   'برمى\u200cگردانند',
#   'يارى\u200cدهندگان',
#   'فتنه\u200cجويى',
#   'حسرتى',
#   'برمى\u200cگرداند',
#   'حوران',
#   'منات',
#   'پشيمان',
#   'دامهايتان',
#   'وجود',
#   'طنابى',
#   'بيدادى',
#   'آويخت',
#   'پشيمانى\u200c',
#   'آورد',
#   'بخورانيم',
#   'بگذار',
#   'بچشاند',
#   'نبخشايد',
#   'سنگهايى\u200c',
#   'ترسيدم',
#   'بز',
#   'اين\u200cها',
#   'گامى',
#   'تازه\u200c',
#   'بى\u200cنيازى',
#   'يارى\u200cكردن',
#   'بسته\u200cايم',
#   'عده\u200cاى\u200c',
#   'دستورهاى',
#   'مضمون',
#   'كفار',
#   'آماج',
#   'بازداشتند',
#   'كارشان\u200c',
#   'ياد',
#   'عيال\u200cوار',
#   'تبهكارانه',
#   'دعاست',
#   'نصرانى',
#   'روى\u200cآور',
#   'مشاركتى',
#   'درازشان',
#   'تقدير',
#   'آخرت',
#   'يورش\u200c',
#   'بپوى',
#   'بينند',
#   'يافته\u200cاند',
#   'خدايانتان',
#   'بدانيد',
#   'جبرئيل',
#   'يك\u200c',
#   'كرند',
#   'حقى',
#   'تار',
#   'چيزهايى',
#   'يافتم',
#   'آسوده\u200cخاطرشان',
#   'نمى\u200cطلبم',
#   'سنگهايى',
#   'مدد',
#   'نامت',
#   'وام',
#   'نمانده',
#   'اداره',
#   'بخوريد',
#   'صندوقچه\u200cاى',
#   'رهبرى',
#   'فكرى\u200c',
#   'گردانيديم',
#   'بگرويد',
#   'مى\u200cشنوى',
#   'پناهگاهى',
#   'بفرست',
#   'آنى',
#   'رويانيده\u200cايم',
#   'زيورهاى',
#   'بازگو',
#   'مجسمه\u200cها',
#   'امتناع',
#   'ستمكارند',
#   'دريابد',
#   'اجابتتان',
#   'بازگشتى',
#   'غذايمان',
#   'بيان',
#   'نيكوآراست',
#   'كوتاه',
#   'شگفت\u200cآور',
#   'خدمتكاران',
#   'باشم',
#   'مى\u200cشنوند',
#   'متنفرى',
#   'بازمى\u200cآورد',
#   'بزرگتران',
#   'دراندازد',
#   'پديدار',
#   'نكشد',
#   'مقتول\u200c',
#   'مى\u200cشكنيد',
#   'جوشان',
#   'بسوى',
#   'تگرگى',
#   'مى\u200cنمايانم',
#   'همانگاه',
#   'مركز',
#   'راههاى',
#   'القاكننده',
#   'سپريد',
#   'سپاسگزاران',
#   'نكنيم',
#   'مى\u200cورزد',
#   'فراخى\u200cاش',
#   'مى\u200cخنديد',
#   'گردد',
#   'جهنده\u200cاى',
#   'مى\u200cخواهد',
#   'انتقام\u200cكشنده\u200cايم',
#   'دروغگو',
#   'نيروى',
#   'جن',
#   'نمى\u200cستاييد',
#   'وفادارند',
#   'نتوانست',
#   'سرآمدى',
#   'آموخته\u200cاند',
#   'سازند',
#   'كام',
#   'مى\u200cنمايند',
#   'دادگستران',
#   'پيشينه\u200cاى',
#   'وعده\u200cشان',
#   'كسانى\u200cاند',
#   'ملحق',
#   'اخراج',
#   'حجتشان',
#   'ايستاده\u200cاى',
#   'بى\u200cنقص',
#   'قبل',
#   'غواصى',
#   'چفته\u200cسازى\u200c',
#   'خواهند',
#   'طلا',
#   'شيوه',
#   'نمى\u200cدانستيد',
#   'مسير',
#   'شمارى\u200c',
#   'فرستاده\u200cاى',
#   'آرمان',
#   'برگرداند',
#   'نيافته\u200cاند',
#   'خداوند',
#   'خاكسترى',
#   'آسمانهاى',
#   'كورند',
#   'مردها',
#   'پر',
#   'كسانم',
#   'سپيدى\u200c',
#   'پرنيان',
#   'فرومى\u200cفرستاديم',
#   'جاودانيد',
#   'داورانى',
#   'دلسوز',
#   'دستم',
#   'زنده',
#   'بلعيد',
#   'پايدارى',
#   'گرانى',
#   'قدرت\u200c',
#   'بنى',
#   'جنگ\u200cافزارهاى',
#   'زنده\u200cاى',
#   'نام\u200c',
#   'بازگرديم',
#   'افسون\u200cشده',
#   'زكات',
#   'سربها',
#   'مادر',
#   'سنجش',
#   'نسلش',
#   'نمى\u200cيابند',
#   'لغوتان',
#   'بشريد',
#   'خلاصه\u200c',
#   'جمعيت',
#   'دنيايند',
#   'چسبيده',
#   'نيازتان',
#   'نفْس',
#   'مرده\u200c',
#   'آمدنش',
#   'نيل',
#   'مى\u200cگدازد',
#   'استفاده',
#   'مشماريد',
#   'بناى',
#   'حدود',
#   'پذيرايى',
#   'پاسخ\u200c',
#   'شنوند',
#   'ره\u200cيافتگانند',
#   'لافزن',
#   'سومين',
#   'رويارويشان',
#   'خامى',
#   'عمْر',
#   'بعدا',
#   'بچشانند',
# ...
#   'آزادشان',
#   'زودتر',
#   'لوح\u200cها',
#   'ترسانند',
#   'ميانه\u200cرو',
#   'برنداشتند',
#   'سزايش',
#   'پرده\u200cاى',
#   'گرفتن',
#   'فروشكستيم',
#   'انسان',
#   'مهلت\u200cيافتن',
#   'گريخت',
#   'بيفزاى',
#   'برنشانى\u200cشان',
#   'مى\u200cتوانستند',
#   'كلوخ',
#   'آفريدگان',
#   'گزيد',
#   'روزافزون',
#   'خوراك',
#   'مى\u200cشنيد',
#   'نافرمانيشان',
#   'ارث',
#   'درنمى\u200cآيند',
#   'كامل',
#   'درجات',
#   'ناخوشايند',
#   'رفته\u200cايد',
#   'كنيزان',
#   'واجب\u200c',
#   'بنياد',
#   'بلندگفتن',
#   'برگردانند',
#   'هلاك',
#   'فهمند',
#   'ستيزه\u200c',
#   'مى\u200cگشتيد',
#   'بخواهى',
#   'بپرستد',
#   'گشايش\u200cبخش',
#   'آسيب\u200cها',
#   'ناسازگارى',
#   'كوشكى',
#   'شوى\u200cدوستانى',
#   'بدكاران\u200c',
#   'منجمد',
#   'هشدار',
#   'درس',
#   'فزون\u200cخواهى',
#   'مى\u200cآفرينم',
#   'بسيارى',
#   'مى\u200cشكند',
#   'علت',
#   'خوشبوست',
#   'نستانند',
#   'تاريكيهاى',
#   'مى\u200cتوانيد',
#   'بزرگ\u200c',
#   'بالاى',
#   'خانه\u200c',
#   'غواص',
#   'نادانيد',
#   'قريش\u200c',
#   'نتيجه',
#   'ايستاده',
#   'گرگ',
#   'مالشان',
#   'پاره\u200cهاى',
#   'توبه\u200c',
#   'تعرض',
#   'خواركننده',
#   'مالهاى',
#   'اسرافكاران',
#   'آزادى\u200c',
#   'گوشتهاى',
#   'حقوق',
#   'سخنان\u200c',
#   'درخواست',
#   'ريگ',
#   'هلاك\u200cكننده',
#   'كتابهاى',
#   'نمى\u200cگذاشت',
#   'آسانى',
#   'ميفكن',
#   'آفريده\u200cهاى',
#   'آهنين',
#   'جهود',
#   'ستيزه',
#   'قربانيش',
#   'جست',
#   'داده\u200cايم',
#   'انحراف',
#   'نگاهبانى',
#   'عده',
#   'سرانگشتان',
#   'نافرمانى\u200c',
#   'پايبند',
#   'پدرانمان',
#   'تسلط',
#   'نموده',
#   'نتوانم',
#   'تخت',
#   ...},
#  'sadeqi.xml': {'دورباشی',
#   'موج\u200cشکنان',
#   'یادواره\u200c\u200cای',
#   'صورتگر',
#   'مالم',
#   'شریعت',
#   'مهاجران',
#   'دروغشان',
#   'مانندهاشان',
#   'بفرستید',
#   'نیکویی',
#   'بت\u200cپرستی',
#   'گناهانمان\u200cایم',
#   'دل\u200cهایی',
#   'پاکیزه',
#   'فرما',
#   'شفیعی',
#   'فعال',
#   'سجودکنندگان',
#   'گذرندگان',
#   'گیریم\u200c',
#   'نامید',
#   'هلاک\u200c\u200c\u200cکننده',
#   'نپرست',
#   'شایستگانند',
#   'تواناست\u200c',
#   'سینه\u200cات',
#   'وامی\u200cگذارد',
#   'دستخوش',
#   'سیراب',
#   'نمی\u200cشد',
#   'ساختی',
#   'عصای',
#   'انکار',
#   'زندگان',
#   'نپروراندیم',
#   'چهره\u200cتان',
#   'سپاهیان\u200cاش',
#   'پاکیزه\u200cترند',
#   'گلوگاه\u200cهاشان',
#   'نفس',
#   'پردازد',
#   'سحرت',
#   'برگماشت',
#   'شنیده',
#   'می\u200cآفرینید',
#   'کردیم',
#   'پروا',
#   'نوادگانی',
#   'تاریک\u200cکننده',
#   'سلسبیل',
#   'نظرخواهی',
#   'آرند',
#   'گیرانه\u200cی',
#   'ندارم',
#   'مهلتم',
#   'غیبت\u200cگویی',
#   'زیروزبر',
#   'برنده',
#   'تقسیم\u200cکنندگان',
#   'بیدادگرتر',
#   'خاطرش',
#   'پرهیز',
#   'شدیم\u200c',
#   'حسرت\u200cهاست',
#   'احساسی',
#   'جاودانان',
#   'پیامبری',
#   'پایند',
#   'بدکاریشان',
#   'بزرگان',
#   'تدبیرکنندگان',
#   'آر',
#   'پسران',
#   'می\u200cافکندند',
#   'نیکوکار',
#   'سرگذشت',
#   'تسبیح',
#   'می\u200cخوانید',
#   'سنگ\u200cهایی',
#   'شفاعتش',
#   'شراره\u200cهایی',
#   'ترسیدم',
#   'فزون\u200c\u200cبخشی',
#   'نپیوسته\u200cاند',
#   'شکافتیم',
#   'زمین',
#   'ناب',
#   'می\u200cنموده\u200cاند',
#   'نظیر',
#   'می\u200cانگاریم',
#   'غرفه\u200cهایی',
#   'عاجزند',
#   'نکبت\u200cباری',
#   'آرایش',
#   'آنجا',
#   'مثل\u200cهاست',
#   'حسابگران',
#   'مأموریت',
#   'امیدیافتگان',
#   'برکت\u200cیافتگان',
#   'بازنشستگان',
#   'تبدیل\u200cپذیر',
#   'دخالت',
#   'خودتان',
#   'کفی',
#   'خون\u200cهایشان',
#   'اعمالتان',
#   'کناره',
#   'آمدید',
#   'بپرسم',
#   'خوشحالاند',
#   'به\u200cغیر',
#   'سرانگشتانشان',
#   'آن\u200cها',
#   'نیالودند',
#   'یهودی',
#   'می\u200cداشته\u200cایدکسانی',
#   'برایتان',
#   'نتوانید',
#   'نمی\u200cشوند',
#   'ناداری',
#   'متعلق',
#   'ن',
#   'بزرگ\u200cتر',
#   'تحویل',
#   'همان',
#   'آمال',
#   'درهم\u200cشان',
#   'هریک',
#   'تشخیص',
#   'به\u200cوسیله\u200cای',
#   'تفاوتی',
#   'انحراف\u200cشان',
#   'می\u200cگزارید',
#   'محور',
#   'جانان\u200c',
#   'ناسپاسانی',
#   'وخیم\u200c',
#   'ستمکارانم',
#   'واهی',
#   'مجاهد',
#   'بدفرجام',
#   'موعظه\u200cای',
#   'شبهه\u200cاند',
#   'همگنان',
#   'برگردید',
#   'دادنی',
#   'گماشتند',
#   'دورویان',
#   'مساجد',
#   'ترک\u200cکننده\u200cای',
#   'خاک\u200cنشین',
#   'رویاندیم',
#   'راد',
#   'نابینایی',
#   'جاودانگی',
#   'مجرمانید',
#   'انعام',
#   'هنگامی\u200cکه',
#   'فاجر',
#   'سوئی',
#   'تنفس',
#   'ماییم',
#   'لعنتی',
#   'گسترده\u200cایم',
#   'شنیدن',
#   'حالم',
#   'نافرمان',
#   'شکستیم',
#   'قرارگاهی',
#   'سراها',
#   'غلاف\u200cهایشان',
#   'گورهامان',
#   'مبنا',
#   'اقنوم\u200cهای',
#   'گواهان',
#   'حیاتی',
#   'نتوانی',
#   'سرهاتان',
#   'امارهاش',
#   'نمی\u200cگیریم',
#   'پیچیدن',
#   'همراهی',
#   'موعد',
#   'رحم\u200cهاشان',
#   'گردانیم',
#   'آورندگانید',
#   'داشته\u200cاید',
#   'ابلیس',
#   'جهان\u200cشمول',
#   'شعیب',
#   'لجوجی',
#   'گسیل',
#   'می\u200cگرایند',
#   'دهشت\u200cآور',
#   'منکرناپسند',
#   'امانتش',
#   'باختر',
#   'می\u200cورزم',
#   'سراهای',
#   'تقرب',
#   'ناکسان',
#   'ندادند',
#   'زحمت',
#   'تعبیر',
#   'شاه',
#   'نمی\u200cدانی',
#   'منه',
#   'ونشانه\u200cها',
#   'دیارتان',
#   'اسب\u200cها',
#   'همسایه\u200cای',
#   'سراغ',
#   'بی\u200cآب',
#   'بجز',
#   'انگورها',
#   'وصیله',
#   'شایسته',
#   'متاع\u200cهایتان',
#   'فرستاده',
#   'مراوده\u200cای',
#   'جنبنده\u200cای',
#   'رویانید',
#   'بزهکاران',
#   'پشتیبانی',
#   'جهانتنها',
#   'محصولات',
#   'چشم\u200cهایی',
#   'غفلتید',
#   'آنان\u200c',
#   'نمایش',
#   'هشتاد',
#   'نیافته\u200cاند',
#   '\u200eآنچنان',
#   'رانده\u200cشدگانند',
#   'دیگربا',
#   'دشوار',
#   'انس\u200c',
#   'همگامشان',
#   'بیخ',
#   'نمی\u200cسازیم',
#   'لشکریانشان',
#   'فرزندانش',
#   'درگذرد',
#   'بشنوانی',
#   'پلیدند',
#   'برسند',
#   'احترامات',
#   'بی\u200cبهرگان',
#   'پهن',
#   'زلیخا',
#   'خران',
#   'بیازماییم',
#   'خویشان',
#   'درآویخت',
#   'بودی',
#   'عقلانی\u200cات',
#   'بسا',
#   'ماست\u200c',
#   'شده\u200cایم',
#   'نگذارده\u200c',
#   'آشفته',
#   'فهمی',
#   'مطمئنه\u200cآرمیده\u200c',
#   'غمین',
#   'سینه\u200cهایتان',
#   'شن',
#   'سرافکنده',
#   'استخوانم',
#   'آفریدگان\u200c',
#   'لجن',
#   'برمی\u200cگردانید',
#   'زیرترین',
#   'صفی',
#   'جایگاه\u200cهای',
#   'آشکارگریم',
#   'زدن',
#   'ناگواری',
#   'ناراحتی\u200cها',
#   'خردکننده',
#   'الاقصای',
#   'سامان\u200cها',
#   'زینتی',
#   'ستد',
#   'می\u200cشدند',
#   'گلی',
#   'ستمکارتر',
#   'صبحدم',
#   'کوچکتان',
#   'پراکنده\u200cی',
#   'مپندار',
#   'مردانی',
#   'زشتکاری',
#   'شدنش',
#   'سوت',
#   'پاداشش',
#   'دشواری',
#   'باربر',
#   'لشکریانی',
#   'غیرعرب\u200cزبانان',
#   'زنده\u200cای',
#   'بازماندگان',
#   'می\u200cجستیم',
#   'ستمکارانند',
#   'رسا',
#   'هم\u200cسان',
#   'زنی',
#   'یکدست',
#   'احدی',
#   'شاهیم',
#   'شرع',
#   'کسی',
#   'انتشارش',
#   'نهانش',
#   'فرآورده\u200cهای',
#   'احضارشد\u200cگانند',
#   'گیرندگانند',
#   'افکندید',
#   'نمی\u200cبینم\u200c',
#   'وسیله\u200cی',
#   'فرونهد',
#   'تکذیبند',
#   'معاوضه',
#   'همپای',
#   'می\u200cآموختند',
#   'گام',
#   'امکان',
#   'بکاهید',
#   'ازغافلان',
#   'انگارکنندگان',
#   'قوم',
#   'درآمیختیم',
#   'سنگسارت',
#   'درماندگان',
#   'استهزا',
#   'یعوق',
#   'بحیره',
#   'الوارهای',
#   'سوره',
#   'دوشیزه',
#   'می\u200cساخته',
#   'پاره\u200cپاره',
#   'فتنه\u200cگر',
#   'رسانده\u200cاند',
#   'آلوده',
#   'بی\u200cگزندی',
#   'پیاز',
#   'مشرکانگروه',
#   'خضوع',
#   'افشاگر',
#   'اعجاز',
#   'نپنداریم',
#   'رهایی',
#   'بگردید',
#   'می\u200cخواهیم',
#   'نمی\u200cشود',
#   'عمرشان',
#   'شیرین',
#   'می\u200cگیری\u200c',
#   'وصف',
#   'نویسنده\u200cای',
#   'فروفرستاده',
#   'ملأ',
#   'ننهادیم',
#   'عنایت',
#   'نمی\u200cرساند',
#   'رویش',
#   'هنوز',
#   'اقتدار',
#   'فریب\u200cخوردگی',
#   'مجسمه\u200cی',
#   'شقاوتمان',
#   'وسیع',
#   'گردانیده\u200cام',
#   'مشاهده',
#   'خطاپیشگی',
#   'نمی\u200cنهد',
#   'خشنودند',
#   'کردنتان',
#   'توصیف',
#   'دنباله\u200cروی',
#   'نماییم',
#   'روان\u200cشدنی',
#   'نظرشان',
#   'چهره\u200cاش',
#   'قسم',
#   'سایه\u200cهایی',
#   'عذاب\u200cشدگان',
#   'صلب\u200cهای',
#   'دقیق',
#   'چهل',
#   'می\u200cرسد',
#   'به\u200cپا',
#   'سرگرم',
#   'برما',
#   'دگرگونی\u200cای',
#   'مبتلا',
#   'کی',
#   'خانه\u200cای',
#   'همزیستی',
#   'خون\u200c\u200cبهایی',
#   'سومین',
#   'ذبح\u200c',
#   'لباس\u200cهاشان',
#   'عرف',
#   'دزد',
#   'بگذر',
#   'رویگرداندید',
#   'حوریانی',
#   'ص',
#   'ویژگان',
#   'بازخواست\u200cشونده\u200cا\u200cند',
#   'فراسوی',
#   'ناخوانده\u200cای',
#   'برهر',
#   'تمکین',
#   'بترسی',
#   'سروسامانشان',
#   'پرتاب',
#   'حدقه',
#   'بازگشتند',
#   'شکست',
#   'عار',
#   'برنمی\u200cخیزند',
#   'شناخته\u200cشده',
#   'سوگندت',
#   'بردارد',
#   'رهنماییتان',
#   'دهان\u200cهایشان',
#   'می\u200cداری\u200c',
#   'راندیم',
#   'پیچد',
#   'تجارتی',
#   'نورشان',
#   'کفاره\u200cاش',
#   'ولی',
#   'اصحاب',
#   'سیمای',
#   'خانوداه\u200cای',
#   'چیرگانید',
#   'سر',
#   'ورزیدی',
#   'کشتن',
#   'می\u200cگزینید',
#   'انداختند',
#   'پردهی',
#   'نمی\u200cتواند',
#   'ندادم',
#   'گلوگیر',
#   'آگاهی',
#   'نعمتش',
#   'سایهی',
#   'مرضی',
#   'نگرانم',
#   'بیناییش',
#   'آزادانتان',
#   'پیامدهای',
#   'چشمش',
#   'زندگی',
#   'برگشت\u200cها',
#   'بهره\u200cهای',
#   'بخشیدن',
#   'گریبانگیرتان',
#   'می\u200cگردانید',
#   'عرشیان',
#   'برانی',
#   'نیک\u200cرفتار',
#   'عادیان',
#   'سرپرستانشان',
#   'رگه\u200cهای',
#   'عیسی',
#   'برآنان',
#   'چپ\u200cهاشان',
#   'ذیحجه',
#   'انگور',
#   'دهانشانو',
#   'به\u200cهنگام',
#   'وقت',
#   'نجاتشان',
#   'تخت\u200cهایی',
#   'پیراهن',
#   'رفاهیت',
#   'آشکارکننده\u200cی',
#   'محمدص',
#   'دیرکرد',
#   'شصت',
#   'دهنده\u200cی',
#   'بخشش',
#   'شوند',
#   'موعدی',
#   'علیون',
#   'زیباست',
#   'محمدی',
#   'نیز',
#   'پیشگانند',
#   'نمی\u200cپیمایند',
#   'علمای',
#   'داریم\u200c',
#   'خشوع\u200c',
#   'خدایشان',
#   'روحانی',
#   'نمی\u200cهراسند',
#   'بهشتی',
#   'جعل',
#   'نیستید',
#   'گردشان',
#   'ساز',
#   'شفاعتگران',
#   'آوردنش',
#   'پدرت',
#   'کیفری',
#   'قرب',
#   'روشی',
#   'خرماهایی',
#   'کامل\u200cکننده',
#   'پروردگارت',
#   'روزی\u200cهای',
#   'سعادت',
#   'روشن\u200cگر',
#   'برنگیرند',
#   'نشانه\u200cهایربانی',
#   'احساسش',
#   'رامند',
#   'انکارکنندهی',
#   'زندانیان',
#   'برسرو',
#   'چونان',
#   'اسرافکارید',
#   'می\u200cجهد',
#   'فرا',
#   'همه',
#   'مروه\u200c',
#   'صددند',
#   'خانواده\u200cاش',
#   'اندازه\u200cگیری',
#   'گرنه',
#   'نوادگانشان',
#   'راه\u200cیافته\u200cتر',
#   'بهایی',
#   'مال\u200cهایتان',
#   'ادامه\u200cی',
#   'اینکه\u200c',
#   'گوشت\u200cهایشان',
#   'سنت\u200cهای',
#   'الله',
#   'عجب',
#   'دارندگان',
#   'ریشه\u200cکننده\u200c\u200cهایی',
#   'بیمارم',
#   'بپردازم',
#   'خوارکننده',
#   'دلباخته\u200cی',
#   'تقدیر',
#   'بنمای',
#   'علمش',
#   'پلیدان',
#   'تنزیهاش',
#   'چشمه\u200cسارانند',
#   'بترسد',
#   'حوران',
#   'معنوی',
#   'وجود',
#   'ناکس',
#   'خروش',
#   'نمی\u200cبینیم',
#   'آورد',
#   'اسیر',
#   'پیام\u200cرسانی',
#   'بخواهی',
#   'فروکاسته',
#   'مجتمعیم',
#   'بگذار',
#   'درگذرید',
#   'دشمن\u200cشادم',
#   'بچشاند',
#   'جاده\u200cای',
#   'نرسید',
#   'بز',
#   'رحیم',
#   'شدیدا',
#   'دفاعی',
#   'احسانی',
#   'انگوری',
#   'خانه\u200cهای',
#   'سنگدل',
#   'وصفاش',
#   'بچه\u200cهای',
#   'بر\u200cگردانده',
#   'می\u200cنگرد',
#   'جایگاه\u200cهایی',
#   'موسم',
#   'می\u200cگذارید',
#   'بدآمد',
#   'موجی',
#   'بازداشتند',
#   'یافته\u200cایم',
#   'کودکانی',
#   'بجویید',
#   'روشنگرانه',
#   'درازشان',
#   'بکشید',
#   'یأجوج',
#   'می\u200cطلبیدند',
#   'بفرست\u200c',
#   'وظایفی',
#   'آخرت',
#   'و\u200cحیانی',
#   'گرانشان',
#   'دیده\u200cهاشان',
#   'رهبانیتی',
#   'تار',
#   'نظری',
#   'پلیدی',
#   'میانه\u200cروتر\u200cشان',
#   'چیرگی\u200cتان',
#   'سالم',
#   'آسوده\u200cخاطرشان',
#   'رحم\u200cهاست',
#   'مراوده',
#   'مدد',
#   'نامت',
#   'میعادگاهش',
#   'نمی\u200cگرفتند',
#   'گریبانگیرشان',
#   'گشایشگر',
#   'وام',
#   'نمانده',
#   'خلاف\u200cکننده',
#   'اداره',
#   'سپارید',
#   'مددش',
#   'می\u200cفروشد',
#   'دایی\u200cهایتان',
#   'نمی\u200cزنند',
#   'بفرست',
#   'فرمان\u200cها',
#   'سخت\u200c\u200cدل',
#   'بندطلایی',
#   'بازگو',
#   'مجسمه\u200cها',
#   'هنگامیکه',
#   'امتناع',
#   'موسویان',
#   'پادارند',
#   'هرزه\u200cدرایی',
#   'پیشامد',
#   'بستر',
#   'نیرنگی',
#   'دانه\u200cی',
#   'گنجایش\u200cشان',
#   'گرانی',
#   'بندگاناش',
#   'برپاخاستگان',
#   'شگفت\u200cآور',
#   'نمی\u200cمانند',
#   'کجی',
#   'اویند',
#   'برگیری',
#   'می\u200cچشانیم',
#   'باشم',
#   'می\u200cآمده\u200cاید',
#   'کاری',
#   'پدر\u200c\u200cانتان',
#   'سختیاش',
#   'برنمی\u200cگردند',
#   'می\u200cجنگند',
#   'خوابند',
#   'بخشوده\u200cای',
#   'می\u200cنهی\u200c',
#   'جوشان',
#   'رسالتتو',
#   'شمردیم',
#   'شنیدند',
#   'می\u200cپنداری',
#   'فاعلان',
#   'نشانگرهای',
#   'بیافرید',
#   'آنی\u200c',
#   'یا',
#   'بزنید',
#   'سپاسگزاران',
#   'برگشتشان',
#   'پوشنده\u200c',
#   'سیاه',
#   'بفهمیم',
#   'دوست\u200cگیران',
#   'گورش',
#   'یتیم',
#   'شب\u200cقدر',
#   'می\u200cرهانیم',
#   'خواهرت',
#   'نمایه\u200cی',
#   'ترتیب',
#   'گردد',
#   'گواهی\u200cدهنده\u200cای',
#   'فروزانش',
#   'پاسدار',
#   'می\u200cاندیشند',
#   'دروغگو',
#   'برداشتیم\u200c',
#   'مستندند',
#   'جن',
#   'سنگ\u200cپاره\u200cهایی',
#   'ابراهیمی',
#   'وفادارند',
#   'یادواره\u200cای',
#   'گفتید',
#   'سازند',
#   'می\u200cشمرند',
#   'نام\u200cهای',
#   'ایمان\u200c\u200cآورنده\u200cاند',
#   'وعده\u200cشان',
#   'ملحق',
#   'اخراج',
#   'حجتشان',
#   'قبل',
#   'خواهند',
#   'طلا',
#   'درستش',
#   'هوس\u200cهای',
#   'وادی\u200cهای',
#   'غیبت',
#   'ناچیزی',
#   'می\u200cدانستی',
#   'برگرداند',
#   'نمی\u200cبینید',
#   'فطرت\u200cها',
#   'خداوند',
#   'غنیمت\u200cهای',
#   'سختی',
#   'بیماری',
#   'درودی',
#   'پر',
#   'عمومی',
#   'توانایان',
#   'بردیم',
#   'نمازی',
#   'دیگرید',
#   'بیشترشان',
#   'ولادت',
#   'روزه\u200cای',
#   'بی\u200cبندوبارهای',
#   'دستم',
#   'دلسوز',
#   'زنده',
#   'دندانش',
#   'پیرویتان',
#   'زشتی',
#   'مادر',
#   'دزدانید',
#   'تبذیری',
#   'سنجش',
#   'نسلش',
#   'باکی',
#   'بازگشته\u200c',
#   'می\u200cزنم',
#   'شکسته',
#   'نکورویانند',
#   'بپرهیز',
#   'شقی\u200cترین',
#   'روشنایی\u200cها',
#   'فرستاده\u200c\u200cاش',
#   'هلاکتی',
#   'پرچم\u200cها',
#   'نشنیده',
#   'بازدارد',
#   'ستایشش',
#   'آمدنش',
#   'ساکن',
#   'مهتران',
#   'سرگین',
#   'جستجوکنان',
#   'رحمت\u200cوارتر',
#   'استفاده',
#   'حدود',
#   'پاسخ\u200c',
#   'شنوند',
#   'سپیده\u200cدم',
#   'فزاینده',
#   'امکانات',
#   'طس',
#   'بیفزای',
#   'سبک\u200cبار',
#   'معدودی',
#   'می\u200cکاهد',
#   'دیدار',
#   'فریادی',
#   'پیرویشان',
#   'درازا',
#   'عنادشان',
#   'باعظمت',
#   'محسوس',
#   'آمدهایی',
#   'تبهکاران',
#   'موجود',
#   'فرمان',
#   'استراحتگاهشان',
#   'گمراه\u200cترینند',
#   'خستند',
#   'می\u200cپرستیم\u200c',
#   'خشنودی\u200cای',
#   'دریایی',
#   'نمی\u200cکردید',
#   'همان\u200cگونه',
#   'عذاب\u200c',
#   'می\u200cافراشته\u200cاند',
#   'رهنمونش',
#   'بی\u200cحساب',
#   'جنگ\u200cافزارهایشان',
#   'جملگی',
#   'درک',
#   'نرساند',
#   'می\u200cشکنید',
#   'خداییان',
#   'خاور',
#   'خویشاوندانشان',
#   'می\u200cجهانید',
#   'بساخت',
#   'وآنان',
#   'پشتوانه',
#   'می\u200cگردی',
#   'پرده\u200cهایی',
#   'هزینه',
#   'پابرجا',
#   'کبودچشم',
#   'فراموششان',
#   'دل\u200cهایمان',
#   'نسزد',
#   'کفالت\u200c\u200cکننده',
#   'ادای',
#   'بعض',
#   'درپی\u200cشان',
#   'ملایم',
#   'مرزبندی\u200cهای',
#   'نمی\u200cدارد',
#   'ناتوانی',
#   'توجه\u200cشان',
#   'شمایید',
#   'فرستادید',
#   'مهمان\u200cسرا',
#   'مستحکم',
#   'نهفته',
#   'روزهای',
#   'دل\u200cخراش',
#   'سی',
#   'می\u200cآورده\u200cاند',
#   'زبانه\u200cدارند',
#   'همانکیفرشان',
#   'خواسته\u200cاند',
#   'بی\u200c\u200cیار',
#   'تعقیب',
#   'کیْ',
#   'فرستاده\u200cاش',
#   'می\u200cافتادند',
#   'باغستان\u200cهایی',
#   'می\u200cپرستی\u200c',
#   'معجزه',
#   'مارشان',
#   'بنماییم',
#   'شام',
#   'زیرینش',
#   'معاد',
#   'شفاعتی',
#   'درمانده\u200cکنندگان',
#   'نیاورید',
#   'ستیزه\u200cجویی',
#   'منزهی\u200c',
#   'اندوهگین',
#   'سخت\u200cدل',
#   'آتشباری',
#   'حقیقت',
#   'روشنی\u200cبخش',
#   'بعل',
#   'بنیامین',
#   'بنگرد',
#   'اجساد',
#   'ریزان',
#   'ناخن\u200cهای',
#   'نگشت',
#   'پیشی\u200cگرفته\u200cشدگان',
#   'نمی\u200cشنوید',
#   'نمایان',
#   'خاکسار',
#   'زبان\u200c',
#   'دل\u200cهایشان',
#   'بی\u200cحفاظ',
#   'درگاه',
#   'یکسان',
#   'می\u200cنگریستید',
#   'نمی\u200cکشند',
#   'مردماناند',
#   'یادواره\u200cای\u200c',
#   'بدا',
#   'آغاز',
#   'میانه',
#   'گرایید',
#   'ورزیدند',
#   'یونس',
#   'بدین',
#   'اسم\u200cها',
#   'سپردند',
#   'بزرگ\u200cترین',
#   'دهان',
#   'گفته',
#   'کنم',
#   'حقیت',
#   'تفرقه',
#   'هسته\u200cی',
#   'گردنش',
#   'رهاننده\u200cای',
#   'ترغیب',
#   'مودت',
#   'نگفتم',
#   'مرواریدهایی',
#   'خودبر',
#   'دوست\u200c\u200cداشتنی',
#   'سردر',
#   'توکل',
#   'نگرفته\u200c',
#   'مجنون',
#   'حوادث',
#   'چهره\u200cات',
#   'مرده\u200cهایند',
#   'همان\u200cهایید',
#   'تمسک',
#   'رنگش',
#   'تندی',
#   'فرستیم',
#   'ظلم',
#   'ناسپاس',
#   'طاغوت',
#   'کارکرد',
#   'صف\u200cاند',
#   'بسترهایی',
#   'بپرستیم',
#   'بخوبی',
#   'درآمیزند',
#   'افتد',
#   'آتش\u200cوار',
#   'خواروبارشان',
#   'تماشاگران',
#   'نکردی',
#   'چفته\u200cسازی',
#   'صاحبانشان',
#   'دعوت\u200cکننده\u200cای',
#   'قبضه\u200cی',
#   'زندگیناچیز',
#   'قطعات',
#   'پشیزی',
#   'ایمن',
#   'اهانت\u200c\u200cبار',
#   'سرتان',
#   'حقیقی',
#   'زندگی\u200cهاشان',
#   'برگرفت\u200c',
#   'می\u200cدادید',
#   'زاری',
#   'تیره',
#   'صبح\u200cگاهان',
#   'پیرامونش',
#   'کشیده',
#   'دلبرانی',
#   'جان\u200cهایتان',
#   'نعمتی',
#   'نایافتگانید',
#   'مادرتان',
#   'برآنچه',
#   'عشیره\u200cی',
#   'نفرت',
#   'می\u200cخورانیم',
#   'اتصال',
#   'ویرانگر',
#   'احوال',
#   'نیافریدم',
#   'تدریجی',
#   'تمامیت',
#   'نگهدارید',
#   'دل\u200cربا',
#   'برنگرفته',
#   'باشیم\u200c',
#   'اولوالعزم',
#   'گیری',
#   'برادرم',
#   'آنانی',
#   'یاریش',
#   'بازگشتید',
#   'آتشی',
#   'سوخت',
#   'پراکنده\u200cگویی',
#   'پوشانده',
#   'نیروهایت',
#   'مشعرالحرام',
#   'خدایش',
#   'هوا',
#   'مسکونی',
#   'مراقبند',
#   'تکلیف',
#   'نیرومندترم',
#   'ماندگار',
#   ...}}

# %%
a = translation_dict['makarem'] & translation_dict['moezzi']
len(a)
# Out:
# 3943

# %%
a = 5001/36268
print(round(a*100))
# Out:
# 14

# %%
overlaps = []
for k1 in translation_dict.keys():
  overlap_list = []
  for k2 in translation_dict.keys():
    name = k1 + ' and ' + k2
    overlap = len(translation_dict[k1] & translation_dict[k2])
    # overlap_list.append(overlap)
    union_set = translation_dict[k1] | translation_dict[k2]
    sim_percent = round(overlap/(len(union_set))*100)
    print(name + ": " + str(overlap) + ' percentage: ' + str(sim_percent) + ' ' + str(len(union_set)))
    overlap_list.append(sim_percent)
  overlaps.append(overlap_list)
# Out:
# ansarian and ansarian: 9486 percentage: 100 9486
# ansarian and ayati: 2322 percentage: 14 16574
# ansarian and bahrampour: 2642 percentage: 15 17263
# ansarian and fooladvand: 2561 percentage: 14 17780
# ansarian and ghomshei: 5431 percentage: 36 14975
# ansarian and khorramdel: 6595 percentage: 19 34310
# ansarian and khorramshahi: 4686 percentage: 30 15648
# ansarian and makarem: 5333 percentage: 38 14076
# ansarian and moezzi: 3702 percentage: 24 15634
# ansarian and mojtabavi: 2344 percentage: 13 17851
# ansarian and sadeqi: 5329 percentage: 32 16869
# ayati and ansarian: 2322 percentage: 14 16574
# ayati and ayati: 9410 percentage: 100 9410
# ayati and bahrampour: 5566 percentage: 39 14263
# ayati and fooladvand: 5632 percentage: 38 14633
# ayati and ghomshei: 2410 percentage: 13 17920
# ayati and khorramdel: 2782 percentage: 7 38047
# ayati and khorramshahi: 2255 percentage: 13 18003
# ayati and makarem: 2258 percentage: 13 17075
# ayati and moezzi: 1740 percentage: 10 17520
# ayati and mojtabavi: 5586 percentage: 38 14533
# ayati and sadeqi: 2318 percentage: 12 19804
# bahrampour and ansarian: 2642 percentage: 15 17263
# bahrampour and ayati: 5566 percentage: 39 14263
# bahrampour and bahrampour: 10419 percentage: 100 10419
# bahrampour and fooladvand: 6816 percentage: 47 14458
# bahrampour and ghomshei: 2606 percentage: 14 18733
# bahrampour and khorramdel: 3058 percentage: 8 38780
# bahrampour and khorramshahi: 2573 percentage: 14 18694
# bahrampour and makarem: 2567 percentage: 14 17775
# bahrampour and moezzi: 1793 percentage: 10 18476
# bahrampour and mojtabavi: 5848 percentage: 38 15280
# bahrampour and sadeqi: 2685 percentage: 13 20446
# fooladvand and ansarian: 2561 percentage: 14 17780
# fooladvand and ayati: 5632 percentage: 38 14633
# fooladvand and bahrampour: 6816 percentage: 47 14458
# fooladvand and fooladvand: 10855 percentage: 100 10855
# fooladvand and ghomshei: 2453 percentage: 13 19322
# fooladvand and khorramdel: 2951 percentage: 8 39323
# fooladvand and khorramshahi: 2623 percentage: 14 19080
# fooladvand and makarem: 2454 percentage: 13 18324
# fooladvand and moezzi: 1844 percentage: 10 18861
# fooladvand and mojtabavi: 6054 percentage: 39 15510
# fooladvand and sadeqi: 2926 percentage: 14 20641
# ghomshei and ansarian: 5431 percentage: 36 14975
# ghomshei and ayati: 2410 percentage: 13 17920
# ghomshei and bahrampour: 2606 percentage: 14 18733
# ghomshei and fooladvand: 2453 percentage: 13 19322
# ghomshei and ghomshei: 10920 percentage: 100 10920
# ghomshei and khorramdel: 7553 percentage: 22 34786
# ghomshei and khorramshahi: 5146 percentage: 31 16622
# ghomshei and makarem: 5790 percentage: 38 15053
# ghomshei and moezzi: 4057 percentage: 24 16713
# ghomshei and mojtabavi: 2367 percentage: 12 19262
# ghomshei and sadeqi: 5573 percentage: 31 18059
# khorramdel and ansarian: 6595 percentage: 19 34310
# khorramdel and ayati: 2782 percentage: 7 38047
# khorramdel and bahrampour: 3058 percentage: 8 38780
# khorramdel and fooladvand: 2951 percentage: 8 39323
# khorramdel and ghomshei: 7553 percentage: 22 34786
# khorramdel and khorramdel: 31419 percentage: 100 31419
# khorramdel and khorramshahi: 6405 percentage: 18 35862
# khorramdel and makarem: 7465 percentage: 22 33877
# khorramdel and moezzi: 5001 percentage: 14 36268
# khorramdel and mojtabavi: 2743 percentage: 7 39385
# khorramdel and sadeqi: 7160 percentage: 19 36971
# khorramshahi and ansarian: 4686 percentage: 30 15648
# khorramshahi and ayati: 2255 percentage: 13 18003
# khorramshahi and bahrampour: 2573 percentage: 14 18694
# khorramshahi and fooladvand: 2623 percentage: 14 19080
# khorramshahi and ghomshei: 5146 percentage: 31 16622
# khorramshahi and khorramdel: 6405 percentage: 18 35862
# khorramshahi and khorramshahi: 10848 percentage: 100 10848
# khorramshahi and makarem: 5161 percentage: 33 15610
# khorramshahi and moezzi: 4168 percentage: 25 16530
# khorramshahi and mojtabavi: 2390 percentage: 12 19167
# khorramshahi and sadeqi: 5607 percentage: 31 17953
# makarem and ansarian: 5333 percentage: 38 14076
# makarem and ayati: 2258 percentage: 13 17075
# makarem and bahrampour: 2567 percentage: 14 17775
# makarem and fooladvand: 2454 percentage: 13 18324
# makarem and ghomshei: 5790 percentage: 38 15053
# makarem and khorramdel: 7465 percentage: 22 33877
# makarem and khorramshahi: 5161 percentage: 33 15610
# makarem and makarem: 9923 percentage: 100 9923
# makarem and moezzi: 3943 percentage: 25 15830
# makarem and mojtabavi: 2174 percentage: 12 18458
# makarem and sadeqi: 5627 percentage: 33 17008
# moezzi and ansarian: 3702 percentage: 24 15634
# moezzi and ayati: 1740 percentage: 10 17520
# moezzi and bahrampour: 1793 percentage: 10 18476
# moezzi and fooladvand: 1844 percentage: 10 18861
# moezzi and ghomshei: 4057 percentage: 24 16713
# moezzi and khorramdel: 5001 percentage: 14 36268
# moezzi and khorramshahi: 4168 percentage: 25 16530
# moezzi and makarem: 3943 percentage: 25 15830
# moezzi and moezzi: 9850 percentage: 100 9850
# moezzi and mojtabavi: 1932 percentage: 10 18627
# moezzi and sadeqi: 4353 percentage: 24 18209
# mojtabavi and ansarian: 2344 percentage: 13 17851
# mojtabavi and ayati: 5586 percentage: 38 14533
# mojtabavi and bahrampour: 5848 percentage: 38 15280
# mojtabavi and fooladvand: 6054 percentage: 39 15510
# mojtabavi and ghomshei: 2367 percentage: 12 19262
# mojtabavi and khorramdel: 2743 percentage: 7 39385
# mojtabavi and khorramshahi: 2390 percentage: 12 19167
# mojtabavi and makarem: 2174 percentage: 12 18458
# mojtabavi and moezzi: 1932 percentage: 10 18627
# mojtabavi and mojtabavi: 10709 percentage: 100 10709
# mojtabavi and sadeqi: 2337 percentage: 11 21084
# sadeqi and ansarian: 5329 percentage: 32 16869
# sadeqi and ayati: 2318 percentage: 12 19804
# sadeqi and bahrampour: 2685 percentage: 13 20446
# sadeqi and fooladvand: 2926 percentage: 14 20641
# sadeqi and ghomshei: 5573 percentage: 31 18059
# sadeqi and khorramdel: 7160 percentage: 19 36971
# sadeqi and khorramshahi: 5607 percentage: 31 17953
# sadeqi and makarem: 5627 percentage: 33 17008
# sadeqi and moezzi: 4353 percentage: 24 18209
# sadeqi and mojtabavi: 2337 percentage: 11 21084
# sadeqi and sadeqi: 12712 percentage: 100 12712

# %%
overlaps
# Out:
# [[100, 14, 15, 14, 36, 19, 30, 38, 24, 13, 32],
#  [14, 100, 39, 38, 13, 7, 13, 13, 10, 38, 12],
#  [15, 39, 100, 47, 14, 8, 14, 14, 10, 38, 13],
#  [14, 38, 47, 100, 13, 8, 14, 13, 10, 39, 14],
#  [36, 13, 14, 13, 100, 22, 31, 38, 24, 12, 31],
#  [19, 7, 8, 8, 22, 100, 18, 22, 14, 7, 19],
#  [30, 13, 14, 14, 31, 18, 100, 33, 25, 12, 31],
#  [38, 13, 14, 13, 38, 22, 33, 100, 25, 12, 33],
#  [24, 10, 10, 10, 24, 14, 25, 25, 100, 10, 24],
#  [13, 38, 38, 39, 12, 7, 12, 12, 10, 100, 11],
#  [32, 12, 13, 14, 31, 19, 31, 33, 24, 11, 100]]

# %%
translation_dict.keys()
# Out:
# dict_keys(['ansarian', 'ayati', 'bahrampour', 'fooladvand', 'ghomshei', 'khorramdel', 'khorramshahi', 'makarem', 'moezzi', 'mojtabavi', 'sadeqi'])

# %%
import numpy as np
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

Index= []
Cols = []

for key in translation_dict.keys():
  Index.append(key)
  Cols.append(key)

df = DataFrame(overlaps, index=Index, columns=Cols)

# sns.fig.set_size_inches(15,15)
plt.figure(figsize=(10, 10))
sns.heatmap(df, annot=True)
plt.show()

# %%
overlap_dict = {}
for k1 in translation_dict.keys():
  if k1 not in overlap_dict.keys():
    overlap_dict[k1] = []
    for k2 in translation_dict.keys():
      name = k1 + ' and ' + k2
      overlap = len(translation_dict[k1] & translation_dict[k2])
      print(name + ": " + str(overlap))
# Out:
# ansarian and ansarian: 9486
# ansarian and ayati: 2322
# ansarian and bahrampour: 2642
# ansarian and fooladvand: 2561
# ansarian and ghomshei: 5431
# ansarian and khorramdel: 6595
# ansarian and khorramshahi: 4686
# ansarian and makarem: 5333
# ansarian and moezzi: 3702
# ansarian and mojtabavi: 2344
# ansarian and sadeqi: 5329
# ayati and ansarian: 2322
# ayati and ayati: 9410
# ayati and bahrampour: 5566
# ayati and fooladvand: 5632
# ayati and ghomshei: 2410
# ayati and khorramdel: 2782
# ayati and khorramshahi: 2255
# ayati and makarem: 2258
# ayati and moezzi: 1740
# ayati and mojtabavi: 5586
# ayati and sadeqi: 2318
# bahrampour and ansarian: 2642
# bahrampour and ayati: 5566
# bahrampour and bahrampour: 10419
# bahrampour and fooladvand: 6816
# bahrampour and ghomshei: 2606
# bahrampour and khorramdel: 3058
# bahrampour and khorramshahi: 2573
# bahrampour and makarem: 2567
# bahrampour and moezzi: 1793
# bahrampour and mojtabavi: 5848
# bahrampour and sadeqi: 2685
# fooladvand and ansarian: 2561
# fooladvand and ayati: 5632
# fooladvand and bahrampour: 6816
# fooladvand and fooladvand: 10855
# fooladvand and ghomshei: 2453
# fooladvand and khorramdel: 2951
# fooladvand and khorramshahi: 2623
# fooladvand and makarem: 2454
# fooladvand and moezzi: 1844
# fooladvand and mojtabavi: 6054
# fooladvand and sadeqi: 2926
# ghomshei and ansarian: 5431
# ghomshei and ayati: 2410
# ghomshei and bahrampour: 2606
# ghomshei and fooladvand: 2453
# ghomshei and ghomshei: 10920
# ghomshei and khorramdel: 7553
# ghomshei and khorramshahi: 5146
# ghomshei and makarem: 5790
# ghomshei and moezzi: 4057
# ghomshei and mojtabavi: 2367
# ghomshei and sadeqi: 5573
# khorramdel and ansarian: 6595
# khorramdel and ayati: 2782
# khorramdel and bahrampour: 3058
# khorramdel and fooladvand: 2951
# khorramdel and ghomshei: 7553
# khorramdel and khorramdel: 31419
# khorramdel and khorramshahi: 6405
# khorramdel and makarem: 7465
# khorramdel and moezzi: 5001
# khorramdel and mojtabavi: 2743
# khorramdel and sadeqi: 7160
# khorramshahi and ansarian: 4686
# khorramshahi and ayati: 2255
# khorramshahi and bahrampour: 2573
# khorramshahi and fooladvand: 2623
# khorramshahi and ghomshei: 5146
# khorramshahi and khorramdel: 6405
# khorramshahi and khorramshahi: 10848
# khorramshahi and makarem: 5161
# khorramshahi and moezzi: 4168
# khorramshahi and mojtabavi: 2390
# khorramshahi and sadeqi: 5607
# makarem and ansarian: 5333
# makarem and ayati: 2258
# makarem and bahrampour: 2567
# makarem and fooladvand: 2454
# makarem and ghomshei: 5790
# makarem and khorramdel: 7465
# makarem and khorramshahi: 5161
# makarem and makarem: 9923
# makarem and moezzi: 3943
# makarem and mojtabavi: 2174
# makarem and sadeqi: 5627
# moezzi and ansarian: 3702
# moezzi and ayati: 1740
# moezzi and bahrampour: 1793
# moezzi and fooladvand: 1844
# moezzi and ghomshei: 4057
# moezzi and khorramdel: 5001
# moezzi and khorramshahi: 4168
# moezzi and makarem: 3943
# moezzi and moezzi: 9850
# moezzi and mojtabavi: 1932
# moezzi and sadeqi: 4353
# mojtabavi and ansarian: 2344
# mojtabavi and ayati: 5586
# mojtabavi and bahrampour: 5848
# mojtabavi and fooladvand: 6054
# mojtabavi and ghomshei: 2367
# mojtabavi and khorramdel: 2743
# mojtabavi and khorramshahi: 2390
# mojtabavi and makarem: 2174
# mojtabavi and moezzi: 1932
# mojtabavi and mojtabavi: 10709
# mojtabavi and sadeqi: 2337
# sadeqi and ansarian: 5329
# sadeqi and ayati: 2318
# sadeqi and bahrampour: 2685
# sadeqi and fooladvand: 2926
# sadeqi and ghomshei: 5573
# sadeqi and khorramdel: 7160
# sadeqi and khorramshahi: 5607
# sadeqi and makarem: 5627
# sadeqi and moezzi: 4353
# sadeqi and mojtabavi: 2337
# sadeqi and sadeqi: 12712

# %%
a = 'من رفتم رفتم بیرون'.split()

b = set(a)

b
# Out:
# {'بیرون', 'رفتم', 'من'}

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib
import matplotlib as mpl

plt.figure(figsize=(10, 6))
vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(overlaps)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(Index)), labels=Index)
ax.set_yticks(np.arange(len(Index)), labels=Index)

# Rotate the tick labels and set their alignment.

plt.figure(figsize=(10, 10))
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(Index)):
    for j in range(len(Index)):
      # print(overlaps[i, j])
      text = ax.text(j, i, overlaps[i] [j], ha="center", va="center", color="w")


ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib
import matplotlib as mpl

plt.figure(figsize=(10, 6))
vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(figsize=(10, 10))
# im = ax.imshow(overlaps, cmap="YlGn")
im = ax.imshow(overlaps, cmap= matplotlib.cm.Blues)
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('llllll', rotation=-90, va="bottom")

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(Index)), labels=Index)
ax.set_yticks(np.arange(len(Index)), labels=Index)
ax.set_label('ColorBar')

# Rotate the tick labels and set their alignment.

plt.figure(figsize=(10, 10))
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(Index)):
    for j in range(len(Index)):
      # print(overlaps[i, j])
      text = ax.text(j, i, overlaps[i] [j], ha="center", va="center", color="black")


# ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()
